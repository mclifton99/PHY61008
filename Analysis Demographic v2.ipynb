# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
import time

# %%
#PopnControl R = 4
IPeak = []
PeakTime = []
Dead = []
Dead019 = []
Dead2029 = []
Dead3039 = []
Dead4049 = []
Dead5059 = []
Dead6069 = []
Dead7079 = []
Dead8089 = []
Dead90 = []
ILifting = []
TotalCases = []
Total019 = []
Total2029 = []
Total3039 = []
Total4049 = []
Total5059 = []
Total6069 = []
Total7079 = []
Total8089 = []
Total90 = []
z = 1.960
for i in range(1,101):
    df = pd.read_csv (r'E:\Users\Michael\Project Notebook\Sim Data\PopnControl\4\PopnControl_R4_{}.csv'.format(i))
    Imax = pd.DataFrame.max(df['I'])
    time = pd.DataFrame.max(df.loc[df['I'] == Imax]['t'])
    dead = df['D'].iloc[-1]
    dead019 = df['London Dead 0-19'].iloc[-1] + df['Birmingham Dead 0-19'].iloc[-1] + df['Leeds Dead 0-19'].iloc[-1]\
    + df['Sheffield Dead 0-19'].iloc[-1] + df['Manchester Dead 0-19'].iloc[-1] + df['Bradford Dead 0-19'].iloc[-1]\
    + df['Liverpool Dead 0-19'].iloc[-1] + df['Bristol Dead 0-19'].iloc[-1]
    dead2029 = df['London Dead 20-29'].iloc[-1] + df['Birmingham Dead 20-29'].iloc[-1] + df['Leeds Dead 20-29'].iloc[-1]\
    + df['Sheffield Dead 20-29'].iloc[-1] + df['Manchester Dead 20-29'].iloc[-1] + df['Bradford Dead 20-29'].iloc[-1]\
    + df['Liverpool Dead 20-29'].iloc[-1] + df['Bristol Dead 20-29'].iloc[-1]
    dead3039 = df['London Dead 30-39'].iloc[-1] + df['Birmingham Dead 30-39'].iloc[-1] + df['Leeds Dead 30-39'].iloc[-1]\
    + df['Sheffield Dead 30-39'].iloc[-1] + df['Manchester Dead 30-39'].iloc[-1] + df['Bradford Dead 30-39'].iloc[-1]\
    + df['Liverpool Dead 30-39'].iloc[-1] + df['Bristol Dead 30-39'].iloc[-1]
    dead4049 = df['London Dead 40-49'].iloc[-1] + df['Birmingham Dead 40-49'].iloc[-1] + df['Leeds Dead 40-49'].iloc[-1]\
    + df['Sheffield Dead 40-49'].iloc[-1] + df['Manchester Dead 40-49'].iloc[-1] + df['Bradford Dead 40-49'].iloc[-1]\
    + df['Liverpool Dead 40-49'].iloc[-1] + df['Bristol Dead 40-49'].iloc[-1]
    dead5059 = df['London Dead 50-59'].iloc[-1] + df['Birmingham Dead 50-59'].iloc[-1] + df['Leeds Dead 50-59'].iloc[-1]\
    + df['Sheffield Dead 50-59'].iloc[-1] + df['Manchester Dead 50-59'].iloc[-1] + df['Bradford Dead 50-59'].iloc[-1]\
    + df['Liverpool Dead 50-59'].iloc[-1] + df['Bristol Dead 50-59'].iloc[-1]
    dead6069 = df['London Dead 60-69'].iloc[-1] + df['Birmingham Dead 60-69'].iloc[-1] + df['Leeds Dead 60-69'].iloc[-1]\
    + df['Sheffield Dead 60-69'].iloc[-1] + df['Manchester Dead 60-69'].iloc[-1] + df['Bradford Dead 60-69'].iloc[-1]\
    + df['Liverpool Dead 60-69'].iloc[-1] + df['Bristol Dead 60-69'].iloc[-1]
    dead7079 = df['London Dead 70-79'].iloc[-1] + df['Birmingham Dead 70-79'].iloc[-1] + df['Leeds Dead 70-79'].iloc[-1]\
    + df['Sheffield Dead 70-79'].iloc[-1] + df['Manchester Dead 70-79'].iloc[-1] + df['Bradford Dead 70-79'].iloc[-1]\
    + df['Liverpool Dead 70-79'].iloc[-1] + df['Bristol Dead 70-79'].iloc[-1]
    dead8089 = df['London Dead 80-89'].iloc[-1] + df['Birmingham Dead 80-89'].iloc[-1] + df['Leeds Dead 80-89'].iloc[-1]\
    + df['Sheffield Dead 80-89'].iloc[-1] + df['Manchester Dead 80-89'].iloc[-1] + df['Bradford Dead 80-89'].iloc[-1]\
    + df['Liverpool Dead 80-89'].iloc[-1] + df['Bristol Dead 80-89'].iloc[-1]
    dead90 = df['London Dead 90+'].iloc[-1] + df['Birmingham Dead 90+'].iloc[-1] + df['Leeds Dead 90+'].iloc[-1]\
    + df['Sheffield Dead 90+'].iloc[-1] + df['Manchester Dead 90+'].iloc[-1] + df['Bradford Dead 90+'].iloc[-1]\
    + df['Liverpool Dead 90+'].iloc[-1] + df['Bristol Dead 90+'].iloc[-1]
    Total019 = df['London Total 0-19'].iloc[-1] + df['Birmingham Total 0-19'].iloc[-1] + df['Leeds Total 0-19'].iloc[-1]\
    + df['Sheffield Total 0-19'].iloc[-1] + df['Manchester Total 0-19'].iloc[-1] + df['Bradford Total 0-19'].iloc[-1]\
    + df['Liverpool Total 0-19'].iloc[-1] + df['Bristol Total 0-19'].iloc[-1]
    Total2029 = df['London Total 20-29'].iloc[-1] + df['Birmingham Total 20-29'].iloc[-1] + df['Leeds Total 20-29'].iloc[-1]\
    + df['Sheffield Total 20-29'].iloc[-1] + df['Manchester Total 20-29'].iloc[-1] + df['Bradford Total 20-29'].iloc[-1]\
    + df['Liverpool Total 20-29'].iloc[-1] + df['Bristol Total 20-29'].iloc[-1]
    Total3039 = df['London Total 30-39'].iloc[-1] + df['Birmingham Total 30-39'].iloc[-1] + df['Leeds Total 30-39'].iloc[-1]\
    + df['Sheffield Total 30-39'].iloc[-1] + df['Manchester Total 30-39'].iloc[-1] + df['Bradford Total 30-39'].iloc[-1]\
    + df['Liverpool Total 30-39'].iloc[-1] + df['Bristol Total 30-39'].iloc[-1]
    Total4049 = df['London Total 40-49'].iloc[-1] + df['Birmingham Total 40-49'].iloc[-1] + df['Leeds Total 40-49'].iloc[-1]\
    + df['Sheffield Total 40-49'].iloc[-1] + df['Manchester Total 40-49'].iloc[-1] + df['Bradford Total 40-49'].iloc[-1]\
    + df['Liverpool Total 40-49'].iloc[-1] + df['Bristol Total 40-49'].iloc[-1]
    Total5059 = df['London Total 50-59'].iloc[-1] + df['Birmingham Total 50-59'].iloc[-1] + df['Leeds Total 50-59'].iloc[-1]\
    + df['Sheffield Total 50-59'].iloc[-1] + df['Manchester Total 50-59'].iloc[-1] + df['Bradford Total 50-59'].iloc[-1]\
    + df['Liverpool Total 50-59'].iloc[-1] + df['Bristol Total 50-59'].iloc[-1]
    Total6069 = df['London Total 60-69'].iloc[-1] + df['Birmingham Total 60-69'].iloc[-1] + df['Leeds Total 60-69'].iloc[-1]\
    + df['Sheffield Total 60-69'].iloc[-1] + df['Manchester Total 60-69'].iloc[-1] + df['Bradford Total 60-69'].iloc[-1]\
    + df['Liverpool Total 60-69'].iloc[-1] + df['Bristol Total 60-69'].iloc[-1]
    Total7079 = df['London Total 70-79'].iloc[-1] + df['Birmingham Total 70-79'].iloc[-1] + df['Leeds Total 70-79'].iloc[-1]\
    + df['Sheffield Total 70-79'].iloc[-1] + df['Manchester Total 70-79'].iloc[-1] + df['Bradford Total 70-79'].iloc[-1]\
    + df['Liverpool Total 70-79'].iloc[-1] + df['Bristol Total 70-79'].iloc[-1]
    Total8089 = df['London Total 80-89'].iloc[-1] + df['Birmingham Total 80-89'].iloc[-1] + df['Leeds Total 80-89'].iloc[-1]\
    + df['Sheffield Total 80-89'].iloc[-1] + df['Manchester Total 80-89'].iloc[-1] + df['Bradford Total 80-89'].iloc[-1]\
    + df['Liverpool Total 80-89'].iloc[-1] + df['Bristol Total 80-89'].iloc[-1]
    Total90 = df['London Total 90+'].iloc[-1] + df['Birmingham Total 90+'].iloc[-1] + df['Leeds Total 90+'].iloc[-1]\
    + df['Sheffield Total 90+'].iloc[-1] + df['Manchester Total 90+'].iloc[-1] + df['Bradford Total 90+'].iloc[-1]\
    + df['Liverpool Total 90+'].iloc[-1] + df['Bristol Total 90+'].iloc[-1]
    Ilift = df.loc[1050]['I']
    TotCas = df['Total Cases'].iloc[-1]
    TotalCases.append(TotCas)
    Dead.append(dead)
    IPeak.append(Imax)
    PeakTime.append(time)
    Dead019.append(dead019)
    Dead2029.append(dead2029)
    Dead3039.append(dead3039) 
    Dead4049.append(dead4049) 
    Dead5059.append(dead5059) 
    Dead6069.append(dead6069) 
    Dead7079.append(dead7079) 
    Dead8089.append(dead8089) 
    Dead90.append(dead90)
    ILifting.append(Ilift)
print(np.mean(IPeak),u"\u00B1",np.std(IPeak))
print(np.mean(PeakTime),u"\u00B1",np.std(PeakTime))  
print(np.mean(Dead),u"\u00B1",np.std(Dead))
print(np.mean(Dead019),u"\u00B1",np.std(Dead019))
print(np.mean(Dead2029),u"\u00B1",np.std(Dead2029))
print(np.mean(Dead3039),u"\u00B1",np.std(Dead3039))
print(np.mean(Dead4049),u"\u00B1",np.std(Dead4049))
print(np.mean(Dead5059),u"\u00B1",np.std(Dead5059))
print(np.mean(Dead6069),u"\u00B1",np.std(Dead6069))
print(np.mean(Dead7079),u"\u00B1",np.std(Dead7079))
print(np.mean(Dead8089),u"\u00B1",np.std(Dead8089))
print(np.mean(Dead90),u"\u00B1",np.std(Dead90))
print(np.mean(ILifting),u"\u00B1",np.std(ILifting))
IPeak_PCO_4 = np.mean(IPeak)
PeakTime_PCO_4 = np.mean(PeakTime)
Dead_PCO_4 = np.mean(Dead)
Dead019_PCO_4 = np.mean(Dead019)
Dead2029_PCO_4 = np.mean(Dead2029)
Dead3039_PCO_4 = np.mean(Dead3039)
Dead4049_PCO_4 = np.mean(Dead4049)
Dead5059_PCO_4 = np.mean(Dead5059)
Dead6069_PCO_4 = np.mean(Dead6069)
Dead7079_PCO_4 = np.mean(Dead7079)
Dead8089_PCO_4 = np.mean(Dead8089)
Dead90_PCO_4 = np.mean(Dead90)
ILifting_PCO_4 = np.mean(ILifting)
IPeak_PCO_4_Err = np.std(IPeak)
PeakTime_PCO_4_Err = np.std(PeakTime)
Dead_PCO_4_Err = np.std(Dead)
Dead019_PCO_4_Err = np.std(Dead019)
Dead2029_PCO_4_Err = np.std(Dead2029)
Dead3039_PCO_4_Err = np.std(Dead3039)
Dead4049_PCO_4_Err = np.std(Dead4049)
Dead5059_PCO_4_Err = np.std(Dead5059)
Dead6069_PCO_4_Err = np.std(Dead6069)
Dead7079_PCO_4_Err = np.std(Dead7079)
Dead8089_PCO_4_Err = np.std(Dead8089)
Dead90_PCO_4_Err = np.std(Dead90)
ILifting_PCO_4_Err = np.std(ILifting)
PeakTimeArray_PCO_4 = PeakTime
TotalCases_PCO_4 = np.mean(TotalCases)
TotalCases_PCO_4_Err = np.std(TotalCases)
Total019_PCO_4 = np.mean(Total019)
Total2029_PCO_4 = np.mean(Total2029)
Total3039_PCO_4 = np.mean(Total3039)
Total4049_PCO_4 = np.mean(Total4049)
Total5059_PCO_4 = np.mean(Total5059)
Total6069_PCO_4 = np.mean(Total6069)
Total7079_PCO_4 = np.mean(Total7079)
Total8089_PCO_4 = np.mean(Total8089)
Total90_PCO_4 = np.mean(Total90)
Total019_PCO_4_Err = np.std(Total019)
Total2029_PCO_4_Err = np.std(Total2029)
Total3039_PCO_4_Err = np.std(Total3039)
Total4049_PCO_4_Err = np.std(Total4049)
Total5059_PCO_4_Err = np.std(Total5059)
Total6069_PCO_4_Err = np.std(Total6069)
Total7079_PCO_4_Err = np.std(Total7079)
Total8089_PCO_4_Err = np.std(Total8089)
Total90_PCO_4_Err = np.std(Total90)
# Out:
# 3259280.32 ± 20487.063030546866
# 57.27799999999999 ± 1.0790347538425253
# 191671.81 ± 468.6462353417554
# 524.89 ± 22.85471286190225
# 722.92 ± 28.001314254870252
# 2822.7 ± 53.99638876813893
# 8882.79 ± 103.19072584297487
# 22526.38 ± 152.27000886583016
# 43293.23 ± 242.33954918667322
# 57058.63 ± 242.59788354394192
# 44333.86 ± 198.96532461713022
# 11506.41 ± 101.55245885747918
# 43747.86 ± 5601.115592486911

# %%
#PopnControl R = 3.75
IPeak = []
PeakTime = []
Dead = []
Dead019 = []
Dead2029 = []
Dead3039 = []
Dead4049 = []
Dead5059 = []
Dead6069 = []
Dead7079 = []
Dead8089 = []
Dead90 = []
ILifting = []
TotalCases = []
Total019 = []
Total2029 = []
Total3039 = []
Total4049 = []
Total5059 = []
Total6069 = []
Total7079 = []
Total8089 = []
Total90 = []
z = 1.960
for i in range(1,101):
    df = pd.read_csv (r'E:\Users\Michael\Project Notebook\Sim Data\PopnControl\3.75\PopnControl_R3.75_{}.csv'.format(i))
    Imax = pd.DataFrame.max(df['I'])
    time = pd.DataFrame.max(df.loc[df['I'] == Imax]['t'])
    dead = df['D'].iloc[-1]
    dead019 = df['London Dead 0-19'].iloc[-1] + df['Birmingham Dead 0-19'].iloc[-1] + df['Leeds Dead 0-19'].iloc[-1]\
    + df['Sheffield Dead 0-19'].iloc[-1] + df['Manchester Dead 0-19'].iloc[-1] + df['Bradford Dead 0-19'].iloc[-1]\
    + df['Liverpool Dead 0-19'].iloc[-1] + df['Bristol Dead 0-19'].iloc[-1]
    dead2029 = df['London Dead 20-29'].iloc[-1] + df['Birmingham Dead 20-29'].iloc[-1] + df['Leeds Dead 20-29'].iloc[-1]\
    + df['Sheffield Dead 20-29'].iloc[-1] + df['Manchester Dead 20-29'].iloc[-1] + df['Bradford Dead 20-29'].iloc[-1]\
    + df['Liverpool Dead 20-29'].iloc[-1] + df['Bristol Dead 20-29'].iloc[-1]
    dead3039 = df['London Dead 30-39'].iloc[-1] + df['Birmingham Dead 30-39'].iloc[-1] + df['Leeds Dead 30-39'].iloc[-1]\
    + df['Sheffield Dead 30-39'].iloc[-1] + df['Manchester Dead 30-39'].iloc[-1] + df['Bradford Dead 30-39'].iloc[-1]\
    + df['Liverpool Dead 30-39'].iloc[-1] + df['Bristol Dead 30-39'].iloc[-1]
    dead4049 = df['London Dead 40-49'].iloc[-1] + df['Birmingham Dead 40-49'].iloc[-1] + df['Leeds Dead 40-49'].iloc[-1]\
    + df['Sheffield Dead 40-49'].iloc[-1] + df['Manchester Dead 40-49'].iloc[-1] + df['Bradford Dead 40-49'].iloc[-1]\
    + df['Liverpool Dead 40-49'].iloc[-1] + df['Bristol Dead 40-49'].iloc[-1]
    dead5059 = df['London Dead 50-59'].iloc[-1] + df['Birmingham Dead 50-59'].iloc[-1] + df['Leeds Dead 50-59'].iloc[-1]\
    + df['Sheffield Dead 50-59'].iloc[-1] + df['Manchester Dead 50-59'].iloc[-1] + df['Bradford Dead 50-59'].iloc[-1]\
    + df['Liverpool Dead 50-59'].iloc[-1] + df['Bristol Dead 50-59'].iloc[-1]
    dead6069 = df['London Dead 60-69'].iloc[-1] + df['Birmingham Dead 60-69'].iloc[-1] + df['Leeds Dead 60-69'].iloc[-1]\
    + df['Sheffield Dead 60-69'].iloc[-1] + df['Manchester Dead 60-69'].iloc[-1] + df['Bradford Dead 60-69'].iloc[-1]\
    + df['Liverpool Dead 60-69'].iloc[-1] + df['Bristol Dead 60-69'].iloc[-1]
    dead7079 = df['London Dead 70-79'].iloc[-1] + df['Birmingham Dead 70-79'].iloc[-1] + df['Leeds Dead 70-79'].iloc[-1]\
    + df['Sheffield Dead 70-79'].iloc[-1] + df['Manchester Dead 70-79'].iloc[-1] + df['Bradford Dead 70-79'].iloc[-1]\
    + df['Liverpool Dead 70-79'].iloc[-1] + df['Bristol Dead 70-79'].iloc[-1]
    dead8089 = df['London Dead 80-89'].iloc[-1] + df['Birmingham Dead 80-89'].iloc[-1] + df['Leeds Dead 80-89'].iloc[-1]\
    + df['Sheffield Dead 80-89'].iloc[-1] + df['Manchester Dead 80-89'].iloc[-1] + df['Bradford Dead 80-89'].iloc[-1]\
    + df['Liverpool Dead 80-89'].iloc[-1] + df['Bristol Dead 80-89'].iloc[-1]
    dead90 = df['London Dead 90+'].iloc[-1] + df['Birmingham Dead 90+'].iloc[-1] + df['Leeds Dead 90+'].iloc[-1]\
    + df['Sheffield Dead 90+'].iloc[-1] + df['Manchester Dead 90+'].iloc[-1] + df['Bradford Dead 90+'].iloc[-1]\
    + df['Liverpool Dead 90+'].iloc[-1] + df['Bristol Dead 90+'].iloc[-1]
    Total019 = df['London Total 0-19'].iloc[-1] + df['Birmingham Total 0-19'].iloc[-1] + df['Leeds Total 0-19'].iloc[-1]\
    + df['Sheffield Total 0-19'].iloc[-1] + df['Manchester Total 0-19'].iloc[-1] + df['Bradford Total 0-19'].iloc[-1]\
    + df['Liverpool Total 0-19'].iloc[-1] + df['Bristol Total 0-19'].iloc[-1]
    Total2029 = df['London Total 20-29'].iloc[-1] + df['Birmingham Total 20-29'].iloc[-1] + df['Leeds Total 20-29'].iloc[-1]\
    + df['Sheffield Total 20-29'].iloc[-1] + df['Manchester Total 20-29'].iloc[-1] + df['Bradford Total 20-29'].iloc[-1]\
    + df['Liverpool Total 20-29'].iloc[-1] + df['Bristol Total 20-29'].iloc[-1]
    Total3039 = df['London Total 30-39'].iloc[-1] + df['Birmingham Total 30-39'].iloc[-1] + df['Leeds Total 30-39'].iloc[-1]\
    + df['Sheffield Total 30-39'].iloc[-1] + df['Manchester Total 30-39'].iloc[-1] + df['Bradford Total 30-39'].iloc[-1]\
    + df['Liverpool Total 30-39'].iloc[-1] + df['Bristol Total 30-39'].iloc[-1]
    Total4049 = df['London Total 40-49'].iloc[-1] + df['Birmingham Total 40-49'].iloc[-1] + df['Leeds Total 40-49'].iloc[-1]\
    + df['Sheffield Total 40-49'].iloc[-1] + df['Manchester Total 40-49'].iloc[-1] + df['Bradford Total 40-49'].iloc[-1]\
    + df['Liverpool Total 40-49'].iloc[-1] + df['Bristol Total 40-49'].iloc[-1]
    Total5059 = df['London Total 50-59'].iloc[-1] + df['Birmingham Total 50-59'].iloc[-1] + df['Leeds Total 50-59'].iloc[-1]\
    + df['Sheffield Total 50-59'].iloc[-1] + df['Manchester Total 50-59'].iloc[-1] + df['Bradford Total 50-59'].iloc[-1]\
    + df['Liverpool Total 50-59'].iloc[-1] + df['Bristol Total 50-59'].iloc[-1]
    Total6069 = df['London Total 60-69'].iloc[-1] + df['Birmingham Total 60-69'].iloc[-1] + df['Leeds Total 60-69'].iloc[-1]\
    + df['Sheffield Total 60-69'].iloc[-1] + df['Manchester Total 60-69'].iloc[-1] + df['Bradford Total 60-69'].iloc[-1]\
    + df['Liverpool Total 60-69'].iloc[-1] + df['Bristol Total 60-69'].iloc[-1]
    Total7079 = df['London Total 70-79'].iloc[-1] + df['Birmingham Total 70-79'].iloc[-1] + df['Leeds Total 70-79'].iloc[-1]\
    + df['Sheffield Total 70-79'].iloc[-1] + df['Manchester Total 70-79'].iloc[-1] + df['Bradford Total 70-79'].iloc[-1]\
    + df['Liverpool Total 70-79'].iloc[-1] + df['Bristol Total 70-79'].iloc[-1]
    Total8089 = df['London Total 80-89'].iloc[-1] + df['Birmingham Total 80-89'].iloc[-1] + df['Leeds Total 80-89'].iloc[-1]\
    + df['Sheffield Total 80-89'].iloc[-1] + df['Manchester Total 80-89'].iloc[-1] + df['Bradford Total 80-89'].iloc[-1]\
    + df['Liverpool Total 80-89'].iloc[-1] + df['Bristol Total 80-89'].iloc[-1]
    Total90 = df['London Total 90+'].iloc[-1] + df['Birmingham Total 90+'].iloc[-1] + df['Leeds Total 90+'].iloc[-1]\
    + df['Sheffield Total 90+'].iloc[-1] + df['Manchester Total 90+'].iloc[-1] + df['Bradford Total 90+'].iloc[-1]\
    + df['Liverpool Total 90+'].iloc[-1] + df['Bristol Total 90+'].iloc[-1]
    Ilift = df.loc[1050]['I']
    TotCas = df['Total Cases'].iloc[-1]
    TotalCases.append(TotCas)
    Dead.append(dead)
    IPeak.append(Imax)
    PeakTime.append(time)
    Dead019.append(dead019)
    Dead2029.append(dead2029)
    Dead3039.append(dead3039) 
    Dead4049.append(dead4049) 
    Dead5059.append(dead5059) 
    Dead6069.append(dead6069) 
    Dead7079.append(dead7079) 
    Dead8089.append(dead8089) 
    Dead90.append(dead90)
    ILifting.append(Ilift)
print(np.mean(IPeak),u"\u00B1",np.std(IPeak))
print(np.mean(PeakTime),u"\u00B1",np.std(PeakTime))  
print(np.mean(Dead),u"\u00B1",np.std(Dead))
print(np.mean(Dead019),u"\u00B1",np.std(Dead019))
print(np.mean(Dead2029),u"\u00B1",np.std(Dead2029))
print(np.mean(Dead3039),u"\u00B1",np.std(Dead3039))
print(np.mean(Dead4049),u"\u00B1",np.std(Dead4049))
print(np.mean(Dead5059),u"\u00B1",np.std(Dead5059))
print(np.mean(Dead6069),u"\u00B1",np.std(Dead6069))
print(np.mean(Dead7079),u"\u00B1",np.std(Dead7079))
print(np.mean(Dead8089),u"\u00B1",np.std(Dead8089))
print(np.mean(Dead90),u"\u00B1",np.std(Dead90))
print(np.mean(ILifting),u"\u00B1",np.std(ILifting))
IPeak_PCO_375 = np.mean(IPeak)
PeakTime_PCO_375 = np.mean(PeakTime)
Dead_PCO_375 = np.mean(Dead)
Dead019_PCO_375 = np.mean(Dead019)
Dead2029_PCO_375 = np.mean(Dead2029)
Dead3039_PCO_375 = np.mean(Dead3039)
Dead4049_PCO_375 = np.mean(Dead4049)
Dead5059_PCO_375 = np.mean(Dead5059)
Dead6069_PCO_375 = np.mean(Dead6069)
Dead7079_PCO_375 = np.mean(Dead7079)
Dead8089_PCO_375 = np.mean(Dead8089)
Dead90_PCO_375 = np.mean(Dead90)
ILifting_PCO_375 = np.mean(ILifting)
IPeak_PCO_375_Err = np.std(IPeak)
PeakTime_PCO_375_Err = np.std(PeakTime)
Dead_PCO_375_Err = np.std(Dead)
Dead019_PCO_375_Err = np.std(Dead019)
Dead2029_PCO_375_Err = np.std(Dead2029)
Dead3039_PCO_375_Err = np.std(Dead3039)
Dead4049_PCO_375_Err = np.std(Dead4049)
Dead5059_PCO_375_Err = np.std(Dead5059)
Dead6069_PCO_375_Err = np.std(Dead6069)
Dead7079_PCO_375_Err = np.std(Dead7079)
Dead8089_PCO_375_Err = np.std(Dead8089)
Dead90_PCO_375_Err = np.std(Dead90)
ILifting_PCO_375_Err = np.std(ILifting)
PeakTimeArray_PCO_375 = PeakTime
TotalCases_PCO_375 = np.mean(TotalCases)
TotalCases_PCO_375_Err = np.std(TotalCases)
Total019_PCO_375 = np.mean(Total019)
Total2029_PCO_375 = np.mean(Total2029)
Total3039_PCO_375 = np.mean(Total3039)
Total4049_PCO_375 = np.mean(Total4049)
Total5059_PCO_375 = np.mean(Total5059)
Total6069_PCO_375 = np.mean(Total6069)
Total7079_PCO_375 = np.mean(Total7079)
Total8089_PCO_375 = np.mean(Total8089)
Total90_PCO_375 = np.mean(Total90)
Total019_PCO_375_Err = np.std(Total019)
Total2029_PCO_375_Err = np.std(Total2029)
Total3039_PCO_375_Err = np.std(Total3039)
Total4049_PCO_375_Err = np.std(Total4049)
Total5059_PCO_375_Err = np.std(Total5059)
Total6069_PCO_375_Err = np.std(Total6069)
Total7079_PCO_375_Err = np.std(Total7079)
Total8089_PCO_375_Err = np.std(Total8089)
Total90_PCO_375_Err = np.std(Total90)
# Out:
# 3093227.15 ± 18833.467761076292
# 61.49400000000001 ± 1.2095304874206356
# 183306.59 ± 498.98519206485474
# 519.14 ± 23.62457195379421
# 719.56 ± 30.998490285818757
# 2805.03 ± 60.00024249950995
# 8844.4 ± 97.42853791369343
# 22133.94 ± 159.11780667166073
# 41547.92 ± 207.82019536127862
# 53963.41 ± 247.73457954028137
# 41915.35 ± 184.02061705145977
# 10857.84 ± 104.30299324563987
# 77294.33 ± 10515.77285419859

# %%
#PopnControl R = 3.5
IPeak = []
PeakTime = []
Dead = []
Dead019 = []
Dead2029 = []
Dead3039 = []
Dead4049 = []
Dead5059 = []
Dead6069 = []
Dead7079 = []
Dead8089 = []
Dead90 = []
ILifting = []
TotalCases = []
Total019 = []
Total2029 = []
Total3039 = []
Total4049 = []
Total5059 = []
Total6069 = []
Total7079 = []
Total8089 = []
Total90 = []
z = 1.960
for i in range(1,101):
    df = pd.read_csv (r'E:\Users\Michael\Project Notebook\Sim Data\PopnControl\3.5\PopnControl_R3.5_{}.csv'.format(i))
    Imax = pd.DataFrame.max(df['I'])
    time = pd.DataFrame.max(df.loc[df['I'] == Imax]['t'])
    dead = df['D'].iloc[-1]
    dead019 = df['London Dead 0-19'].iloc[-1] + df['Birmingham Dead 0-19'].iloc[-1] + df['Leeds Dead 0-19'].iloc[-1]\
    + df['Sheffield Dead 0-19'].iloc[-1] + df['Manchester Dead 0-19'].iloc[-1] + df['Bradford Dead 0-19'].iloc[-1]\
    + df['Liverpool Dead 0-19'].iloc[-1] + df['Bristol Dead 0-19'].iloc[-1]
    dead2029 = df['London Dead 20-29'].iloc[-1] + df['Birmingham Dead 20-29'].iloc[-1] + df['Leeds Dead 20-29'].iloc[-1]\
    + df['Sheffield Dead 20-29'].iloc[-1] + df['Manchester Dead 20-29'].iloc[-1] + df['Bradford Dead 20-29'].iloc[-1]\
    + df['Liverpool Dead 20-29'].iloc[-1] + df['Bristol Dead 20-29'].iloc[-1]
    dead3039 = df['London Dead 30-39'].iloc[-1] + df['Birmingham Dead 30-39'].iloc[-1] + df['Leeds Dead 30-39'].iloc[-1]\
    + df['Sheffield Dead 30-39'].iloc[-1] + df['Manchester Dead 30-39'].iloc[-1] + df['Bradford Dead 30-39'].iloc[-1]\
    + df['Liverpool Dead 30-39'].iloc[-1] + df['Bristol Dead 30-39'].iloc[-1]
    dead4049 = df['London Dead 40-49'].iloc[-1] + df['Birmingham Dead 40-49'].iloc[-1] + df['Leeds Dead 40-49'].iloc[-1]\
    + df['Sheffield Dead 40-49'].iloc[-1] + df['Manchester Dead 40-49'].iloc[-1] + df['Bradford Dead 40-49'].iloc[-1]\
    + df['Liverpool Dead 40-49'].iloc[-1] + df['Bristol Dead 40-49'].iloc[-1]
    dead5059 = df['London Dead 50-59'].iloc[-1] + df['Birmingham Dead 50-59'].iloc[-1] + df['Leeds Dead 50-59'].iloc[-1]\
    + df['Sheffield Dead 50-59'].iloc[-1] + df['Manchester Dead 50-59'].iloc[-1] + df['Bradford Dead 50-59'].iloc[-1]\
    + df['Liverpool Dead 50-59'].iloc[-1] + df['Bristol Dead 50-59'].iloc[-1]
    dead6069 = df['London Dead 60-69'].iloc[-1] + df['Birmingham Dead 60-69'].iloc[-1] + df['Leeds Dead 60-69'].iloc[-1]\
    + df['Sheffield Dead 60-69'].iloc[-1] + df['Manchester Dead 60-69'].iloc[-1] + df['Bradford Dead 60-69'].iloc[-1]\
    + df['Liverpool Dead 60-69'].iloc[-1] + df['Bristol Dead 60-69'].iloc[-1]
    dead7079 = df['London Dead 70-79'].iloc[-1] + df['Birmingham Dead 70-79'].iloc[-1] + df['Leeds Dead 70-79'].iloc[-1]\
    + df['Sheffield Dead 70-79'].iloc[-1] + df['Manchester Dead 70-79'].iloc[-1] + df['Bradford Dead 70-79'].iloc[-1]\
    + df['Liverpool Dead 70-79'].iloc[-1] + df['Bristol Dead 70-79'].iloc[-1]
    dead8089 = df['London Dead 80-89'].iloc[-1] + df['Birmingham Dead 80-89'].iloc[-1] + df['Leeds Dead 80-89'].iloc[-1]\
    + df['Sheffield Dead 80-89'].iloc[-1] + df['Manchester Dead 80-89'].iloc[-1] + df['Bradford Dead 80-89'].iloc[-1]\
    + df['Liverpool Dead 80-89'].iloc[-1] + df['Bristol Dead 80-89'].iloc[-1]
    dead90 = df['London Dead 90+'].iloc[-1] + df['Birmingham Dead 90+'].iloc[-1] + df['Leeds Dead 90+'].iloc[-1]\
    + df['Sheffield Dead 90+'].iloc[-1] + df['Manchester Dead 90+'].iloc[-1] + df['Bradford Dead 90+'].iloc[-1]\
    + df['Liverpool Dead 90+'].iloc[-1] + df['Bristol Dead 90+'].iloc[-1]
    Total019 = df['London Total 0-19'].iloc[-1] + df['Birmingham Total 0-19'].iloc[-1] + df['Leeds Total 0-19'].iloc[-1]\
    + df['Sheffield Total 0-19'].iloc[-1] + df['Manchester Total 0-19'].iloc[-1] + df['Bradford Total 0-19'].iloc[-1]\
    + df['Liverpool Total 0-19'].iloc[-1] + df['Bristol Total 0-19'].iloc[-1]
    Total2029 = df['London Total 20-29'].iloc[-1] + df['Birmingham Total 20-29'].iloc[-1] + df['Leeds Total 20-29'].iloc[-1]\
    + df['Sheffield Total 20-29'].iloc[-1] + df['Manchester Total 20-29'].iloc[-1] + df['Bradford Total 20-29'].iloc[-1]\
    + df['Liverpool Total 20-29'].iloc[-1] + df['Bristol Total 20-29'].iloc[-1]
    Total3039 = df['London Total 30-39'].iloc[-1] + df['Birmingham Total 30-39'].iloc[-1] + df['Leeds Total 30-39'].iloc[-1]\
    + df['Sheffield Total 30-39'].iloc[-1] + df['Manchester Total 30-39'].iloc[-1] + df['Bradford Total 30-39'].iloc[-1]\
    + df['Liverpool Total 30-39'].iloc[-1] + df['Bristol Total 30-39'].iloc[-1]
    Total4049 = df['London Total 40-49'].iloc[-1] + df['Birmingham Total 40-49'].iloc[-1] + df['Leeds Total 40-49'].iloc[-1]\
    + df['Sheffield Total 40-49'].iloc[-1] + df['Manchester Total 40-49'].iloc[-1] + df['Bradford Total 40-49'].iloc[-1]\
    + df['Liverpool Total 40-49'].iloc[-1] + df['Bristol Total 40-49'].iloc[-1]
    Total5059 = df['London Total 50-59'].iloc[-1] + df['Birmingham Total 50-59'].iloc[-1] + df['Leeds Total 50-59'].iloc[-1]\
    + df['Sheffield Total 50-59'].iloc[-1] + df['Manchester Total 50-59'].iloc[-1] + df['Bradford Total 50-59'].iloc[-1]\
    + df['Liverpool Total 50-59'].iloc[-1] + df['Bristol Total 50-59'].iloc[-1]
    Total6069 = df['London Total 60-69'].iloc[-1] + df['Birmingham Total 60-69'].iloc[-1] + df['Leeds Total 60-69'].iloc[-1]\
    + df['Sheffield Total 60-69'].iloc[-1] + df['Manchester Total 60-69'].iloc[-1] + df['Bradford Total 60-69'].iloc[-1]\
    + df['Liverpool Total 60-69'].iloc[-1] + df['Bristol Total 60-69'].iloc[-1]
    Total7079 = df['London Total 70-79'].iloc[-1] + df['Birmingham Total 70-79'].iloc[-1] + df['Leeds Total 70-79'].iloc[-1]\
    + df['Sheffield Total 70-79'].iloc[-1] + df['Manchester Total 70-79'].iloc[-1] + df['Bradford Total 70-79'].iloc[-1]\
    + df['Liverpool Total 70-79'].iloc[-1] + df['Bristol Total 70-79'].iloc[-1]
    Total8089 = df['London Total 80-89'].iloc[-1] + df['Birmingham Total 80-89'].iloc[-1] + df['Leeds Total 80-89'].iloc[-1]\
    + df['Sheffield Total 80-89'].iloc[-1] + df['Manchester Total 80-89'].iloc[-1] + df['Bradford Total 80-89'].iloc[-1]\
    + df['Liverpool Total 80-89'].iloc[-1] + df['Bristol Total 80-89'].iloc[-1]
    Total90 = df['London Total 90+'].iloc[-1] + df['Birmingham Total 90+'].iloc[-1] + df['Leeds Total 90+'].iloc[-1]\
    + df['Sheffield Total 90+'].iloc[-1] + df['Manchester Total 90+'].iloc[-1] + df['Bradford Total 90+'].iloc[-1]\
    + df['Liverpool Total 90+'].iloc[-1] + df['Bristol Total 90+'].iloc[-1]
    Ilift = df.loc[1050]['I']
    TotCas = df['Total Cases'].iloc[-1]
    TotalCases.append(TotCas)
    Dead.append(dead)
    IPeak.append(Imax)
    PeakTime.append(time)
    Dead019.append(dead019)
    Dead2029.append(dead2029)
    Dead3039.append(dead3039) 
    Dead4049.append(dead4049) 
    Dead5059.append(dead5059) 
    Dead6069.append(dead6069) 
    Dead7079.append(dead7079) 
    Dead8089.append(dead8089) 
    Dead90.append(dead90)
    ILifting.append(Ilift)
print(np.mean(IPeak),u"\u00B1",np.std(IPeak))
print(np.mean(PeakTime),u"\u00B1",np.std(PeakTime))  
print(np.mean(Dead),u"\u00B1",np.std(Dead))
print(np.mean(Dead019),u"\u00B1",np.std(Dead019))
print(np.mean(Dead2029),u"\u00B1",np.std(Dead2029))
print(np.mean(Dead3039),u"\u00B1",np.std(Dead3039))
print(np.mean(Dead4049),u"\u00B1",np.std(Dead4049))
print(np.mean(Dead5059),u"\u00B1",np.std(Dead5059))
print(np.mean(Dead6069),u"\u00B1",np.std(Dead6069))
print(np.mean(Dead7079),u"\u00B1",np.std(Dead7079))
print(np.mean(Dead8089),u"\u00B1",np.std(Dead8089))
print(np.mean(Dead90),u"\u00B1",np.std(Dead90))
print(np.mean(ILifting),u"\u00B1",np.std(ILifting))
IPeak_PCO_35 = np.mean(IPeak)
PeakTime_PCO_35 = np.mean(PeakTime)
Dead_PCO_35 = np.mean(Dead)
Dead019_PCO_35 = np.mean(Dead019)
Dead2029_PCO_35 = np.mean(Dead2029)
Dead3039_PCO_35 = np.mean(Dead3039)
Dead4049_PCO_35 = np.mean(Dead4049)
Dead5059_PCO_35 = np.mean(Dead5059)
Dead6069_PCO_35 = np.mean(Dead6069)
Dead7079_PCO_35 = np.mean(Dead7079)
Dead8089_PCO_35 = np.mean(Dead8089)
Dead90_PCO_35 = np.mean(Dead90)
ILifting_PCO_35 = np.mean(ILifting)
IPeak_PCO_35_Err = np.std(IPeak)
PeakTime_PCO_35_Err = np.std(PeakTime)
Dead_PCO_35_Err = np.std(Dead)
Dead019_PCO_35_Err = np.std(Dead019)
Dead2029_PCO_35_Err = np.std(Dead2029)
Dead3039_PCO_35_Err = np.std(Dead3039)
Dead4049_PCO_35_Err = np.std(Dead4049)
Dead5059_PCO_35_Err = np.std(Dead5059)
Dead6069_PCO_35_Err = np.std(Dead6069)
Dead7079_PCO_35_Err = np.std(Dead7079)
Dead8089_PCO_35_Err = np.std(Dead8089)
Dead90_PCO_35_Err = np.std(Dead90)
ILifting_PCO_35_Err = np.std(ILifting)
PeakTimeArray_PCO_35 = PeakTime
TotalCases_PCO_35 = np.mean(TotalCases)
TotalCases_PCO_35_Err = np.std(TotalCases)
Total019_PCO_35 = np.mean(Total019)
Total2029_PCO_35 = np.mean(Total2029)
Total3039_PCO_35 = np.mean(Total3039)
Total4049_PCO_35 = np.mean(Total4049)
Total5059_PCO_35 = np.mean(Total5059)
Total6069_PCO_35 = np.mean(Total6069)
Total7079_PCO_35 = np.mean(Total7079)
Total8089_PCO_35 = np.mean(Total8089)
Total90_PCO_35 = np.mean(Total90)
Total019_PCO_35_Err = np.std(Total019)
Total2029_PCO_35_Err = np.std(Total2029)
Total3039_PCO_35_Err = np.std(Total3039)
Total4049_PCO_35_Err = np.std(Total4049)
Total5059_PCO_35_Err = np.std(Total5059)
Total6069_PCO_35_Err = np.std(Total6069)
Total7079_PCO_35_Err = np.std(Total7079)
Total8089_PCO_35_Err = np.std(Total8089)
Total90_PCO_35_Err = np.std(Total90)
# Out:
# 2907411.29 ± 19010.12675880674
# 66.52000000000001 ± 1.5139352694220451
# 174396.01 ± 406.0032880408729
# 515.54 ± 22.764191178251863
# 713.36 ± 28.591089521037844
# 2780.19 ± 50.908485540231894
# 8813.2 ± 102.42226320483256
# 21666.04 ± 135.2438479192307
# 39670.63 ± 189.13295085732682
# 50605.57 ± 218.39712704154326
# 39419.96 ± 207.53481250142107
# 10211.52 ± 87.9997136358977
# 145933.53 ± 23720.541619640564

# %%
#PopnControl R = 3.25
IPeak = []
PeakTime = []
Dead = []
Dead019 = []
Dead2029 = []
Dead3039 = []
Dead4049 = []
Dead5059 = []
Dead6069 = []
Dead7079 = []
Dead8089 = []
Dead90 = []
ILifting = []
TotalCases = []
Total019 = []
Total2029 = []
Total3039 = []
Total4049 = []
Total5059 = []
Total6069 = []
Total7079 = []
Total8089 = []
Total90 = []
z = 1.960
for i in range(1,101):
    df = pd.read_csv (r'E:\Users\Michael\Project Notebook\Sim Data\PopnControl\3.25\PopnControl_R3.25_{}.csv'.format(i))
    Imax = pd.DataFrame.max(df['I'])
    time = pd.DataFrame.max(df.loc[df['I'] == Imax]['t'])
    dead = df['D'].iloc[-1]
    dead019 = df['London Dead 0-19'].iloc[-1] + df['Birmingham Dead 0-19'].iloc[-1] + df['Leeds Dead 0-19'].iloc[-1]\
    + df['Sheffield Dead 0-19'].iloc[-1] + df['Manchester Dead 0-19'].iloc[-1] + df['Bradford Dead 0-19'].iloc[-1]\
    + df['Liverpool Dead 0-19'].iloc[-1] + df['Bristol Dead 0-19'].iloc[-1]
    dead2029 = df['London Dead 20-29'].iloc[-1] + df['Birmingham Dead 20-29'].iloc[-1] + df['Leeds Dead 20-29'].iloc[-1]\
    + df['Sheffield Dead 20-29'].iloc[-1] + df['Manchester Dead 20-29'].iloc[-1] + df['Bradford Dead 20-29'].iloc[-1]\
    + df['Liverpool Dead 20-29'].iloc[-1] + df['Bristol Dead 20-29'].iloc[-1]
    dead3039 = df['London Dead 30-39'].iloc[-1] + df['Birmingham Dead 30-39'].iloc[-1] + df['Leeds Dead 30-39'].iloc[-1]\
    + df['Sheffield Dead 30-39'].iloc[-1] + df['Manchester Dead 30-39'].iloc[-1] + df['Bradford Dead 30-39'].iloc[-1]\
    + df['Liverpool Dead 30-39'].iloc[-1] + df['Bristol Dead 30-39'].iloc[-1]
    dead4049 = df['London Dead 40-49'].iloc[-1] + df['Birmingham Dead 40-49'].iloc[-1] + df['Leeds Dead 40-49'].iloc[-1]\
    + df['Sheffield Dead 40-49'].iloc[-1] + df['Manchester Dead 40-49'].iloc[-1] + df['Bradford Dead 40-49'].iloc[-1]\
    + df['Liverpool Dead 40-49'].iloc[-1] + df['Bristol Dead 40-49'].iloc[-1]
    dead5059 = df['London Dead 50-59'].iloc[-1] + df['Birmingham Dead 50-59'].iloc[-1] + df['Leeds Dead 50-59'].iloc[-1]\
    + df['Sheffield Dead 50-59'].iloc[-1] + df['Manchester Dead 50-59'].iloc[-1] + df['Bradford Dead 50-59'].iloc[-1]\
    + df['Liverpool Dead 50-59'].iloc[-1] + df['Bristol Dead 50-59'].iloc[-1]
    dead6069 = df['London Dead 60-69'].iloc[-1] + df['Birmingham Dead 60-69'].iloc[-1] + df['Leeds Dead 60-69'].iloc[-1]\
    + df['Sheffield Dead 60-69'].iloc[-1] + df['Manchester Dead 60-69'].iloc[-1] + df['Bradford Dead 60-69'].iloc[-1]\
    + df['Liverpool Dead 60-69'].iloc[-1] + df['Bristol Dead 60-69'].iloc[-1]
    dead7079 = df['London Dead 70-79'].iloc[-1] + df['Birmingham Dead 70-79'].iloc[-1] + df['Leeds Dead 70-79'].iloc[-1]\
    + df['Sheffield Dead 70-79'].iloc[-1] + df['Manchester Dead 70-79'].iloc[-1] + df['Bradford Dead 70-79'].iloc[-1]\
    + df['Liverpool Dead 70-79'].iloc[-1] + df['Bristol Dead 70-79'].iloc[-1]
    dead8089 = df['London Dead 80-89'].iloc[-1] + df['Birmingham Dead 80-89'].iloc[-1] + df['Leeds Dead 80-89'].iloc[-1]\
    + df['Sheffield Dead 80-89'].iloc[-1] + df['Manchester Dead 80-89'].iloc[-1] + df['Bradford Dead 80-89'].iloc[-1]\
    + df['Liverpool Dead 80-89'].iloc[-1] + df['Bristol Dead 80-89'].iloc[-1]
    dead90 = df['London Dead 90+'].iloc[-1] + df['Birmingham Dead 90+'].iloc[-1] + df['Leeds Dead 90+'].iloc[-1]\
    + df['Sheffield Dead 90+'].iloc[-1] + df['Manchester Dead 90+'].iloc[-1] + df['Bradford Dead 90+'].iloc[-1]\
    + df['Liverpool Dead 90+'].iloc[-1] + df['Bristol Dead 90+'].iloc[-1]
    Total019 = df['London Total 0-19'].iloc[-1] + df['Birmingham Total 0-19'].iloc[-1] + df['Leeds Total 0-19'].iloc[-1]\
    + df['Sheffield Total 0-19'].iloc[-1] + df['Manchester Total 0-19'].iloc[-1] + df['Bradford Total 0-19'].iloc[-1]\
    + df['Liverpool Total 0-19'].iloc[-1] + df['Bristol Total 0-19'].iloc[-1]
    Total2029 = df['London Total 20-29'].iloc[-1] + df['Birmingham Total 20-29'].iloc[-1] + df['Leeds Total 20-29'].iloc[-1]\
    + df['Sheffield Total 20-29'].iloc[-1] + df['Manchester Total 20-29'].iloc[-1] + df['Bradford Total 20-29'].iloc[-1]\
    + df['Liverpool Total 20-29'].iloc[-1] + df['Bristol Total 20-29'].iloc[-1]
    Total3039 = df['London Total 30-39'].iloc[-1] + df['Birmingham Total 30-39'].iloc[-1] + df['Leeds Total 30-39'].iloc[-1]\
    + df['Sheffield Total 30-39'].iloc[-1] + df['Manchester Total 30-39'].iloc[-1] + df['Bradford Total 30-39'].iloc[-1]\
    + df['Liverpool Total 30-39'].iloc[-1] + df['Bristol Total 30-39'].iloc[-1]
    Total4049 = df['London Total 40-49'].iloc[-1] + df['Birmingham Total 40-49'].iloc[-1] + df['Leeds Total 40-49'].iloc[-1]\
    + df['Sheffield Total 40-49'].iloc[-1] + df['Manchester Total 40-49'].iloc[-1] + df['Bradford Total 40-49'].iloc[-1]\
    + df['Liverpool Total 40-49'].iloc[-1] + df['Bristol Total 40-49'].iloc[-1]
    Total5059 = df['London Total 50-59'].iloc[-1] + df['Birmingham Total 50-59'].iloc[-1] + df['Leeds Total 50-59'].iloc[-1]\
    + df['Sheffield Total 50-59'].iloc[-1] + df['Manchester Total 50-59'].iloc[-1] + df['Bradford Total 50-59'].iloc[-1]\
    + df['Liverpool Total 50-59'].iloc[-1] + df['Bristol Total 50-59'].iloc[-1]
    Total6069 = df['London Total 60-69'].iloc[-1] + df['Birmingham Total 60-69'].iloc[-1] + df['Leeds Total 60-69'].iloc[-1]\
    + df['Sheffield Total 60-69'].iloc[-1] + df['Manchester Total 60-69'].iloc[-1] + df['Bradford Total 60-69'].iloc[-1]\
    + df['Liverpool Total 60-69'].iloc[-1] + df['Bristol Total 60-69'].iloc[-1]
    Total7079 = df['London Total 70-79'].iloc[-1] + df['Birmingham Total 70-79'].iloc[-1] + df['Leeds Total 70-79'].iloc[-1]\
    + df['Sheffield Total 70-79'].iloc[-1] + df['Manchester Total 70-79'].iloc[-1] + df['Bradford Total 70-79'].iloc[-1]\
    + df['Liverpool Total 70-79'].iloc[-1] + df['Bristol Total 70-79'].iloc[-1]
    Total8089 = df['London Total 80-89'].iloc[-1] + df['Birmingham Total 80-89'].iloc[-1] + df['Leeds Total 80-89'].iloc[-1]\
    + df['Sheffield Total 80-89'].iloc[-1] + df['Manchester Total 80-89'].iloc[-1] + df['Bradford Total 80-89'].iloc[-1]\
    + df['Liverpool Total 80-89'].iloc[-1] + df['Bristol Total 80-89'].iloc[-1]
    Total90 = df['London Total 90+'].iloc[-1] + df['Birmingham Total 90+'].iloc[-1] + df['Leeds Total 90+'].iloc[-1]\
    + df['Sheffield Total 90+'].iloc[-1] + df['Manchester Total 90+'].iloc[-1] + df['Bradford Total 90+'].iloc[-1]\
    + df['Liverpool Total 90+'].iloc[-1] + df['Bristol Total 90+'].iloc[-1]
    Ilift = df.loc[1050]['I']
    TotCas = df['Total Cases'].iloc[-1]
    TotalCases.append(TotCas)
    Dead.append(dead)
    IPeak.append(Imax)
    PeakTime.append(time)
    Dead019.append(dead019)
    Dead2029.append(dead2029)
    Dead3039.append(dead3039) 
    Dead4049.append(dead4049) 
    Dead5059.append(dead5059) 
    Dead6069.append(dead6069) 
    Dead7079.append(dead7079) 
    Dead8089.append(dead8089) 
    Dead90.append(dead90)
    ILifting.append(Ilift)
print(np.mean(IPeak),u"\u00B1",np.std(IPeak))
print(np.mean(PeakTime),u"\u00B1",np.std(PeakTime))  
print(np.mean(Dead),u"\u00B1",np.std(Dead))
print(np.mean(Dead019),u"\u00B1",np.std(Dead019))
print(np.mean(Dead2029),u"\u00B1",np.std(Dead2029))
print(np.mean(Dead3039),u"\u00B1",np.std(Dead3039))
print(np.mean(Dead4049),u"\u00B1",np.std(Dead4049))
print(np.mean(Dead5059),u"\u00B1",np.std(Dead5059))
print(np.mean(Dead6069),u"\u00B1",np.std(Dead6069))
print(np.mean(Dead7079),u"\u00B1",np.std(Dead7079))
print(np.mean(Dead8089),u"\u00B1",np.std(Dead8089))
print(np.mean(Dead90),u"\u00B1",np.std(Dead90))
print(np.mean(ILifting),u"\u00B1",np.std(ILifting))
IPeak_PCO_325 = np.mean(IPeak)
PeakTime_PCO_325 = np.mean(PeakTime)
Dead_PCO_325 = np.mean(Dead)
Dead019_PCO_325 = np.mean(Dead019)
Dead2029_PCO_325 = np.mean(Dead2029)
Dead3039_PCO_325 = np.mean(Dead3039)
Dead4049_PCO_325 = np.mean(Dead4049)
Dead5059_PCO_325 = np.mean(Dead5059)
Dead6069_PCO_325 = np.mean(Dead6069)
Dead7079_PCO_325 = np.mean(Dead7079)
Dead8089_PCO_325 = np.mean(Dead8089)
Dead90_PCO_325 = np.mean(Dead90)
ILifting_PCO_325 = np.mean(ILifting)
IPeak_PCO_325_Err = np.std(IPeak)
PeakTime_PCO_325_Err = np.std(PeakTime)
Dead_PCO_325_Err = np.std(Dead)
Dead019_PCO_325_Err = np.std(Dead019)
Dead2029_PCO_325_Err = np.std(Dead2029)
Dead3039_PCO_325_Err = np.std(Dead3039)
Dead4049_PCO_325_Err = np.std(Dead4049)
Dead5059_PCO_325_Err = np.std(Dead5059)
Dead6069_PCO_325_Err = np.std(Dead6069)
Dead7079_PCO_325_Err = np.std(Dead7079)
Dead8089_PCO_325_Err = np.std(Dead8089)
Dead90_PCO_325_Err = np.std(Dead90)
ILifting_PCO_325_Err = np.std(ILifting)
PeakTimeArray_PCO_325 = PeakTime
TotalCases_PCO_325 = np.mean(TotalCases)
TotalCases_PCO_325_Err = np.std(TotalCases)
Total019_PCO_325 = np.mean(Total019)
Total2029_PCO_325 = np.mean(Total2029)
Total3039_PCO_325 = np.mean(Total3039)
Total4049_PCO_325 = np.mean(Total4049)
Total5059_PCO_325 = np.mean(Total5059)
Total6069_PCO_325 = np.mean(Total6069)
Total7079_PCO_325 = np.mean(Total7079)
Total8089_PCO_325 = np.mean(Total8089)
Total90_PCO_325 = np.mean(Total90)
Total019_PCO_325_Err = np.std(Total019)
Total2029_PCO_325_Err = np.std(Total2029)
Total3039_PCO_325_Err = np.std(Total3039)
Total4049_PCO_325_Err = np.std(Total4049)
Total5059_PCO_325_Err = np.std(Total5059)
Total6069_PCO_325_Err = np.std(Total6069)
Total7079_PCO_325_Err = np.std(Total7079)
Total8089_PCO_325_Err = np.std(Total8089)
Total90_PCO_325_Err = np.std(Total90)
# Out:
# 2703150.42 ± 18697.336273480243
# 72.292 ± 1.845138477188095
# 164732.59 ± 460.65368977139434
# 509.79 ± 21.91177537307281
# 705.32 ± 28.360846249715472
# 2756.6 ± 54.814596596162225
# 8733.1 ± 93.6621054642698
# 21089.65 ± 136.75762318788668
# 37622.7 ± 195.31623076436836
# 47160.51 ± 230.9834840416085
# 36659.25 ± 165.16200380232738
# 9495.67 ± 89.7845259496312
# 286593.96 ± 55368.65700663508

# %%
#PopnControl R = 3
IPeak = []
PeakTime = []
Dead = []
Dead019 = []
Dead2029 = []
Dead3039 = []
Dead4049 = []
Dead5059 = []
Dead6069 = []
Dead7079 = []
Dead8089 = []
Dead90 = []
ILifting = []
TotalCases = []
Total019 = []
Total2029 = []
Total3039 = []
Total4049 = []
Total5059 = []
Total6069 = []
Total7079 = []
Total8089 = []
Total90 = []
z = 1.960
for i in range(1,101):
    df = pd.read_csv (r'E:\Users\Michael\Project Notebook\Sim Data\PopnControl\3\PopnControl_R3_{}.csv'.format(i))
    Imax = pd.DataFrame.max(df['I'])
    time = pd.DataFrame.max(df.loc[df['I'] == Imax]['t'])
    dead = df['D'].iloc[-1]
    dead019 = df['London Dead 0-19'].iloc[-1] + df['Birmingham Dead 0-19'].iloc[-1] + df['Leeds Dead 0-19'].iloc[-1]\
    + df['Sheffield Dead 0-19'].iloc[-1] + df['Manchester Dead 0-19'].iloc[-1] + df['Bradford Dead 0-19'].iloc[-1]\
    + df['Liverpool Dead 0-19'].iloc[-1] + df['Bristol Dead 0-19'].iloc[-1]
    dead2029 = df['London Dead 20-29'].iloc[-1] + df['Birmingham Dead 20-29'].iloc[-1] + df['Leeds Dead 20-29'].iloc[-1]\
    + df['Sheffield Dead 20-29'].iloc[-1] + df['Manchester Dead 20-29'].iloc[-1] + df['Bradford Dead 20-29'].iloc[-1]\
    + df['Liverpool Dead 20-29'].iloc[-1] + df['Bristol Dead 20-29'].iloc[-1]
    dead3039 = df['London Dead 30-39'].iloc[-1] + df['Birmingham Dead 30-39'].iloc[-1] + df['Leeds Dead 30-39'].iloc[-1]\
    + df['Sheffield Dead 30-39'].iloc[-1] + df['Manchester Dead 30-39'].iloc[-1] + df['Bradford Dead 30-39'].iloc[-1]\
    + df['Liverpool Dead 30-39'].iloc[-1] + df['Bristol Dead 30-39'].iloc[-1]
    dead4049 = df['London Dead 40-49'].iloc[-1] + df['Birmingham Dead 40-49'].iloc[-1] + df['Leeds Dead 40-49'].iloc[-1]\
    + df['Sheffield Dead 40-49'].iloc[-1] + df['Manchester Dead 40-49'].iloc[-1] + df['Bradford Dead 40-49'].iloc[-1]\
    + df['Liverpool Dead 40-49'].iloc[-1] + df['Bristol Dead 40-49'].iloc[-1]
    dead5059 = df['London Dead 50-59'].iloc[-1] + df['Birmingham Dead 50-59'].iloc[-1] + df['Leeds Dead 50-59'].iloc[-1]\
    + df['Sheffield Dead 50-59'].iloc[-1] + df['Manchester Dead 50-59'].iloc[-1] + df['Bradford Dead 50-59'].iloc[-1]\
    + df['Liverpool Dead 50-59'].iloc[-1] + df['Bristol Dead 50-59'].iloc[-1]
    dead6069 = df['London Dead 60-69'].iloc[-1] + df['Birmingham Dead 60-69'].iloc[-1] + df['Leeds Dead 60-69'].iloc[-1]\
    + df['Sheffield Dead 60-69'].iloc[-1] + df['Manchester Dead 60-69'].iloc[-1] + df['Bradford Dead 60-69'].iloc[-1]\
    + df['Liverpool Dead 60-69'].iloc[-1] + df['Bristol Dead 60-69'].iloc[-1]
    dead7079 = df['London Dead 70-79'].iloc[-1] + df['Birmingham Dead 70-79'].iloc[-1] + df['Leeds Dead 70-79'].iloc[-1]\
    + df['Sheffield Dead 70-79'].iloc[-1] + df['Manchester Dead 70-79'].iloc[-1] + df['Bradford Dead 70-79'].iloc[-1]\
    + df['Liverpool Dead 70-79'].iloc[-1] + df['Bristol Dead 70-79'].iloc[-1]
    dead8089 = df['London Dead 80-89'].iloc[-1] + df['Birmingham Dead 80-89'].iloc[-1] + df['Leeds Dead 80-89'].iloc[-1]\
    + df['Sheffield Dead 80-89'].iloc[-1] + df['Manchester Dead 80-89'].iloc[-1] + df['Bradford Dead 80-89'].iloc[-1]\
    + df['Liverpool Dead 80-89'].iloc[-1] + df['Bristol Dead 80-89'].iloc[-1]
    dead90 = df['London Dead 90+'].iloc[-1] + df['Birmingham Dead 90+'].iloc[-1] + df['Leeds Dead 90+'].iloc[-1]\
    + df['Sheffield Dead 90+'].iloc[-1] + df['Manchester Dead 90+'].iloc[-1] + df['Bradford Dead 90+'].iloc[-1]\
    + df['Liverpool Dead 90+'].iloc[-1] + df['Bristol Dead 90+'].iloc[-1]
    Total019 = df['London Total 0-19'].iloc[-1] + df['Birmingham Total 0-19'].iloc[-1] + df['Leeds Total 0-19'].iloc[-1]\
    + df['Sheffield Total 0-19'].iloc[-1] + df['Manchester Total 0-19'].iloc[-1] + df['Bradford Total 0-19'].iloc[-1]\
    + df['Liverpool Total 0-19'].iloc[-1] + df['Bristol Total 0-19'].iloc[-1]
    Total2029 = df['London Total 20-29'].iloc[-1] + df['Birmingham Total 20-29'].iloc[-1] + df['Leeds Total 20-29'].iloc[-1]\
    + df['Sheffield Total 20-29'].iloc[-1] + df['Manchester Total 20-29'].iloc[-1] + df['Bradford Total 20-29'].iloc[-1]\
    + df['Liverpool Total 20-29'].iloc[-1] + df['Bristol Total 20-29'].iloc[-1]
    Total3039 = df['London Total 30-39'].iloc[-1] + df['Birmingham Total 30-39'].iloc[-1] + df['Leeds Total 30-39'].iloc[-1]\
    + df['Sheffield Total 30-39'].iloc[-1] + df['Manchester Total 30-39'].iloc[-1] + df['Bradford Total 30-39'].iloc[-1]\
    + df['Liverpool Total 30-39'].iloc[-1] + df['Bristol Total 30-39'].iloc[-1]
    Total4049 = df['London Total 40-49'].iloc[-1] + df['Birmingham Total 40-49'].iloc[-1] + df['Leeds Total 40-49'].iloc[-1]\
    + df['Sheffield Total 40-49'].iloc[-1] + df['Manchester Total 40-49'].iloc[-1] + df['Bradford Total 40-49'].iloc[-1]\
    + df['Liverpool Total 40-49'].iloc[-1] + df['Bristol Total 40-49'].iloc[-1]
    Total5059 = df['London Total 50-59'].iloc[-1] + df['Birmingham Total 50-59'].iloc[-1] + df['Leeds Total 50-59'].iloc[-1]\
    + df['Sheffield Total 50-59'].iloc[-1] + df['Manchester Total 50-59'].iloc[-1] + df['Bradford Total 50-59'].iloc[-1]\
    + df['Liverpool Total 50-59'].iloc[-1] + df['Bristol Total 50-59'].iloc[-1]
    Total6069 = df['London Total 60-69'].iloc[-1] + df['Birmingham Total 60-69'].iloc[-1] + df['Leeds Total 60-69'].iloc[-1]\
    + df['Sheffield Total 60-69'].iloc[-1] + df['Manchester Total 60-69'].iloc[-1] + df['Bradford Total 60-69'].iloc[-1]\
    + df['Liverpool Total 60-69'].iloc[-1] + df['Bristol Total 60-69'].iloc[-1]
    Total7079 = df['London Total 70-79'].iloc[-1] + df['Birmingham Total 70-79'].iloc[-1] + df['Leeds Total 70-79'].iloc[-1]\
    + df['Sheffield Total 70-79'].iloc[-1] + df['Manchester Total 70-79'].iloc[-1] + df['Bradford Total 70-79'].iloc[-1]\
    + df['Liverpool Total 70-79'].iloc[-1] + df['Bristol Total 70-79'].iloc[-1]
    Total8089 = df['London Total 80-89'].iloc[-1] + df['Birmingham Total 80-89'].iloc[-1] + df['Leeds Total 80-89'].iloc[-1]\
    + df['Sheffield Total 80-89'].iloc[-1] + df['Manchester Total 80-89'].iloc[-1] + df['Bradford Total 80-89'].iloc[-1]\
    + df['Liverpool Total 80-89'].iloc[-1] + df['Bristol Total 80-89'].iloc[-1]
    Total90 = df['London Total 90+'].iloc[-1] + df['Birmingham Total 90+'].iloc[-1] + df['Leeds Total 90+'].iloc[-1]\
    + df['Sheffield Total 90+'].iloc[-1] + df['Manchester Total 90+'].iloc[-1] + df['Bradford Total 90+'].iloc[-1]\
    + df['Liverpool Total 90+'].iloc[-1] + df['Bristol Total 90+'].iloc[-1]
    Ilift = df.loc[1050]['I']
    TotCas = df['Total Cases'].iloc[-1]
    TotalCases.append(TotCas)
    Dead.append(dead)
    IPeak.append(Imax)
    PeakTime.append(time)
    Dead019.append(dead019)
    Dead2029.append(dead2029)
    Dead3039.append(dead3039) 
    Dead4049.append(dead4049) 
    Dead5059.append(dead5059) 
    Dead6069.append(dead6069) 
    Dead7079.append(dead7079) 
    Dead8089.append(dead8089) 
    Dead90.append(dead90)
    ILifting.append(Ilift)
print(np.mean(IPeak),u"\u00B1",np.std(IPeak))
print(np.mean(PeakTime),u"\u00B1",np.std(PeakTime))  
print(np.mean(Dead),u"\u00B1",np.std(Dead))
print(np.mean(Dead019),u"\u00B1",np.std(Dead019))
print(np.mean(Dead2029),u"\u00B1",np.std(Dead2029))
print(np.mean(Dead3039),u"\u00B1",np.std(Dead3039))
print(np.mean(Dead4049),u"\u00B1",np.std(Dead4049))
print(np.mean(Dead5059),u"\u00B1",np.std(Dead5059))
print(np.mean(Dead6069),u"\u00B1",np.std(Dead6069))
print(np.mean(Dead7079),u"\u00B1",np.std(Dead7079))
print(np.mean(Dead8089),u"\u00B1",np.std(Dead8089))
print(np.mean(Dead90),u"\u00B1",np.std(Dead90))
print(np.mean(ILifting),u"\u00B1",np.std(ILifting))
IPeak_PCO_3 = np.mean(IPeak)
PeakTime_PCO_3 = np.mean(PeakTime)
Dead_PCO_3 = np.mean(Dead)
Dead019_PCO_3 = np.mean(Dead019)
Dead2029_PCO_3 = np.mean(Dead2029)
Dead3039_PCO_3 = np.mean(Dead3039)
Dead4049_PCO_3 = np.mean(Dead4049)
Dead5059_PCO_3 = np.mean(Dead5059)
Dead6069_PCO_3 = np.mean(Dead6069)
Dead7079_PCO_3 = np.mean(Dead7079)
Dead8089_PCO_3 = np.mean(Dead8089)
Dead90_PCO_3 = np.mean(Dead90)
ILifting_PCO_3 = np.mean(ILifting)
IPeak_PCO_3_Err = np.std(IPeak)
PeakTime_PCO_3_Err = np.std(PeakTime)
Dead_PCO_3_Err = np.std(Dead)
Dead019_PCO_3_Err = np.std(Dead019)
Dead2029_PCO_3_Err = np.std(Dead2029)
Dead3039_PCO_3_Err = np.std(Dead3039)
Dead4049_PCO_3_Err = np.std(Dead4049)
Dead5059_PCO_3_Err = np.std(Dead5059)
Dead6069_PCO_3_Err = np.std(Dead6069)
Dead7079_PCO_3_Err = np.std(Dead7079)
Dead8089_PCO_3_Err = np.std(Dead8089)
Dead90_PCO_3_Err = np.std(Dead90)
ILifting_PCO_3_Err = np.std(ILifting)
PeakTimeArray_PCO_3 = PeakTime
TotalCases_PCO_3 = np.mean(TotalCases)
TotalCases_PCO_3_Err = np.std(TotalCases)
Total019_PCO_3 = np.mean(Total019)
Total2029_PCO_3 = np.mean(Total2029)
Total3039_PCO_3 = np.mean(Total3039)
Total4049_PCO_3 = np.mean(Total4049)
Total5059_PCO_3 = np.mean(Total5059)
Total6069_PCO_3 = np.mean(Total6069)
Total7079_PCO_3 = np.mean(Total7079)
Total8089_PCO_3 = np.mean(Total8089)
Total90_PCO_3 = np.mean(Total90)
Total019_PCO_3_Err = np.std(Total019)
Total2029_PCO_3_Err = np.std(Total2029)
Total3039_PCO_3_Err = np.std(Total3039)
Total4049_PCO_3_Err = np.std(Total4049)
Total5059_PCO_3_Err = np.std(Total5059)
Total6069_PCO_3_Err = np.std(Total6069)
Total7079_PCO_3_Err = np.std(Total7079)
Total8089_PCO_3_Err = np.std(Total8089)
Total90_PCO_3_Err = np.std(Total90)
# Out:
# 2474591.59 ± 18397.26378464743
# 79.54900000000002 ± 1.729710669447351
# 154336.61 ± 390.8050382223853
# 498.89 ± 20.51872072035681
# 695.28 ± 25.644133832126208
# 2739.63 ± 56.57095632919777
# 8652.6 ± 90.4695528893561
# 20405.56 ± 151.1916876021959
# 35320.76 ± 195.11402409873054
# 43478.13 ± 202.23548921986963
# 33783.13 ± 166.8957551886806
# 8762.63 ± 94.18764834095816
# 589440.24 ± 89860.15225895403

# %%
#PopnControl R = 2.75
IPeak = []
PeakTime = []
Dead = []
Dead019 = []
Dead2029 = []
Dead3039 = []
Dead4049 = []
Dead5059 = []
Dead6069 = []
Dead7079 = []
Dead8089 = []
Dead90 = []
ILifting = []
TotalCases = []
Total019 = []
Total2029 = []
Total3039 = []
Total4049 = []
Total5059 = []
Total6069 = []
Total7079 = []
Total8089 = []
Total90 = []
z = 1.960
for i in range(1,101):
    df = pd.read_csv (r'E:\Users\Michael\Project Notebook\Sim Data\PopnControl\2.75\PopnControl_R2.75_{}.csv'.format(i))
    Imax = pd.DataFrame.max(df['I'])
    time = pd.DataFrame.max(df.loc[df['I'] == Imax]['t'])
    dead = df['D'].iloc[-1]
    dead019 = df['London Dead 0-19'].iloc[-1] + df['Birmingham Dead 0-19'].iloc[-1] + df['Leeds Dead 0-19'].iloc[-1]\
    + df['Sheffield Dead 0-19'].iloc[-1] + df['Manchester Dead 0-19'].iloc[-1] + df['Bradford Dead 0-19'].iloc[-1]\
    + df['Liverpool Dead 0-19'].iloc[-1] + df['Bristol Dead 0-19'].iloc[-1]
    dead2029 = df['London Dead 20-29'].iloc[-1] + df['Birmingham Dead 20-29'].iloc[-1] + df['Leeds Dead 20-29'].iloc[-1]\
    + df['Sheffield Dead 20-29'].iloc[-1] + df['Manchester Dead 20-29'].iloc[-1] + df['Bradford Dead 20-29'].iloc[-1]\
    + df['Liverpool Dead 20-29'].iloc[-1] + df['Bristol Dead 20-29'].iloc[-1]
    dead3039 = df['London Dead 30-39'].iloc[-1] + df['Birmingham Dead 30-39'].iloc[-1] + df['Leeds Dead 30-39'].iloc[-1]\
    + df['Sheffield Dead 30-39'].iloc[-1] + df['Manchester Dead 30-39'].iloc[-1] + df['Bradford Dead 30-39'].iloc[-1]\
    + df['Liverpool Dead 30-39'].iloc[-1] + df['Bristol Dead 30-39'].iloc[-1]
    dead4049 = df['London Dead 40-49'].iloc[-1] + df['Birmingham Dead 40-49'].iloc[-1] + df['Leeds Dead 40-49'].iloc[-1]\
    + df['Sheffield Dead 40-49'].iloc[-1] + df['Manchester Dead 40-49'].iloc[-1] + df['Bradford Dead 40-49'].iloc[-1]\
    + df['Liverpool Dead 40-49'].iloc[-1] + df['Bristol Dead 40-49'].iloc[-1]
    dead5059 = df['London Dead 50-59'].iloc[-1] + df['Birmingham Dead 50-59'].iloc[-1] + df['Leeds Dead 50-59'].iloc[-1]\
    + df['Sheffield Dead 50-59'].iloc[-1] + df['Manchester Dead 50-59'].iloc[-1] + df['Bradford Dead 50-59'].iloc[-1]\
    + df['Liverpool Dead 50-59'].iloc[-1] + df['Bristol Dead 50-59'].iloc[-1]
    dead6069 = df['London Dead 60-69'].iloc[-1] + df['Birmingham Dead 60-69'].iloc[-1] + df['Leeds Dead 60-69'].iloc[-1]\
    + df['Sheffield Dead 60-69'].iloc[-1] + df['Manchester Dead 60-69'].iloc[-1] + df['Bradford Dead 60-69'].iloc[-1]\
    + df['Liverpool Dead 60-69'].iloc[-1] + df['Bristol Dead 60-69'].iloc[-1]
    dead7079 = df['London Dead 70-79'].iloc[-1] + df['Birmingham Dead 70-79'].iloc[-1] + df['Leeds Dead 70-79'].iloc[-1]\
    + df['Sheffield Dead 70-79'].iloc[-1] + df['Manchester Dead 70-79'].iloc[-1] + df['Bradford Dead 70-79'].iloc[-1]\
    + df['Liverpool Dead 70-79'].iloc[-1] + df['Bristol Dead 70-79'].iloc[-1]
    dead8089 = df['London Dead 80-89'].iloc[-1] + df['Birmingham Dead 80-89'].iloc[-1] + df['Leeds Dead 80-89'].iloc[-1]\
    + df['Sheffield Dead 80-89'].iloc[-1] + df['Manchester Dead 80-89'].iloc[-1] + df['Bradford Dead 80-89'].iloc[-1]\
    + df['Liverpool Dead 80-89'].iloc[-1] + df['Bristol Dead 80-89'].iloc[-1]
    dead90 = df['London Dead 90+'].iloc[-1] + df['Birmingham Dead 90+'].iloc[-1] + df['Leeds Dead 90+'].iloc[-1]\
    + df['Sheffield Dead 90+'].iloc[-1] + df['Manchester Dead 90+'].iloc[-1] + df['Bradford Dead 90+'].iloc[-1]\
    + df['Liverpool Dead 90+'].iloc[-1] + df['Bristol Dead 90+'].iloc[-1]
    Total019 = df['London Total 0-19'].iloc[-1] + df['Birmingham Total 0-19'].iloc[-1] + df['Leeds Total 0-19'].iloc[-1]\
    + df['Sheffield Total 0-19'].iloc[-1] + df['Manchester Total 0-19'].iloc[-1] + df['Bradford Total 0-19'].iloc[-1]\
    + df['Liverpool Total 0-19'].iloc[-1] + df['Bristol Total 0-19'].iloc[-1]
    Total2029 = df['London Total 20-29'].iloc[-1] + df['Birmingham Total 20-29'].iloc[-1] + df['Leeds Total 20-29'].iloc[-1]\
    + df['Sheffield Total 20-29'].iloc[-1] + df['Manchester Total 20-29'].iloc[-1] + df['Bradford Total 20-29'].iloc[-1]\
    + df['Liverpool Total 20-29'].iloc[-1] + df['Bristol Total 20-29'].iloc[-1]
    Total3039 = df['London Total 30-39'].iloc[-1] + df['Birmingham Total 30-39'].iloc[-1] + df['Leeds Total 30-39'].iloc[-1]\
    + df['Sheffield Total 30-39'].iloc[-1] + df['Manchester Total 30-39'].iloc[-1] + df['Bradford Total 30-39'].iloc[-1]\
    + df['Liverpool Total 30-39'].iloc[-1] + df['Bristol Total 30-39'].iloc[-1]
    Total4049 = df['London Total 40-49'].iloc[-1] + df['Birmingham Total 40-49'].iloc[-1] + df['Leeds Total 40-49'].iloc[-1]\
    + df['Sheffield Total 40-49'].iloc[-1] + df['Manchester Total 40-49'].iloc[-1] + df['Bradford Total 40-49'].iloc[-1]\
    + df['Liverpool Total 40-49'].iloc[-1] + df['Bristol Total 40-49'].iloc[-1]
    Total5059 = df['London Total 50-59'].iloc[-1] + df['Birmingham Total 50-59'].iloc[-1] + df['Leeds Total 50-59'].iloc[-1]\
    + df['Sheffield Total 50-59'].iloc[-1] + df['Manchester Total 50-59'].iloc[-1] + df['Bradford Total 50-59'].iloc[-1]\
    + df['Liverpool Total 50-59'].iloc[-1] + df['Bristol Total 50-59'].iloc[-1]
    Total6069 = df['London Total 60-69'].iloc[-1] + df['Birmingham Total 60-69'].iloc[-1] + df['Leeds Total 60-69'].iloc[-1]\
    + df['Sheffield Total 60-69'].iloc[-1] + df['Manchester Total 60-69'].iloc[-1] + df['Bradford Total 60-69'].iloc[-1]\
    + df['Liverpool Total 60-69'].iloc[-1] + df['Bristol Total 60-69'].iloc[-1]
    Total7079 = df['London Total 70-79'].iloc[-1] + df['Birmingham Total 70-79'].iloc[-1] + df['Leeds Total 70-79'].iloc[-1]\
    + df['Sheffield Total 70-79'].iloc[-1] + df['Manchester Total 70-79'].iloc[-1] + df['Bradford Total 70-79'].iloc[-1]\
    + df['Liverpool Total 70-79'].iloc[-1] + df['Bristol Total 70-79'].iloc[-1]
    Total8089 = df['London Total 80-89'].iloc[-1] + df['Birmingham Total 80-89'].iloc[-1] + df['Leeds Total 80-89'].iloc[-1]\
    + df['Sheffield Total 80-89'].iloc[-1] + df['Manchester Total 80-89'].iloc[-1] + df['Bradford Total 80-89'].iloc[-1]\
    + df['Liverpool Total 80-89'].iloc[-1] + df['Bristol Total 80-89'].iloc[-1]
    Total90 = df['London Total 90+'].iloc[-1] + df['Birmingham Total 90+'].iloc[-1] + df['Leeds Total 90+'].iloc[-1]\
    + df['Sheffield Total 90+'].iloc[-1] + df['Manchester Total 90+'].iloc[-1] + df['Bradford Total 90+'].iloc[-1]\
    + df['Liverpool Total 90+'].iloc[-1] + df['Bristol Total 90+'].iloc[-1]
    Ilift = df.loc[1050]['I']
    TotCas = df['Total Cases'].iloc[-1]
    TotalCases.append(TotCas)
    Dead.append(dead)
    IPeak.append(Imax)
    PeakTime.append(time)
    Dead019.append(dead019)
    Dead2029.append(dead2029)
    Dead3039.append(dead3039) 
    Dead4049.append(dead4049) 
    Dead5059.append(dead5059) 
    Dead6069.append(dead6069) 
    Dead7079.append(dead7079) 
    Dead8089.append(dead8089) 
    Dead90.append(dead90)
    ILifting.append(Ilift)
print(np.mean(IPeak),u"\u00B1",np.std(IPeak))
print(np.mean(PeakTime),u"\u00B1",np.std(PeakTime))  
print(np.mean(Dead),u"\u00B1",np.std(Dead))
print(np.mean(Dead019),u"\u00B1",np.std(Dead019))
print(np.mean(Dead2029),u"\u00B1",np.std(Dead2029))
print(np.mean(Dead3039),u"\u00B1",np.std(Dead3039))
print(np.mean(Dead4049),u"\u00B1",np.std(Dead4049))
print(np.mean(Dead5059),u"\u00B1",np.std(Dead5059))
print(np.mean(Dead6069),u"\u00B1",np.std(Dead6069))
print(np.mean(Dead7079),u"\u00B1",np.std(Dead7079))
print(np.mean(Dead8089),u"\u00B1",np.std(Dead8089))
print(np.mean(Dead90),u"\u00B1",np.std(Dead90))
print(np.mean(ILifting),u"\u00B1",np.std(ILifting))
IPeak_PCO_275 = np.mean(IPeak)
PeakTime_PCO_275 = np.mean(PeakTime)
Dead_PCO_275 = np.mean(Dead)
Dead019_PCO_275 = np.mean(Dead019)
Dead2029_PCO_275 = np.mean(Dead2029)
Dead3039_PCO_275 = np.mean(Dead3039)
Dead4049_PCO_275 = np.mean(Dead4049)
Dead5059_PCO_275 = np.mean(Dead5059)
Dead6069_PCO_275 = np.mean(Dead6069)
Dead7079_PCO_275 = np.mean(Dead7079)
Dead8089_PCO_275 = np.mean(Dead8089)
Dead90_PCO_275 = np.mean(Dead90)
ILifting_PCO_275 = np.mean(ILifting)
IPeak_PCO_275_Err = np.std(IPeak)
PeakTime_PCO_275_Err = np.std(PeakTime)
Dead_PCO_275_Err = np.std(Dead)
Dead019_PCO_275_Err = np.std(Dead019)
Dead2029_PCO_275_Err = np.std(Dead2029)
Dead3039_PCO_275_Err = np.std(Dead3039)
Dead4049_PCO_275_Err = np.std(Dead4049)
Dead5059_PCO_275_Err = np.std(Dead5059)
Dead6069_PCO_275_Err = np.std(Dead6069)
Dead7079_PCO_275_Err = np.std(Dead7079)
Dead8089_PCO_275_Err = np.std(Dead8089)
Dead90_PCO_275_Err = np.std(Dead90)
ILifting_PCO_275_Err = np.std(ILifting)
PeakTimeArray_PCO_275 = PeakTime
TotalCases_PCO_275 = np.mean(TotalCases)
TotalCases_PCO_275_Err = np.std(TotalCases)
Total019_PCO_275 = np.mean(Total019)
Total2029_PCO_275 = np.mean(Total2029)
Total3039_PCO_275 = np.mean(Total3039)
Total4049_PCO_275 = np.mean(Total4049)
Total5059_PCO_275 = np.mean(Total5059)
Total6069_PCO_275 = np.mean(Total6069)
Total7079_PCO_275 = np.mean(Total7079)
Total8089_PCO_275 = np.mean(Total8089)
Total90_PCO_275 = np.mean(Total90)
Total019_PCO_275_Err = np.std(Total019)
Total2029_PCO_275_Err = np.std(Total2029)
Total3039_PCO_275_Err = np.std(Total3039)
Total4049_PCO_275_Err = np.std(Total4049)
Total5059_PCO_275_Err = np.std(Total5059)
Total6069_PCO_275_Err = np.std(Total6069)
Total7079_PCO_275_Err = np.std(Total7079)
Total8089_PCO_275_Err = np.std(Total8089)
Total90_PCO_275_Err = np.std(Total90)
# Out:
# 2221346.77 ± 14590.69859592405
# 89.21400000000003 ± 2.225669337525227
# 142899.92 ± 368.6426095827773
# 489.7 ± 23.448027635602955
# 681.4 ± 24.580886883918566
# 2687.35 ± 46.240323312018475
# 8485.92 ± 95.8689397041607
# 19552.64 ± 123.5935694120046
# 32720.75 ± 172.87755059579018
# 39564.93 ± 224.49121385925108
# 30752.84 ± 172.8692407572845
# 7964.39 ± 76.18607418682235
# 1228803.0 ± 174036.16827309201

# %%
#PopnControl R = 2.5
IPeak = []
PeakTime = []
Dead = []
Dead019 = []
Dead2029 = []
Dead3039 = []
Dead4049 = []
Dead5059 = []
Dead6069 = []
Dead7079 = []
Dead8089 = []
Dead90 = []
ILifting = []
TotalCases = []
Total019 = []
Total2029 = []
Total3039 = []
Total4049 = []
Total5059 = []
Total6069 = []
Total7079 = []
Total8089 = []
Total90 = []
z = 1.960
for i in range(1,101):
    df = pd.read_csv (r'E:\Users\Michael\Project Notebook\Sim Data\PopnControl\2.5\PopnControl_R2.5_{}.csv'.format(i))
    Imax = pd.DataFrame.max(df['I'])
    time = pd.DataFrame.max(df.loc[df['I'] == Imax]['t'])
    dead = df['D'].iloc[-1]
    dead019 = df['London Dead 0-19'].iloc[-1] + df['Birmingham Dead 0-19'].iloc[-1] + df['Leeds Dead 0-19'].iloc[-1]\
    + df['Sheffield Dead 0-19'].iloc[-1] + df['Manchester Dead 0-19'].iloc[-1] + df['Bradford Dead 0-19'].iloc[-1]\
    + df['Liverpool Dead 0-19'].iloc[-1] + df['Bristol Dead 0-19'].iloc[-1]
    dead2029 = df['London Dead 20-29'].iloc[-1] + df['Birmingham Dead 20-29'].iloc[-1] + df['Leeds Dead 20-29'].iloc[-1]\
    + df['Sheffield Dead 20-29'].iloc[-1] + df['Manchester Dead 20-29'].iloc[-1] + df['Bradford Dead 20-29'].iloc[-1]\
    + df['Liverpool Dead 20-29'].iloc[-1] + df['Bristol Dead 20-29'].iloc[-1]
    dead3039 = df['London Dead 30-39'].iloc[-1] + df['Birmingham Dead 30-39'].iloc[-1] + df['Leeds Dead 30-39'].iloc[-1]\
    + df['Sheffield Dead 30-39'].iloc[-1] + df['Manchester Dead 30-39'].iloc[-1] + df['Bradford Dead 30-39'].iloc[-1]\
    + df['Liverpool Dead 30-39'].iloc[-1] + df['Bristol Dead 30-39'].iloc[-1]
    dead4049 = df['London Dead 40-49'].iloc[-1] + df['Birmingham Dead 40-49'].iloc[-1] + df['Leeds Dead 40-49'].iloc[-1]\
    + df['Sheffield Dead 40-49'].iloc[-1] + df['Manchester Dead 40-49'].iloc[-1] + df['Bradford Dead 40-49'].iloc[-1]\
    + df['Liverpool Dead 40-49'].iloc[-1] + df['Bristol Dead 40-49'].iloc[-1]
    dead5059 = df['London Dead 50-59'].iloc[-1] + df['Birmingham Dead 50-59'].iloc[-1] + df['Leeds Dead 50-59'].iloc[-1]\
    + df['Sheffield Dead 50-59'].iloc[-1] + df['Manchester Dead 50-59'].iloc[-1] + df['Bradford Dead 50-59'].iloc[-1]\
    + df['Liverpool Dead 50-59'].iloc[-1] + df['Bristol Dead 50-59'].iloc[-1]
    dead6069 = df['London Dead 60-69'].iloc[-1] + df['Birmingham Dead 60-69'].iloc[-1] + df['Leeds Dead 60-69'].iloc[-1]\
    + df['Sheffield Dead 60-69'].iloc[-1] + df['Manchester Dead 60-69'].iloc[-1] + df['Bradford Dead 60-69'].iloc[-1]\
    + df['Liverpool Dead 60-69'].iloc[-1] + df['Bristol Dead 60-69'].iloc[-1]
    dead7079 = df['London Dead 70-79'].iloc[-1] + df['Birmingham Dead 70-79'].iloc[-1] + df['Leeds Dead 70-79'].iloc[-1]\
    + df['Sheffield Dead 70-79'].iloc[-1] + df['Manchester Dead 70-79'].iloc[-1] + df['Bradford Dead 70-79'].iloc[-1]\
    + df['Liverpool Dead 70-79'].iloc[-1] + df['Bristol Dead 70-79'].iloc[-1]
    dead8089 = df['London Dead 80-89'].iloc[-1] + df['Birmingham Dead 80-89'].iloc[-1] + df['Leeds Dead 80-89'].iloc[-1]\
    + df['Sheffield Dead 80-89'].iloc[-1] + df['Manchester Dead 80-89'].iloc[-1] + df['Bradford Dead 80-89'].iloc[-1]\
    + df['Liverpool Dead 80-89'].iloc[-1] + df['Bristol Dead 80-89'].iloc[-1]
    dead90 = df['London Dead 90+'].iloc[-1] + df['Birmingham Dead 90+'].iloc[-1] + df['Leeds Dead 90+'].iloc[-1]\
    + df['Sheffield Dead 90+'].iloc[-1] + df['Manchester Dead 90+'].iloc[-1] + df['Bradford Dead 90+'].iloc[-1]\
    + df['Liverpool Dead 90+'].iloc[-1] + df['Bristol Dead 90+'].iloc[-1]
    Total019 = df['London Total 0-19'].iloc[-1] + df['Birmingham Total 0-19'].iloc[-1] + df['Leeds Total 0-19'].iloc[-1]\
    + df['Sheffield Total 0-19'].iloc[-1] + df['Manchester Total 0-19'].iloc[-1] + df['Bradford Total 0-19'].iloc[-1]\
    + df['Liverpool Total 0-19'].iloc[-1] + df['Bristol Total 0-19'].iloc[-1]
    Total2029 = df['London Total 20-29'].iloc[-1] + df['Birmingham Total 20-29'].iloc[-1] + df['Leeds Total 20-29'].iloc[-1]\
    + df['Sheffield Total 20-29'].iloc[-1] + df['Manchester Total 20-29'].iloc[-1] + df['Bradford Total 20-29'].iloc[-1]\
    + df['Liverpool Total 20-29'].iloc[-1] + df['Bristol Total 20-29'].iloc[-1]
    Total3039 = df['London Total 30-39'].iloc[-1] + df['Birmingham Total 30-39'].iloc[-1] + df['Leeds Total 30-39'].iloc[-1]\
    + df['Sheffield Total 30-39'].iloc[-1] + df['Manchester Total 30-39'].iloc[-1] + df['Bradford Total 30-39'].iloc[-1]\
    + df['Liverpool Total 30-39'].iloc[-1] + df['Bristol Total 30-39'].iloc[-1]
    Total4049 = df['London Total 40-49'].iloc[-1] + df['Birmingham Total 40-49'].iloc[-1] + df['Leeds Total 40-49'].iloc[-1]\
    + df['Sheffield Total 40-49'].iloc[-1] + df['Manchester Total 40-49'].iloc[-1] + df['Bradford Total 40-49'].iloc[-1]\
    + df['Liverpool Total 40-49'].iloc[-1] + df['Bristol Total 40-49'].iloc[-1]
    Total5059 = df['London Total 50-59'].iloc[-1] + df['Birmingham Total 50-59'].iloc[-1] + df['Leeds Total 50-59'].iloc[-1]\
    + df['Sheffield Total 50-59'].iloc[-1] + df['Manchester Total 50-59'].iloc[-1] + df['Bradford Total 50-59'].iloc[-1]\
    + df['Liverpool Total 50-59'].iloc[-1] + df['Bristol Total 50-59'].iloc[-1]
    Total6069 = df['London Total 60-69'].iloc[-1] + df['Birmingham Total 60-69'].iloc[-1] + df['Leeds Total 60-69'].iloc[-1]\
    + df['Sheffield Total 60-69'].iloc[-1] + df['Manchester Total 60-69'].iloc[-1] + df['Bradford Total 60-69'].iloc[-1]\
    + df['Liverpool Total 60-69'].iloc[-1] + df['Bristol Total 60-69'].iloc[-1]
    Total7079 = df['London Total 70-79'].iloc[-1] + df['Birmingham Total 70-79'].iloc[-1] + df['Leeds Total 70-79'].iloc[-1]\
    + df['Sheffield Total 70-79'].iloc[-1] + df['Manchester Total 70-79'].iloc[-1] + df['Bradford Total 70-79'].iloc[-1]\
    + df['Liverpool Total 70-79'].iloc[-1] + df['Bristol Total 70-79'].iloc[-1]
    Total8089 = df['London Total 80-89'].iloc[-1] + df['Birmingham Total 80-89'].iloc[-1] + df['Leeds Total 80-89'].iloc[-1]\
    + df['Sheffield Total 80-89'].iloc[-1] + df['Manchester Total 80-89'].iloc[-1] + df['Bradford Total 80-89'].iloc[-1]\
    + df['Liverpool Total 80-89'].iloc[-1] + df['Bristol Total 80-89'].iloc[-1]
    Total90 = df['London Total 90+'].iloc[-1] + df['Birmingham Total 90+'].iloc[-1] + df['Leeds Total 90+'].iloc[-1]\
    + df['Sheffield Total 90+'].iloc[-1] + df['Manchester Total 90+'].iloc[-1] + df['Bradford Total 90+'].iloc[-1]\
    + df['Liverpool Total 90+'].iloc[-1] + df['Bristol Total 90+'].iloc[-1]
    Ilift = df.loc[1050]['I']
    TotCas = df['Total Cases'].iloc[-1]
    TotalCases.append(TotCas)
    Dead.append(dead)
    IPeak.append(Imax)
    PeakTime.append(time)
    Dead019.append(dead019)
    Dead2029.append(dead2029)
    Dead3039.append(dead3039) 
    Dead4049.append(dead4049) 
    Dead5059.append(dead5059) 
    Dead6069.append(dead6069) 
    Dead7079.append(dead7079) 
    Dead8089.append(dead8089) 
    Dead90.append(dead90)
    ILifting.append(Ilift)
print(np.mean(IPeak),u"\u00B1",np.std(IPeak))
print(np.mean(PeakTime),u"\u00B1",np.std(PeakTime))  
print(np.mean(Dead),u"\u00B1",np.std(Dead))
print(np.mean(Dead019),u"\u00B1",np.std(Dead019))
print(np.mean(Dead2029),u"\u00B1",np.std(Dead2029))
print(np.mean(Dead3039),u"\u00B1",np.std(Dead3039))
print(np.mean(Dead4049),u"\u00B1",np.std(Dead4049))
print(np.mean(Dead5059),u"\u00B1",np.std(Dead5059))
print(np.mean(Dead6069),u"\u00B1",np.std(Dead6069))
print(np.mean(Dead7079),u"\u00B1",np.std(Dead7079))
print(np.mean(Dead8089),u"\u00B1",np.std(Dead8089))
print(np.mean(Dead90),u"\u00B1",np.std(Dead90))
print(np.mean(ILifting),u"\u00B1",np.std(ILifting))
IPeak_PCO_25 = np.mean(IPeak)
PeakTime_PCO_25 = np.mean(PeakTime)
Dead_PCO_25 = np.mean(Dead)
Dead019_PCO_25 = np.mean(Dead019)
Dead2029_PCO_25 = np.mean(Dead2029)
Dead3039_PCO_25 = np.mean(Dead3039)
Dead4049_PCO_25 = np.mean(Dead4049)
Dead5059_PCO_25 = np.mean(Dead5059)
Dead6069_PCO_25 = np.mean(Dead6069)
Dead7079_PCO_25 = np.mean(Dead7079)
Dead8089_PCO_25 = np.mean(Dead8089)
Dead90_PCO_25 = np.mean(Dead90)
ILifting_PCO_25 = np.mean(ILifting)
IPeak_PCO_25_Err = np.std(IPeak)
PeakTime_PCO_25_Err = np.std(PeakTime)
Dead_PCO_25_Err = np.std(Dead)
Dead019_PCO_25_Err = np.std(Dead019)
Dead2029_PCO_25_Err = np.std(Dead2029)
Dead3039_PCO_25_Err = np.std(Dead3039)
Dead4049_PCO_25_Err = np.std(Dead4049)
Dead5059_PCO_25_Err = np.std(Dead5059)
Dead6069_PCO_25_Err = np.std(Dead6069)
Dead7079_PCO_25_Err = np.std(Dead7079)
Dead8089_PCO_25_Err = np.std(Dead8089)
Dead90_PCO_25_Err = np.std(Dead90)
ILifting_PCO_25_Err = np.std(ILifting)
PeakTimeArray_PCO_25 = PeakTime
TotalCases_PCO_25 = np.mean(TotalCases)
TotalCases_PCO_25_Err = np.std(TotalCases)
Total019_PCO_25 = np.mean(Total019)
Total2029_PCO_25 = np.mean(Total2029)
Total3039_PCO_25 = np.mean(Total3039)
Total4049_PCO_25 = np.mean(Total4049)
Total5059_PCO_25 = np.mean(Total5059)
Total6069_PCO_25 = np.mean(Total6069)
Total7079_PCO_25 = np.mean(Total7079)
Total8089_PCO_25 = np.mean(Total8089)
Total90_PCO_25 = np.mean(Total90)
Total019_PCO_25_Err = np.std(Total019)
Total2029_PCO_25_Err = np.std(Total2029)
Total3039_PCO_25_Err = np.std(Total3039)
Total4049_PCO_25_Err = np.std(Total4049)
Total5059_PCO_25_Err = np.std(Total5059)
Total6069_PCO_25_Err = np.std(Total6069)
Total7079_PCO_25_Err = np.std(Total7079)
Total8089_PCO_25_Err = np.std(Total8089)
Total90_PCO_25_Err = np.std(Total90)
# Out:
# 1933076.99 ± 12121.344768213634
# 101.215 ± 2.346545333037485
# 130356.05 ± 379.5755096156758
# 470.75 ± 23.138009853917858
# 662.47 ± 25.913106722274733
# 2616.62 ± 51.34564830635601
# 8282.41 ± 90.19502148123256
# 18494.28 ± 138.4496356080434
# 29840.82 ± 175.56112211990444
# 35355.87 ± 172.4836024090406
# 27509.55 ± 167.9375106996647
# 7123.28 ± 82.06534956971792
# 1845098.3 ± 75750.4524808268

# %%
#PopnControl R = 2.25
IPeak = []
PeakTime = []
Dead = []
Dead019 = []
Dead2029 = []
Dead3039 = []
Dead4049 = []
Dead5059 = []
Dead6069 = []
Dead7079 = []
Dead8089 = []
Dead90 = []
ILifting = []
TotalCases = []
Total019 = []
Total2029 = []
Total3039 = []
Total4049 = []
Total5059 = []
Total6069 = []
Total7079 = []
Total8089 = []
Total90 = []
z = 1.960
for i in range(1,101):
    df = pd.read_csv (r'E:\Users\Michael\Project Notebook\Sim Data\PopnControl\2.25\PopnControl_R2.25_{}.csv'.format(i))
    Imax = pd.DataFrame.max(df['I'])
    time = pd.DataFrame.max(df.loc[df['I'] == Imax]['t'])
    dead = df['D'].iloc[-1]
    dead019 = df['London Dead 0-19'].iloc[-1] + df['Birmingham Dead 0-19'].iloc[-1] + df['Leeds Dead 0-19'].iloc[-1]\
    + df['Sheffield Dead 0-19'].iloc[-1] + df['Manchester Dead 0-19'].iloc[-1] + df['Bradford Dead 0-19'].iloc[-1]\
    + df['Liverpool Dead 0-19'].iloc[-1] + df['Bristol Dead 0-19'].iloc[-1]
    dead2029 = df['London Dead 20-29'].iloc[-1] + df['Birmingham Dead 20-29'].iloc[-1] + df['Leeds Dead 20-29'].iloc[-1]\
    + df['Sheffield Dead 20-29'].iloc[-1] + df['Manchester Dead 20-29'].iloc[-1] + df['Bradford Dead 20-29'].iloc[-1]\
    + df['Liverpool Dead 20-29'].iloc[-1] + df['Bristol Dead 20-29'].iloc[-1]
    dead3039 = df['London Dead 30-39'].iloc[-1] + df['Birmingham Dead 30-39'].iloc[-1] + df['Leeds Dead 30-39'].iloc[-1]\
    + df['Sheffield Dead 30-39'].iloc[-1] + df['Manchester Dead 30-39'].iloc[-1] + df['Bradford Dead 30-39'].iloc[-1]\
    + df['Liverpool Dead 30-39'].iloc[-1] + df['Bristol Dead 30-39'].iloc[-1]
    dead4049 = df['London Dead 40-49'].iloc[-1] + df['Birmingham Dead 40-49'].iloc[-1] + df['Leeds Dead 40-49'].iloc[-1]\
    + df['Sheffield Dead 40-49'].iloc[-1] + df['Manchester Dead 40-49'].iloc[-1] + df['Bradford Dead 40-49'].iloc[-1]\
    + df['Liverpool Dead 40-49'].iloc[-1] + df['Bristol Dead 40-49'].iloc[-1]
    dead5059 = df['London Dead 50-59'].iloc[-1] + df['Birmingham Dead 50-59'].iloc[-1] + df['Leeds Dead 50-59'].iloc[-1]\
    + df['Sheffield Dead 50-59'].iloc[-1] + df['Manchester Dead 50-59'].iloc[-1] + df['Bradford Dead 50-59'].iloc[-1]\
    + df['Liverpool Dead 50-59'].iloc[-1] + df['Bristol Dead 50-59'].iloc[-1]
    dead6069 = df['London Dead 60-69'].iloc[-1] + df['Birmingham Dead 60-69'].iloc[-1] + df['Leeds Dead 60-69'].iloc[-1]\
    + df['Sheffield Dead 60-69'].iloc[-1] + df['Manchester Dead 60-69'].iloc[-1] + df['Bradford Dead 60-69'].iloc[-1]\
    + df['Liverpool Dead 60-69'].iloc[-1] + df['Bristol Dead 60-69'].iloc[-1]
    dead7079 = df['London Dead 70-79'].iloc[-1] + df['Birmingham Dead 70-79'].iloc[-1] + df['Leeds Dead 70-79'].iloc[-1]\
    + df['Sheffield Dead 70-79'].iloc[-1] + df['Manchester Dead 70-79'].iloc[-1] + df['Bradford Dead 70-79'].iloc[-1]\
    + df['Liverpool Dead 70-79'].iloc[-1] + df['Bristol Dead 70-79'].iloc[-1]
    dead8089 = df['London Dead 80-89'].iloc[-1] + df['Birmingham Dead 80-89'].iloc[-1] + df['Leeds Dead 80-89'].iloc[-1]\
    + df['Sheffield Dead 80-89'].iloc[-1] + df['Manchester Dead 80-89'].iloc[-1] + df['Bradford Dead 80-89'].iloc[-1]\
    + df['Liverpool Dead 80-89'].iloc[-1] + df['Bristol Dead 80-89'].iloc[-1]
    dead90 = df['London Dead 90+'].iloc[-1] + df['Birmingham Dead 90+'].iloc[-1] + df['Leeds Dead 90+'].iloc[-1]\
    + df['Sheffield Dead 90+'].iloc[-1] + df['Manchester Dead 90+'].iloc[-1] + df['Bradford Dead 90+'].iloc[-1]\
    + df['Liverpool Dead 90+'].iloc[-1] + df['Bristol Dead 90+'].iloc[-1]
    Total019 = df['London Total 0-19'].iloc[-1] + df['Birmingham Total 0-19'].iloc[-1] + df['Leeds Total 0-19'].iloc[-1]\
    + df['Sheffield Total 0-19'].iloc[-1] + df['Manchester Total 0-19'].iloc[-1] + df['Bradford Total 0-19'].iloc[-1]\
    + df['Liverpool Total 0-19'].iloc[-1] + df['Bristol Total 0-19'].iloc[-1]
    Total2029 = df['London Total 20-29'].iloc[-1] + df['Birmingham Total 20-29'].iloc[-1] + df['Leeds Total 20-29'].iloc[-1]\
    + df['Sheffield Total 20-29'].iloc[-1] + df['Manchester Total 20-29'].iloc[-1] + df['Bradford Total 20-29'].iloc[-1]\
    + df['Liverpool Total 20-29'].iloc[-1] + df['Bristol Total 20-29'].iloc[-1]
    Total3039 = df['London Total 30-39'].iloc[-1] + df['Birmingham Total 30-39'].iloc[-1] + df['Leeds Total 30-39'].iloc[-1]\
    + df['Sheffield Total 30-39'].iloc[-1] + df['Manchester Total 30-39'].iloc[-1] + df['Bradford Total 30-39'].iloc[-1]\
    + df['Liverpool Total 30-39'].iloc[-1] + df['Bristol Total 30-39'].iloc[-1]
    Total4049 = df['London Total 40-49'].iloc[-1] + df['Birmingham Total 40-49'].iloc[-1] + df['Leeds Total 40-49'].iloc[-1]\
    + df['Sheffield Total 40-49'].iloc[-1] + df['Manchester Total 40-49'].iloc[-1] + df['Bradford Total 40-49'].iloc[-1]\
    + df['Liverpool Total 40-49'].iloc[-1] + df['Bristol Total 40-49'].iloc[-1]
    Total5059 = df['London Total 50-59'].iloc[-1] + df['Birmingham Total 50-59'].iloc[-1] + df['Leeds Total 50-59'].iloc[-1]\
    + df['Sheffield Total 50-59'].iloc[-1] + df['Manchester Total 50-59'].iloc[-1] + df['Bradford Total 50-59'].iloc[-1]\
    + df['Liverpool Total 50-59'].iloc[-1] + df['Bristol Total 50-59'].iloc[-1]
    Total6069 = df['London Total 60-69'].iloc[-1] + df['Birmingham Total 60-69'].iloc[-1] + df['Leeds Total 60-69'].iloc[-1]\
    + df['Sheffield Total 60-69'].iloc[-1] + df['Manchester Total 60-69'].iloc[-1] + df['Bradford Total 60-69'].iloc[-1]\
    + df['Liverpool Total 60-69'].iloc[-1] + df['Bristol Total 60-69'].iloc[-1]
    Total7079 = df['London Total 70-79'].iloc[-1] + df['Birmingham Total 70-79'].iloc[-1] + df['Leeds Total 70-79'].iloc[-1]\
    + df['Sheffield Total 70-79'].iloc[-1] + df['Manchester Total 70-79'].iloc[-1] + df['Bradford Total 70-79'].iloc[-1]\
    + df['Liverpool Total 70-79'].iloc[-1] + df['Bristol Total 70-79'].iloc[-1]
    Total8089 = df['London Total 80-89'].iloc[-1] + df['Birmingham Total 80-89'].iloc[-1] + df['Leeds Total 80-89'].iloc[-1]\
    + df['Sheffield Total 80-89'].iloc[-1] + df['Manchester Total 80-89'].iloc[-1] + df['Bradford Total 80-89'].iloc[-1]\
    + df['Liverpool Total 80-89'].iloc[-1] + df['Bristol Total 80-89'].iloc[-1]
    Total90 = df['London Total 90+'].iloc[-1] + df['Birmingham Total 90+'].iloc[-1] + df['Leeds Total 90+'].iloc[-1]\
    + df['Sheffield Total 90+'].iloc[-1] + df['Manchester Total 90+'].iloc[-1] + df['Bradford Total 90+'].iloc[-1]\
    + df['Liverpool Total 90+'].iloc[-1] + df['Bristol Total 90+'].iloc[-1]
    Ilift = df.loc[1050]['I']
    TotCas = df['Total Cases'].iloc[-1]
    TotalCases.append(TotCas)
    Dead.append(dead)
    IPeak.append(Imax)
    PeakTime.append(time)
    Dead019.append(dead019)
    Dead2029.append(dead2029)
    Dead3039.append(dead3039) 
    Dead4049.append(dead4049) 
    Dead5059.append(dead5059) 
    Dead6069.append(dead6069) 
    Dead7079.append(dead7079) 
    Dead8089.append(dead8089) 
    Dead90.append(dead90)
    ILifting.append(Ilift)
print(np.mean(IPeak),u"\u00B1",np.std(IPeak))
print(np.mean(PeakTime),u"\u00B1",np.std(PeakTime))  
print(np.mean(Dead),u"\u00B1",np.std(Dead))
print(np.mean(Dead019),u"\u00B1",np.std(Dead019))
print(np.mean(Dead2029),u"\u00B1",np.std(Dead2029))
print(np.mean(Dead3039),u"\u00B1",np.std(Dead3039))
print(np.mean(Dead4049),u"\u00B1",np.std(Dead4049))
print(np.mean(Dead5059),u"\u00B1",np.std(Dead5059))
print(np.mean(Dead6069),u"\u00B1",np.std(Dead6069))
print(np.mean(Dead7079),u"\u00B1",np.std(Dead7079))
print(np.mean(Dead8089),u"\u00B1",np.std(Dead8089))
print(np.mean(Dead90),u"\u00B1",np.std(Dead90))
print(np.mean(ILifting),u"\u00B1",np.std(ILifting))
IPeak_PCO_225 = np.mean(IPeak)
PeakTime_PCO_225 = np.mean(PeakTime)
Dead_PCO_225 = np.mean(Dead)
Dead019_PCO_225 = np.mean(Dead019)
Dead2029_PCO_225 = np.mean(Dead2029)
Dead3039_PCO_225 = np.mean(Dead3039)
Dead4049_PCO_225 = np.mean(Dead4049)
Dead5059_PCO_225 = np.mean(Dead5059)
Dead6069_PCO_225 = np.mean(Dead6069)
Dead7079_PCO_225 = np.mean(Dead7079)
Dead8089_PCO_225 = np.mean(Dead8089)
Dead90_PCO_225 = np.mean(Dead90)
ILifting_PCO_225 = np.mean(ILifting)
IPeak_PCO_225_Err = np.std(IPeak)
PeakTime_PCO_225_Err = np.std(PeakTime)
Dead_PCO_225_Err = np.std(Dead)
Dead019_PCO_225_Err = np.std(Dead019)
Dead2029_PCO_225_Err = np.std(Dead2029)
Dead3039_PCO_225_Err = np.std(Dead3039)
Dead4049_PCO_225_Err = np.std(Dead4049)
Dead5059_PCO_225_Err = np.std(Dead5059)
Dead6069_PCO_225_Err = np.std(Dead6069)
Dead7079_PCO_225_Err = np.std(Dead7079)
Dead8089_PCO_225_Err = np.std(Dead8089)
Dead90_PCO_225_Err = np.std(Dead90)
ILifting_PCO_225_Err = np.std(ILifting)
PeakTimeArray_PCO_225 = PeakTime
TotalCases_PCO_225 = np.mean(TotalCases)
TotalCases_PCO_225_Err = np.std(TotalCases)
Total019_PCO_225 = np.mean(Total019)
Total2029_PCO_225 = np.mean(Total2029)
Total3039_PCO_225 = np.mean(Total3039)
Total4049_PCO_225 = np.mean(Total4049)
Total5059_PCO_225 = np.mean(Total5059)
Total6069_PCO_225 = np.mean(Total6069)
Total7079_PCO_225 = np.mean(Total7079)
Total8089_PCO_225 = np.mean(Total8089)
Total90_PCO_225 = np.mean(Total90)
Total019_PCO_225_Err = np.std(Total019)
Total2029_PCO_225_Err = np.std(Total2029)
Total3039_PCO_225_Err = np.std(Total3039)
Total4049_PCO_225_Err = np.std(Total4049)
Total5059_PCO_225_Err = np.std(Total5059)
Total6069_PCO_225_Err = np.std(Total6069)
Total7079_PCO_225_Err = np.std(Total7079)
Total8089_PCO_225_Err = np.std(Total8089)
Total90_PCO_225_Err = np.std(Total90)
# Out:
# 1617015.33 ± 12046.72761131005
# 118.31100000000002 ± 3.734270879301608
# 116378.18 ± 384.77560681519304
# 453.97 ± 22.810284960955663
# 630.44 ± 24.343508374924106
# 2527.13 ± 54.272581475363786
# 7959.49 ± 81.24204514904828
# 17147.41 ± 150.66267586897558
# 26626.96 ± 187.60596579000358
# 30820.57 ± 179.4389731914447
# 23986.18 ± 148.95619356038875
# 6226.03 ± 77.93734085789686
# 1102658.44 ± 223497.38204924547

# %%
#PopnControl R = 2
IPeak = []
PeakTime = []
Dead = []
Dead019 = []
Dead2029 = []
Dead3039 = []
Dead4049 = []
Dead5059 = []
Dead6069 = []
Dead7079 = []
Dead8089 = []
Dead90 = []
ILifting = []
TotalCases = []
Total019 = []
Total2029 = []
Total3039 = []
Total4049 = []
Total5059 = []
Total6069 = []
Total7079 = []
Total8089 = []
Total90 = []
z = 1.960
for i in range(1,101):
    df = pd.read_csv (r'E:\Users\Michael\Project Notebook\Sim Data\PopnControl\2\PopnControl_R2_{}.csv'.format(i))
    Imax = pd.DataFrame.max(df['I'])
    time = pd.DataFrame.max(df.loc[df['I'] == Imax]['t'])
    dead = df['D'].iloc[-1]
    dead019 = df['London Dead 0-19'].iloc[-1] + df['Birmingham Dead 0-19'].iloc[-1] + df['Leeds Dead 0-19'].iloc[-1]\
    + df['Sheffield Dead 0-19'].iloc[-1] + df['Manchester Dead 0-19'].iloc[-1] + df['Bradford Dead 0-19'].iloc[-1]\
    + df['Liverpool Dead 0-19'].iloc[-1] + df['Bristol Dead 0-19'].iloc[-1]
    dead2029 = df['London Dead 20-29'].iloc[-1] + df['Birmingham Dead 20-29'].iloc[-1] + df['Leeds Dead 20-29'].iloc[-1]\
    + df['Sheffield Dead 20-29'].iloc[-1] + df['Manchester Dead 20-29'].iloc[-1] + df['Bradford Dead 20-29'].iloc[-1]\
    + df['Liverpool Dead 20-29'].iloc[-1] + df['Bristol Dead 20-29'].iloc[-1]
    dead3039 = df['London Dead 30-39'].iloc[-1] + df['Birmingham Dead 30-39'].iloc[-1] + df['Leeds Dead 30-39'].iloc[-1]\
    + df['Sheffield Dead 30-39'].iloc[-1] + df['Manchester Dead 30-39'].iloc[-1] + df['Bradford Dead 30-39'].iloc[-1]\
    + df['Liverpool Dead 30-39'].iloc[-1] + df['Bristol Dead 30-39'].iloc[-1]
    dead4049 = df['London Dead 40-49'].iloc[-1] + df['Birmingham Dead 40-49'].iloc[-1] + df['Leeds Dead 40-49'].iloc[-1]\
    + df['Sheffield Dead 40-49'].iloc[-1] + df['Manchester Dead 40-49'].iloc[-1] + df['Bradford Dead 40-49'].iloc[-1]\
    + df['Liverpool Dead 40-49'].iloc[-1] + df['Bristol Dead 40-49'].iloc[-1]
    dead5059 = df['London Dead 50-59'].iloc[-1] + df['Birmingham Dead 50-59'].iloc[-1] + df['Leeds Dead 50-59'].iloc[-1]\
    + df['Sheffield Dead 50-59'].iloc[-1] + df['Manchester Dead 50-59'].iloc[-1] + df['Bradford Dead 50-59'].iloc[-1]\
    + df['Liverpool Dead 50-59'].iloc[-1] + df['Bristol Dead 50-59'].iloc[-1]
    dead6069 = df['London Dead 60-69'].iloc[-1] + df['Birmingham Dead 60-69'].iloc[-1] + df['Leeds Dead 60-69'].iloc[-1]\
    + df['Sheffield Dead 60-69'].iloc[-1] + df['Manchester Dead 60-69'].iloc[-1] + df['Bradford Dead 60-69'].iloc[-1]\
    + df['Liverpool Dead 60-69'].iloc[-1] + df['Bristol Dead 60-69'].iloc[-1]
    dead7079 = df['London Dead 70-79'].iloc[-1] + df['Birmingham Dead 70-79'].iloc[-1] + df['Leeds Dead 70-79'].iloc[-1]\
    + df['Sheffield Dead 70-79'].iloc[-1] + df['Manchester Dead 70-79'].iloc[-1] + df['Bradford Dead 70-79'].iloc[-1]\
    + df['Liverpool Dead 70-79'].iloc[-1] + df['Bristol Dead 70-79'].iloc[-1]
    dead8089 = df['London Dead 80-89'].iloc[-1] + df['Birmingham Dead 80-89'].iloc[-1] + df['Leeds Dead 80-89'].iloc[-1]\
    + df['Sheffield Dead 80-89'].iloc[-1] + df['Manchester Dead 80-89'].iloc[-1] + df['Bradford Dead 80-89'].iloc[-1]\
    + df['Liverpool Dead 80-89'].iloc[-1] + df['Bristol Dead 80-89'].iloc[-1]
    dead90 = df['London Dead 90+'].iloc[-1] + df['Birmingham Dead 90+'].iloc[-1] + df['Leeds Dead 90+'].iloc[-1]\
    + df['Sheffield Dead 90+'].iloc[-1] + df['Manchester Dead 90+'].iloc[-1] + df['Bradford Dead 90+'].iloc[-1]\
    + df['Liverpool Dead 90+'].iloc[-1] + df['Bristol Dead 90+'].iloc[-1]
    Total019 = df['London Total 0-19'].iloc[-1] + df['Birmingham Total 0-19'].iloc[-1] + df['Leeds Total 0-19'].iloc[-1]\
    + df['Sheffield Total 0-19'].iloc[-1] + df['Manchester Total 0-19'].iloc[-1] + df['Bradford Total 0-19'].iloc[-1]\
    + df['Liverpool Total 0-19'].iloc[-1] + df['Bristol Total 0-19'].iloc[-1]
    Total2029 = df['London Total 20-29'].iloc[-1] + df['Birmingham Total 20-29'].iloc[-1] + df['Leeds Total 20-29'].iloc[-1]\
    + df['Sheffield Total 20-29'].iloc[-1] + df['Manchester Total 20-29'].iloc[-1] + df['Bradford Total 20-29'].iloc[-1]\
    + df['Liverpool Total 20-29'].iloc[-1] + df['Bristol Total 20-29'].iloc[-1]
    Total3039 = df['London Total 30-39'].iloc[-1] + df['Birmingham Total 30-39'].iloc[-1] + df['Leeds Total 30-39'].iloc[-1]\
    + df['Sheffield Total 30-39'].iloc[-1] + df['Manchester Total 30-39'].iloc[-1] + df['Bradford Total 30-39'].iloc[-1]\
    + df['Liverpool Total 30-39'].iloc[-1] + df['Bristol Total 30-39'].iloc[-1]
    Total4049 = df['London Total 40-49'].iloc[-1] + df['Birmingham Total 40-49'].iloc[-1] + df['Leeds Total 40-49'].iloc[-1]\
    + df['Sheffield Total 40-49'].iloc[-1] + df['Manchester Total 40-49'].iloc[-1] + df['Bradford Total 40-49'].iloc[-1]\
    + df['Liverpool Total 40-49'].iloc[-1] + df['Bristol Total 40-49'].iloc[-1]
    Total5059 = df['London Total 50-59'].iloc[-1] + df['Birmingham Total 50-59'].iloc[-1] + df['Leeds Total 50-59'].iloc[-1]\
    + df['Sheffield Total 50-59'].iloc[-1] + df['Manchester Total 50-59'].iloc[-1] + df['Bradford Total 50-59'].iloc[-1]\
    + df['Liverpool Total 50-59'].iloc[-1] + df['Bristol Total 50-59'].iloc[-1]
    Total6069 = df['London Total 60-69'].iloc[-1] + df['Birmingham Total 60-69'].iloc[-1] + df['Leeds Total 60-69'].iloc[-1]\
    + df['Sheffield Total 60-69'].iloc[-1] + df['Manchester Total 60-69'].iloc[-1] + df['Bradford Total 60-69'].iloc[-1]\
    + df['Liverpool Total 60-69'].iloc[-1] + df['Bristol Total 60-69'].iloc[-1]
    Total7079 = df['London Total 70-79'].iloc[-1] + df['Birmingham Total 70-79'].iloc[-1] + df['Leeds Total 70-79'].iloc[-1]\
    + df['Sheffield Total 70-79'].iloc[-1] + df['Manchester Total 70-79'].iloc[-1] + df['Bradford Total 70-79'].iloc[-1]\
    + df['Liverpool Total 70-79'].iloc[-1] + df['Bristol Total 70-79'].iloc[-1]
    Total8089 = df['London Total 80-89'].iloc[-1] + df['Birmingham Total 80-89'].iloc[-1] + df['Leeds Total 80-89'].iloc[-1]\
    + df['Sheffield Total 80-89'].iloc[-1] + df['Manchester Total 80-89'].iloc[-1] + df['Bradford Total 80-89'].iloc[-1]\
    + df['Liverpool Total 80-89'].iloc[-1] + df['Bristol Total 80-89'].iloc[-1]
    Total90 = df['London Total 90+'].iloc[-1] + df['Birmingham Total 90+'].iloc[-1] + df['Leeds Total 90+'].iloc[-1]\
    + df['Sheffield Total 90+'].iloc[-1] + df['Manchester Total 90+'].iloc[-1] + df['Bradford Total 90+'].iloc[-1]\
    + df['Liverpool Total 90+'].iloc[-1] + df['Bristol Total 90+'].iloc[-1]
    Ilift = df.loc[1050]['I']
    TotCas = df['Total Cases'].iloc[-1]
    TotalCases.append(TotCas)
    Dead.append(dead)
    IPeak.append(Imax)
    PeakTime.append(time)
    Dead019.append(dead019)
    Dead2029.append(dead2029)
    Dead3039.append(dead3039) 
    Dead4049.append(dead4049) 
    Dead5059.append(dead5059) 
    Dead6069.append(dead6069) 
    Dead7079.append(dead7079) 
    Dead8089.append(dead8089) 
    Dead90.append(dead90)
    ILifting.append(Ilift)
print(np.mean(IPeak),u"\u00B1",np.std(IPeak))
print(np.mean(PeakTime),u"\u00B1",np.std(PeakTime))  
print(np.mean(Dead),u"\u00B1",np.std(Dead))
print(np.mean(Dead019),u"\u00B1",np.std(Dead019))
print(np.mean(Dead2029),u"\u00B1",np.std(Dead2029))
print(np.mean(Dead3039),u"\u00B1",np.std(Dead3039))
print(np.mean(Dead4049),u"\u00B1",np.std(Dead4049))
print(np.mean(Dead5059),u"\u00B1",np.std(Dead5059))
print(np.mean(Dead6069),u"\u00B1",np.std(Dead6069))
print(np.mean(Dead7079),u"\u00B1",np.std(Dead7079))
print(np.mean(Dead8089),u"\u00B1",np.std(Dead8089))
print(np.mean(Dead90),u"\u00B1",np.std(Dead90))
print(np.mean(ILifting),u"\u00B1",np.std(ILifting))
IPeak_PCO_2 = np.mean(IPeak)
PeakTime_PCO_2 = np.mean(PeakTime)
Dead_PCO_2 = np.mean(Dead)
Dead019_PCO_2 = np.mean(Dead019)
Dead2029_PCO_2 = np.mean(Dead2029)
Dead3039_PCO_2 = np.mean(Dead3039)
Dead4049_PCO_2 = np.mean(Dead4049)
Dead5059_PCO_2 = np.mean(Dead5059)
Dead6069_PCO_2 = np.mean(Dead6069)
Dead7079_PCO_2 = np.mean(Dead7079)
Dead8089_PCO_2 = np.mean(Dead8089)
Dead90_PCO_2 = np.mean(Dead90)
ILifting_PCO_2 = np.mean(ILifting)
IPeak_PCO_2_Err = np.std(IPeak)
PeakTime_PCO_2_Err = np.std(PeakTime)
Dead_PCO_2_Err = np.std(Dead)
Dead019_PCO_2_Err = np.std(Dead019)
Dead2029_PCO_2_Err = np.std(Dead2029)
Dead3039_PCO_2_Err = np.std(Dead3039)
Dead4049_PCO_2_Err = np.std(Dead4049)
Dead5059_PCO_2_Err = np.std(Dead5059)
Dead6069_PCO_2_Err = np.std(Dead6069)
Dead7079_PCO_2_Err = np.std(Dead7079)
Dead8089_PCO_2_Err = np.std(Dead8089)
Dead90_PCO_2_Err = np.std(Dead90)
ILifting_PCO_2_Err = np.std(ILifting)
PeakTimeArray_PCO_2 = PeakTime
TotalCases_PCO_2 = np.mean(TotalCases)
TotalCases_PCO_2_Err = np.std(TotalCases)
Total019_PCO_2 = np.mean(Total019)
Total2029_PCO_2 = np.mean(Total2029)
Total3039_PCO_2 = np.mean(Total3039)
Total4049_PCO_2 = np.mean(Total4049)
Total5059_PCO_2 = np.mean(Total5059)
Total6069_PCO_2 = np.mean(Total6069)
Total7079_PCO_2 = np.mean(Total7079)
Total8089_PCO_2 = np.mean(Total8089)
Total90_PCO_2 = np.mean(Total90)
Total019_PCO_2_Err = np.std(Total019)
Total2029_PCO_2_Err = np.std(Total2029)
Total3039_PCO_2_Err = np.std(Total3039)
Total4049_PCO_2_Err = np.std(Total4049)
Total5059_PCO_2_Err = np.std(Total5059)
Total6069_PCO_2_Err = np.std(Total6069)
Total7079_PCO_2_Err = np.std(Total7079)
Total8089_PCO_2_Err = np.std(Total8089)
Total90_PCO_2_Err = np.std(Total90)
# Out:
# 1270582.46 ± 8747.007108057018
# 143.03400000000002 ± 4.566600924100992
# 100407.62 ± 338.76678644755003
# 413.92 ± 20.067227013217348
# 590.66 ± 22.936529815994398
# 2362.26 ± 52.86031025258932
# 7479.48 ± 75.09733417372418
# 15367.33 ± 119.73872013680455
# 22885.7 ± 175.33336818757573
# 25951.5 ± 158.95600020131357
# 20143.95 ± 133.8393346516636
# 5212.82 ± 69.07856107360662
# 187627.76 ± 67261.8504635607

# %%
#PopnChanged R = 4
IPeak = []
PeakTime = []
Dead = []
Dead019 = []
Dead2029 = []
Dead3039 = []
Dead4049 = []
Dead5059 = []
Dead6069 = []
Dead7079 = []
Dead8089 = []
Dead90 = []
ILifting = []
TotalCases = []
Total019 = []
Total2029 = []
Total3039 = []
Total4049 = []
Total5059 = []
Total6069 = []
Total7079 = []
Total8089 = []
Total90 = []
z = 1.960
for i in range(1,101):
    df = pd.read_csv (r'E:\Users\Michael\Project Notebook\Sim Data\PopnChanged\4\PopnChanged_R4_{}.csv'.format(i))
    Imax = pd.DataFrame.max(df['I'])
    time = pd.DataFrame.max(df.loc[df['I'] == Imax]['t'])
    dead = df['D'].iloc[-1]
    dead019 = df['London Dead 0-19'].iloc[-1] + df['Birmingham Dead 0-19'].iloc[-1] + df['Leeds Dead 0-19'].iloc[-1]\
    + df['Sheffield Dead 0-19'].iloc[-1] + df['Manchester Dead 0-19'].iloc[-1] + df['Bradford Dead 0-19'].iloc[-1]\
    + df['Liverpool Dead 0-19'].iloc[-1] + df['Bristol Dead 0-19'].iloc[-1]
    dead2029 = df['London Dead 20-29'].iloc[-1] + df['Birmingham Dead 20-29'].iloc[-1] + df['Leeds Dead 20-29'].iloc[-1]\
    + df['Sheffield Dead 20-29'].iloc[-1] + df['Manchester Dead 20-29'].iloc[-1] + df['Bradford Dead 20-29'].iloc[-1]\
    + df['Liverpool Dead 20-29'].iloc[-1] + df['Bristol Dead 20-29'].iloc[-1]
    dead3039 = df['London Dead 30-39'].iloc[-1] + df['Birmingham Dead 30-39'].iloc[-1] + df['Leeds Dead 30-39'].iloc[-1]\
    + df['Sheffield Dead 30-39'].iloc[-1] + df['Manchester Dead 30-39'].iloc[-1] + df['Bradford Dead 30-39'].iloc[-1]\
    + df['Liverpool Dead 30-39'].iloc[-1] + df['Bristol Dead 30-39'].iloc[-1]
    dead4049 = df['London Dead 40-49'].iloc[-1] + df['Birmingham Dead 40-49'].iloc[-1] + df['Leeds Dead 40-49'].iloc[-1]\
    + df['Sheffield Dead 40-49'].iloc[-1] + df['Manchester Dead 40-49'].iloc[-1] + df['Bradford Dead 40-49'].iloc[-1]\
    + df['Liverpool Dead 40-49'].iloc[-1] + df['Bristol Dead 40-49'].iloc[-1]
    dead5059 = df['London Dead 50-59'].iloc[-1] + df['Birmingham Dead 50-59'].iloc[-1] + df['Leeds Dead 50-59'].iloc[-1]\
    + df['Sheffield Dead 50-59'].iloc[-1] + df['Manchester Dead 50-59'].iloc[-1] + df['Bradford Dead 50-59'].iloc[-1]\
    + df['Liverpool Dead 50-59'].iloc[-1] + df['Bristol Dead 50-59'].iloc[-1]
    dead6069 = df['London Dead 60-69'].iloc[-1] + df['Birmingham Dead 60-69'].iloc[-1] + df['Leeds Dead 60-69'].iloc[-1]\
    + df['Sheffield Dead 60-69'].iloc[-1] + df['Manchester Dead 60-69'].iloc[-1] + df['Bradford Dead 60-69'].iloc[-1]\
    + df['Liverpool Dead 60-69'].iloc[-1] + df['Bristol Dead 60-69'].iloc[-1]
    dead7079 = df['London Dead 70-79'].iloc[-1] + df['Birmingham Dead 70-79'].iloc[-1] + df['Leeds Dead 70-79'].iloc[-1]\
    + df['Sheffield Dead 70-79'].iloc[-1] + df['Manchester Dead 70-79'].iloc[-1] + df['Bradford Dead 70-79'].iloc[-1]\
    + df['Liverpool Dead 70-79'].iloc[-1] + df['Bristol Dead 70-79'].iloc[-1]
    dead8089 = df['London Dead 80-89'].iloc[-1] + df['Birmingham Dead 80-89'].iloc[-1] + df['Leeds Dead 80-89'].iloc[-1]\
    + df['Sheffield Dead 80-89'].iloc[-1] + df['Manchester Dead 80-89'].iloc[-1] + df['Bradford Dead 80-89'].iloc[-1]\
    + df['Liverpool Dead 80-89'].iloc[-1] + df['Bristol Dead 80-89'].iloc[-1]
    dead90 = df['London Dead 90+'].iloc[-1] + df['Birmingham Dead 90+'].iloc[-1] + df['Leeds Dead 90+'].iloc[-1]\
    + df['Sheffield Dead 90+'].iloc[-1] + df['Manchester Dead 90+'].iloc[-1] + df['Bradford Dead 90+'].iloc[-1]\
    + df['Liverpool Dead 90+'].iloc[-1] + df['Bristol Dead 90+'].iloc[-1]
    Total019 = df['London Total 0-19'].iloc[-1] + df['Birmingham Total 0-19'].iloc[-1] + df['Leeds Total 0-19'].iloc[-1]\
    + df['Sheffield Total 0-19'].iloc[-1] + df['Manchester Total 0-19'].iloc[-1] + df['Bradford Total 0-19'].iloc[-1]\
    + df['Liverpool Total 0-19'].iloc[-1] + df['Bristol Total 0-19'].iloc[-1]
    Total2029 = df['London Total 20-29'].iloc[-1] + df['Birmingham Total 20-29'].iloc[-1] + df['Leeds Total 20-29'].iloc[-1]\
    + df['Sheffield Total 20-29'].iloc[-1] + df['Manchester Total 20-29'].iloc[-1] + df['Bradford Total 20-29'].iloc[-1]\
    + df['Liverpool Total 20-29'].iloc[-1] + df['Bristol Total 20-29'].iloc[-1]
    Total3039 = df['London Total 30-39'].iloc[-1] + df['Birmingham Total 30-39'].iloc[-1] + df['Leeds Total 30-39'].iloc[-1]\
    + df['Sheffield Total 30-39'].iloc[-1] + df['Manchester Total 30-39'].iloc[-1] + df['Bradford Total 30-39'].iloc[-1]\
    + df['Liverpool Total 30-39'].iloc[-1] + df['Bristol Total 30-39'].iloc[-1]
    Total4049 = df['London Total 40-49'].iloc[-1] + df['Birmingham Total 40-49'].iloc[-1] + df['Leeds Total 40-49'].iloc[-1]\
    + df['Sheffield Total 40-49'].iloc[-1] + df['Manchester Total 40-49'].iloc[-1] + df['Bradford Total 40-49'].iloc[-1]\
    + df['Liverpool Total 40-49'].iloc[-1] + df['Bristol Total 40-49'].iloc[-1]
    Total5059 = df['London Total 50-59'].iloc[-1] + df['Birmingham Total 50-59'].iloc[-1] + df['Leeds Total 50-59'].iloc[-1]\
    + df['Sheffield Total 50-59'].iloc[-1] + df['Manchester Total 50-59'].iloc[-1] + df['Bradford Total 50-59'].iloc[-1]\
    + df['Liverpool Total 50-59'].iloc[-1] + df['Bristol Total 50-59'].iloc[-1]
    Total6069 = df['London Total 60-69'].iloc[-1] + df['Birmingham Total 60-69'].iloc[-1] + df['Leeds Total 60-69'].iloc[-1]\
    + df['Sheffield Total 60-69'].iloc[-1] + df['Manchester Total 60-69'].iloc[-1] + df['Bradford Total 60-69'].iloc[-1]\
    + df['Liverpool Total 60-69'].iloc[-1] + df['Bristol Total 60-69'].iloc[-1]
    Total7079 = df['London Total 70-79'].iloc[-1] + df['Birmingham Total 70-79'].iloc[-1] + df['Leeds Total 70-79'].iloc[-1]\
    + df['Sheffield Total 70-79'].iloc[-1] + df['Manchester Total 70-79'].iloc[-1] + df['Bradford Total 70-79'].iloc[-1]\
    + df['Liverpool Total 70-79'].iloc[-1] + df['Bristol Total 70-79'].iloc[-1]
    Total8089 = df['London Total 80-89'].iloc[-1] + df['Birmingham Total 80-89'].iloc[-1] + df['Leeds Total 80-89'].iloc[-1]\
    + df['Sheffield Total 80-89'].iloc[-1] + df['Manchester Total 80-89'].iloc[-1] + df['Bradford Total 80-89'].iloc[-1]\
    + df['Liverpool Total 80-89'].iloc[-1] + df['Bristol Total 80-89'].iloc[-1]
    Total90 = df['London Total 90+'].iloc[-1] + df['Birmingham Total 90+'].iloc[-1] + df['Leeds Total 90+'].iloc[-1]\
    + df['Sheffield Total 90+'].iloc[-1] + df['Manchester Total 90+'].iloc[-1] + df['Bradford Total 90+'].iloc[-1]\
    + df['Liverpool Total 90+'].iloc[-1] + df['Bristol Total 90+'].iloc[-1]
    Ilift = df.loc[1050]['I']
    TotCas = df['Total Cases'].iloc[-1]
    TotalCases.append(TotCas)
    Dead.append(dead)
    IPeak.append(Imax)
    PeakTime.append(time)
    Dead019.append(dead019)
    Dead2029.append(dead2029)
    Dead3039.append(dead3039) 
    Dead4049.append(dead4049) 
    Dead5059.append(dead5059) 
    Dead6069.append(dead6069) 
    Dead7079.append(dead7079) 
    Dead8089.append(dead8089) 
    Dead90.append(dead90)
    ILifting.append(Ilift)
print(np.mean(IPeak),u"\u00B1",np.std(IPeak))
print(np.mean(PeakTime),u"\u00B1",np.std(PeakTime))  
print(np.mean(Dead),u"\u00B1",np.std(Dead))
print(np.mean(Dead019),u"\u00B1",np.std(Dead019))
print(np.mean(Dead2029),u"\u00B1",np.std(Dead2029))
print(np.mean(Dead3039),u"\u00B1",np.std(Dead3039))
print(np.mean(Dead4049),u"\u00B1",np.std(Dead4049))
print(np.mean(Dead5059),u"\u00B1",np.std(Dead5059))
print(np.mean(Dead6069),u"\u00B1",np.std(Dead6069))
print(np.mean(Dead7079),u"\u00B1",np.std(Dead7079))
print(np.mean(Dead8089),u"\u00B1",np.std(Dead8089))
print(np.mean(Dead90),u"\u00B1",np.std(Dead90))
print(np.mean(ILifting),u"\u00B1",np.std(ILifting))
IPeak_PCH_4 = np.mean(IPeak)
PeakTime_PCH_4 = np.mean(PeakTime)
Dead_PCH_4 = np.mean(Dead)
Dead019_PCH_4 = np.mean(Dead019)
Dead2029_PCH_4 = np.mean(Dead2029)
Dead3039_PCH_4 = np.mean(Dead3039)
Dead4049_PCH_4 = np.mean(Dead4049)
Dead5059_PCH_4 = np.mean(Dead5059)
Dead6069_PCH_4 = np.mean(Dead6069)
Dead7079_PCH_4 = np.mean(Dead7079)
Dead8089_PCH_4 = np.mean(Dead8089)
Dead90_PCH_4 = np.mean(Dead90)
ILifting_PCH_4 = np.mean(ILifting)
IPeak_PCH_4_Err = np.std(IPeak)
PeakTime_PCH_4_Err = np.std(PeakTime)
Dead_PCH_4_Err = np.std(Dead)
Dead019_PCH_4_Err = np.std(Dead019)
Dead2029_PCH_4_Err = np.std(Dead2029)
Dead3039_PCH_4_Err = np.std(Dead3039)
Dead4049_PCH_4_Err = np.std(Dead4049)
Dead5059_PCH_4_Err = np.std(Dead5059)
Dead6069_PCH_4_Err = np.std(Dead6069)
Dead7079_PCH_4_Err = np.std(Dead7079)
Dead8089_PCH_4_Err = np.std(Dead8089)
Dead90_PCH_4_Err = np.std(Dead90)
ILifting_PCH_4_Err = np.std(ILifting)
PeakTimeArray_PCH_4 = PeakTime
TotalCases_PCH_4 = np.mean(TotalCases)
TotalCases_PCH_4_Err = np.std(TotalCases)
Total019_PCH_4 = np.mean(Total019)
Total2029_PCH_4 = np.mean(Total2029)
Total3039_PCH_4 = np.mean(Total3039)
Total4049_PCH_4 = np.mean(Total4049)
Total5059_PCH_4 = np.mean(Total5059)
Total6069_PCH_4 = np.mean(Total6069)
Total7079_PCH_4 = np.mean(Total7079)
Total8089_PCH_4 = np.mean(Total8089)
Total90_PCH_4 = np.mean(Total90)
Total019_PCH_4_Err = np.std(Total019)
Total2029_PCH_4_Err = np.std(Total2029)
Total3039_PCH_4_Err = np.std(Total3039)
Total4049_PCH_4_Err = np.std(Total4049)
Total5059_PCH_4_Err = np.std(Total5059)
Total6069_PCH_4_Err = np.std(Total6069)
Total7079_PCH_4_Err = np.std(Total7079)
Total8089_PCH_4_Err = np.std(Total8089)
Total90_PCH_4_Err = np.std(Total90)
# Out:
# 3635523.21 ± 18294.18326370161
# 53.245 ± 0.8846892109662009
# 105415.55 ± 376.0292375600599
# 774.67 ± 26.549220327535043
# 717.19 ± 25.369546704661477
# 2453.52 ± 53.563323272552836
# 8906.46 ± 96.82679587800062
# 18806.29 ± 137.95146211620957
# 33093.51 ± 183.73886333598563
# 29762.68 ± 172.1965667485853
# 9654.22 ± 84.55135480877878
# 1247.01 ± 34.12550219410698
# 23447.15 ± 2542.5071774726616

# %%
#PopnChanged R = 3.75
IPeak = []
PeakTime = []
Dead = []
Dead019 = []
Dead2029 = []
Dead3039 = []
Dead4049 = []
Dead5059 = []
Dead6069 = []
Dead7079 = []
Dead8089 = []
Dead90 = []
ILifting = []
TotalCases = []
Total019 = []
Total2029 = []
Total3039 = []
Total4049 = []
Total5059 = []
Total6069 = []
Total7079 = []
Total8089 = []
Total90 = []
z = 1.960
for i in range(1,101):
    df = pd.read_csv (r'E:\Users\Michael\Project Notebook\Sim Data\PopnChanged\3.75\PopnChanged_R3.75_{}.csv'.format(i))
    Imax = pd.DataFrame.max(df['I'])
    time = pd.DataFrame.max(df.loc[df['I'] == Imax]['t'])
    dead = df['D'].iloc[-1]
    dead019 = df['London Dead 0-19'].iloc[-1] + df['Birmingham Dead 0-19'].iloc[-1] + df['Leeds Dead 0-19'].iloc[-1]\
    + df['Sheffield Dead 0-19'].iloc[-1] + df['Manchester Dead 0-19'].iloc[-1] + df['Bradford Dead 0-19'].iloc[-1]\
    + df['Liverpool Dead 0-19'].iloc[-1] + df['Bristol Dead 0-19'].iloc[-1]
    dead2029 = df['London Dead 20-29'].iloc[-1] + df['Birmingham Dead 20-29'].iloc[-1] + df['Leeds Dead 20-29'].iloc[-1]\
    + df['Sheffield Dead 20-29'].iloc[-1] + df['Manchester Dead 20-29'].iloc[-1] + df['Bradford Dead 20-29'].iloc[-1]\
    + df['Liverpool Dead 20-29'].iloc[-1] + df['Bristol Dead 20-29'].iloc[-1]
    dead3039 = df['London Dead 30-39'].iloc[-1] + df['Birmingham Dead 30-39'].iloc[-1] + df['Leeds Dead 30-39'].iloc[-1]\
    + df['Sheffield Dead 30-39'].iloc[-1] + df['Manchester Dead 30-39'].iloc[-1] + df['Bradford Dead 30-39'].iloc[-1]\
    + df['Liverpool Dead 30-39'].iloc[-1] + df['Bristol Dead 30-39'].iloc[-1]
    dead4049 = df['London Dead 40-49'].iloc[-1] + df['Birmingham Dead 40-49'].iloc[-1] + df['Leeds Dead 40-49'].iloc[-1]\
    + df['Sheffield Dead 40-49'].iloc[-1] + df['Manchester Dead 40-49'].iloc[-1] + df['Bradford Dead 40-49'].iloc[-1]\
    + df['Liverpool Dead 40-49'].iloc[-1] + df['Bristol Dead 40-49'].iloc[-1]
    dead5059 = df['London Dead 50-59'].iloc[-1] + df['Birmingham Dead 50-59'].iloc[-1] + df['Leeds Dead 50-59'].iloc[-1]\
    + df['Sheffield Dead 50-59'].iloc[-1] + df['Manchester Dead 50-59'].iloc[-1] + df['Bradford Dead 50-59'].iloc[-1]\
    + df['Liverpool Dead 50-59'].iloc[-1] + df['Bristol Dead 50-59'].iloc[-1]
    dead6069 = df['London Dead 60-69'].iloc[-1] + df['Birmingham Dead 60-69'].iloc[-1] + df['Leeds Dead 60-69'].iloc[-1]\
    + df['Sheffield Dead 60-69'].iloc[-1] + df['Manchester Dead 60-69'].iloc[-1] + df['Bradford Dead 60-69'].iloc[-1]\
    + df['Liverpool Dead 60-69'].iloc[-1] + df['Bristol Dead 60-69'].iloc[-1]
    dead7079 = df['London Dead 70-79'].iloc[-1] + df['Birmingham Dead 70-79'].iloc[-1] + df['Leeds Dead 70-79'].iloc[-1]\
    + df['Sheffield Dead 70-79'].iloc[-1] + df['Manchester Dead 70-79'].iloc[-1] + df['Bradford Dead 70-79'].iloc[-1]\
    + df['Liverpool Dead 70-79'].iloc[-1] + df['Bristol Dead 70-79'].iloc[-1]
    dead8089 = df['London Dead 80-89'].iloc[-1] + df['Birmingham Dead 80-89'].iloc[-1] + df['Leeds Dead 80-89'].iloc[-1]\
    + df['Sheffield Dead 80-89'].iloc[-1] + df['Manchester Dead 80-89'].iloc[-1] + df['Bradford Dead 80-89'].iloc[-1]\
    + df['Liverpool Dead 80-89'].iloc[-1] + df['Bristol Dead 80-89'].iloc[-1]
    dead90 = df['London Dead 90+'].iloc[-1] + df['Birmingham Dead 90+'].iloc[-1] + df['Leeds Dead 90+'].iloc[-1]\
    + df['Sheffield Dead 90+'].iloc[-1] + df['Manchester Dead 90+'].iloc[-1] + df['Bradford Dead 90+'].iloc[-1]\
    + df['Liverpool Dead 90+'].iloc[-1] + df['Bristol Dead 90+'].iloc[-1]
    Total019 = df['London Total 0-19'].iloc[-1] + df['Birmingham Total 0-19'].iloc[-1] + df['Leeds Total 0-19'].iloc[-1]\
    + df['Sheffield Total 0-19'].iloc[-1] + df['Manchester Total 0-19'].iloc[-1] + df['Bradford Total 0-19'].iloc[-1]\
    + df['Liverpool Total 0-19'].iloc[-1] + df['Bristol Total 0-19'].iloc[-1]
    Total2029 = df['London Total 20-29'].iloc[-1] + df['Birmingham Total 20-29'].iloc[-1] + df['Leeds Total 20-29'].iloc[-1]\
    + df['Sheffield Total 20-29'].iloc[-1] + df['Manchester Total 20-29'].iloc[-1] + df['Bradford Total 20-29'].iloc[-1]\
    + df['Liverpool Total 20-29'].iloc[-1] + df['Bristol Total 20-29'].iloc[-1]
    Total3039 = df['London Total 30-39'].iloc[-1] + df['Birmingham Total 30-39'].iloc[-1] + df['Leeds Total 30-39'].iloc[-1]\
    + df['Sheffield Total 30-39'].iloc[-1] + df['Manchester Total 30-39'].iloc[-1] + df['Bradford Total 30-39'].iloc[-1]\
    + df['Liverpool Total 30-39'].iloc[-1] + df['Bristol Total 30-39'].iloc[-1]
    Total4049 = df['London Total 40-49'].iloc[-1] + df['Birmingham Total 40-49'].iloc[-1] + df['Leeds Total 40-49'].iloc[-1]\
    + df['Sheffield Total 40-49'].iloc[-1] + df['Manchester Total 40-49'].iloc[-1] + df['Bradford Total 40-49'].iloc[-1]\
    + df['Liverpool Total 40-49'].iloc[-1] + df['Bristol Total 40-49'].iloc[-1]
    Total5059 = df['London Total 50-59'].iloc[-1] + df['Birmingham Total 50-59'].iloc[-1] + df['Leeds Total 50-59'].iloc[-1]\
    + df['Sheffield Total 50-59'].iloc[-1] + df['Manchester Total 50-59'].iloc[-1] + df['Bradford Total 50-59'].iloc[-1]\
    + df['Liverpool Total 50-59'].iloc[-1] + df['Bristol Total 50-59'].iloc[-1]
    Total6069 = df['London Total 60-69'].iloc[-1] + df['Birmingham Total 60-69'].iloc[-1] + df['Leeds Total 60-69'].iloc[-1]\
    + df['Sheffield Total 60-69'].iloc[-1] + df['Manchester Total 60-69'].iloc[-1] + df['Bradford Total 60-69'].iloc[-1]\
    + df['Liverpool Total 60-69'].iloc[-1] + df['Bristol Total 60-69'].iloc[-1]
    Total7079 = df['London Total 70-79'].iloc[-1] + df['Birmingham Total 70-79'].iloc[-1] + df['Leeds Total 70-79'].iloc[-1]\
    + df['Sheffield Total 70-79'].iloc[-1] + df['Manchester Total 70-79'].iloc[-1] + df['Bradford Total 70-79'].iloc[-1]\
    + df['Liverpool Total 70-79'].iloc[-1] + df['Bristol Total 70-79'].iloc[-1]
    Total8089 = df['London Total 80-89'].iloc[-1] + df['Birmingham Total 80-89'].iloc[-1] + df['Leeds Total 80-89'].iloc[-1]\
    + df['Sheffield Total 80-89'].iloc[-1] + df['Manchester Total 80-89'].iloc[-1] + df['Bradford Total 80-89'].iloc[-1]\
    + df['Liverpool Total 80-89'].iloc[-1] + df['Bristol Total 80-89'].iloc[-1]
    Total90 = df['London Total 90+'].iloc[-1] + df['Birmingham Total 90+'].iloc[-1] + df['Leeds Total 90+'].iloc[-1]\
    + df['Sheffield Total 90+'].iloc[-1] + df['Manchester Total 90+'].iloc[-1] + df['Bradford Total 90+'].iloc[-1]\
    + df['Liverpool Total 90+'].iloc[-1] + df['Bristol Total 90+'].iloc[-1]
    Ilift = df.loc[1050]['I']
    TotCas = df['Total Cases'].iloc[-1]
    TotalCases.append(TotCas)
    Dead.append(dead)
    IPeak.append(Imax)
    PeakTime.append(time)
    Dead019.append(dead019)
    Dead2029.append(dead2029)
    Dead3039.append(dead3039) 
    Dead4049.append(dead4049) 
    Dead5059.append(dead5059) 
    Dead6069.append(dead6069) 
    Dead7079.append(dead7079) 
    Dead8089.append(dead8089) 
    Dead90.append(dead90)
    ILifting.append(Ilift)
print(np.mean(IPeak),u"\u00B1",np.std(IPeak))
print(np.mean(PeakTime),u"\u00B1",np.std(PeakTime))  
print(np.mean(Dead),u"\u00B1",np.std(Dead))
print(np.mean(Dead019),u"\u00B1",np.std(Dead019))
print(np.mean(Dead2029),u"\u00B1",np.std(Dead2029))
print(np.mean(Dead3039),u"\u00B1",np.std(Dead3039))
print(np.mean(Dead4049),u"\u00B1",np.std(Dead4049))
print(np.mean(Dead5059),u"\u00B1",np.std(Dead5059))
print(np.mean(Dead6069),u"\u00B1",np.std(Dead6069))
print(np.mean(Dead7079),u"\u00B1",np.std(Dead7079))
print(np.mean(Dead8089),u"\u00B1",np.std(Dead8089))
print(np.mean(Dead90),u"\u00B1",np.std(Dead90))
print(np.mean(ILifting),u"\u00B1",np.std(ILifting))
IPeak_PCH_375 = np.mean(IPeak)
PeakTime_PCH_375 = np.mean(PeakTime)
Dead_PCH_375 = np.mean(Dead)
Dead019_PCH_375 = np.mean(Dead019)
Dead2029_PCH_375 = np.mean(Dead2029)
Dead3039_PCH_375 = np.mean(Dead3039)
Dead4049_PCH_375 = np.mean(Dead4049)
Dead5059_PCH_375 = np.mean(Dead5059)
Dead6069_PCH_375 = np.mean(Dead6069)
Dead7079_PCH_375 = np.mean(Dead7079)
Dead8089_PCH_375 = np.mean(Dead8089)
Dead90_PCH_375 = np.mean(Dead90)
ILifting_PCH_375 = np.mean(ILifting)
IPeak_PCH_375_Err = np.std(IPeak)
PeakTime_PCH_375_Err = np.std(PeakTime)
Dead_PCH_375_Err = np.std(Dead)
Dead019_PCH_375_Err = np.std(Dead019)
Dead2029_PCH_375_Err = np.std(Dead2029)
Dead3039_PCH_375_Err = np.std(Dead3039)
Dead4049_PCH_375_Err = np.std(Dead4049)
Dead5059_PCH_375_Err = np.std(Dead5059)
Dead6069_PCH_375_Err = np.std(Dead6069)
Dead7079_PCH_375_Err = np.std(Dead7079)
Dead8089_PCH_375_Err = np.std(Dead8089)
Dead90_PCH_375_Err = np.std(Dead90)
ILifting_PCH_375_Err = np.std(ILifting)
PeakTimeArray_PCH_375 = PeakTime
TotalCases_PCH_375 = np.mean(TotalCases)
TotalCases_PCH_375_Err = np.std(TotalCases)
Total019_PCH_375 = np.mean(Total019)
Total2029_PCH_375 = np.mean(Total2029)
Total3039_PCH_375 = np.mean(Total3039)
Total4049_PCH_375 = np.mean(Total4049)
Total5059_PCH_375 = np.mean(Total5059)
Total6069_PCH_375 = np.mean(Total6069)
Total7079_PCH_375 = np.mean(Total7079)
Total8089_PCH_375 = np.mean(Total8089)
Total90_PCH_375 = np.mean(Total90)
Total019_PCH_375_Err = np.std(Total019)
Total2029_PCH_375_Err = np.std(Total2029)
Total3039_PCH_375_Err = np.std(Total3039)
Total4049_PCH_375_Err = np.std(Total4049)
Total5059_PCH_375_Err = np.std(Total5059)
Total6069_PCH_375_Err = np.std(Total6069)
Total7079_PCH_375_Err = np.std(Total7079)
Total8089_PCH_375_Err = np.std(Total8089)
Total90_PCH_375_Err = np.std(Total90)
# Out:
# 3463444.44 ± 20802.80699296131
# 57.47800000000001 ± 1.2342268835185848
# 101794.63 ± 334.62715535353675
# 769.72 ± 28.505466142478706
# 714.84 ± 26.2098149554704
# 2438.77 ± 53.06804217229047
# 8869.31 ± 89.81444148910575
# 18488.21 ± 133.73431085551678
# 31902.57 ± 187.1221128033777
# 28258.39 ± 157.2503669312094
# 9166.74 ± 103.85361043314768
# 1186.08 ± 30.639086148251877
# 43139.1 ± 6515.924452447251

# %%
#PopnChanged R = 3.5
IPeak = []
PeakTime = []
Dead = []
Dead019 = []
Dead2029 = []
Dead3039 = []
Dead4049 = []
Dead5059 = []
Dead6069 = []
Dead7079 = []
Dead8089 = []
Dead90 = []
ILifting = []
TotalCases = []
Total019 = []
Total2029 = []
Total3039 = []
Total4049 = []
Total5059 = []
Total6069 = []
Total7079 = []
Total8089 = []
Total90 = []
z = 1.960
for i in range(1,101):
    df = pd.read_csv (r'E:\Users\Michael\Project Notebook\Sim Data\PopnChanged\3.5\PopnChanged_R3.5_{}.csv'.format(i))
    Imax = pd.DataFrame.max(df['I'])
    time = pd.DataFrame.max(df.loc[df['I'] == Imax]['t'])
    dead = df['D'].iloc[-1]
    dead019 = df['London Dead 0-19'].iloc[-1] + df['Birmingham Dead 0-19'].iloc[-1] + df['Leeds Dead 0-19'].iloc[-1]\
    + df['Sheffield Dead 0-19'].iloc[-1] + df['Manchester Dead 0-19'].iloc[-1] + df['Bradford Dead 0-19'].iloc[-1]\
    + df['Liverpool Dead 0-19'].iloc[-1] + df['Bristol Dead 0-19'].iloc[-1]
    dead2029 = df['London Dead 20-29'].iloc[-1] + df['Birmingham Dead 20-29'].iloc[-1] + df['Leeds Dead 20-29'].iloc[-1]\
    + df['Sheffield Dead 20-29'].iloc[-1] + df['Manchester Dead 20-29'].iloc[-1] + df['Bradford Dead 20-29'].iloc[-1]\
    + df['Liverpool Dead 20-29'].iloc[-1] + df['Bristol Dead 20-29'].iloc[-1]
    dead3039 = df['London Dead 30-39'].iloc[-1] + df['Birmingham Dead 30-39'].iloc[-1] + df['Leeds Dead 30-39'].iloc[-1]\
    + df['Sheffield Dead 30-39'].iloc[-1] + df['Manchester Dead 30-39'].iloc[-1] + df['Bradford Dead 30-39'].iloc[-1]\
    + df['Liverpool Dead 30-39'].iloc[-1] + df['Bristol Dead 30-39'].iloc[-1]
    dead4049 = df['London Dead 40-49'].iloc[-1] + df['Birmingham Dead 40-49'].iloc[-1] + df['Leeds Dead 40-49'].iloc[-1]\
    + df['Sheffield Dead 40-49'].iloc[-1] + df['Manchester Dead 40-49'].iloc[-1] + df['Bradford Dead 40-49'].iloc[-1]\
    + df['Liverpool Dead 40-49'].iloc[-1] + df['Bristol Dead 40-49'].iloc[-1]
    dead5059 = df['London Dead 50-59'].iloc[-1] + df['Birmingham Dead 50-59'].iloc[-1] + df['Leeds Dead 50-59'].iloc[-1]\
    + df['Sheffield Dead 50-59'].iloc[-1] + df['Manchester Dead 50-59'].iloc[-1] + df['Bradford Dead 50-59'].iloc[-1]\
    + df['Liverpool Dead 50-59'].iloc[-1] + df['Bristol Dead 50-59'].iloc[-1]
    dead6069 = df['London Dead 60-69'].iloc[-1] + df['Birmingham Dead 60-69'].iloc[-1] + df['Leeds Dead 60-69'].iloc[-1]\
    + df['Sheffield Dead 60-69'].iloc[-1] + df['Manchester Dead 60-69'].iloc[-1] + df['Bradford Dead 60-69'].iloc[-1]\
    + df['Liverpool Dead 60-69'].iloc[-1] + df['Bristol Dead 60-69'].iloc[-1]
    dead7079 = df['London Dead 70-79'].iloc[-1] + df['Birmingham Dead 70-79'].iloc[-1] + df['Leeds Dead 70-79'].iloc[-1]\
    + df['Sheffield Dead 70-79'].iloc[-1] + df['Manchester Dead 70-79'].iloc[-1] + df['Bradford Dead 70-79'].iloc[-1]\
    + df['Liverpool Dead 70-79'].iloc[-1] + df['Bristol Dead 70-79'].iloc[-1]
    dead8089 = df['London Dead 80-89'].iloc[-1] + df['Birmingham Dead 80-89'].iloc[-1] + df['Leeds Dead 80-89'].iloc[-1]\
    + df['Sheffield Dead 80-89'].iloc[-1] + df['Manchester Dead 80-89'].iloc[-1] + df['Bradford Dead 80-89'].iloc[-1]\
    + df['Liverpool Dead 80-89'].iloc[-1] + df['Bristol Dead 80-89'].iloc[-1]
    dead90 = df['London Dead 90+'].iloc[-1] + df['Birmingham Dead 90+'].iloc[-1] + df['Leeds Dead 90+'].iloc[-1]\
    + df['Sheffield Dead 90+'].iloc[-1] + df['Manchester Dead 90+'].iloc[-1] + df['Bradford Dead 90+'].iloc[-1]\
    + df['Liverpool Dead 90+'].iloc[-1] + df['Bristol Dead 90+'].iloc[-1]
    Total019 = df['London Total 0-19'].iloc[-1] + df['Birmingham Total 0-19'].iloc[-1] + df['Leeds Total 0-19'].iloc[-1]\
    + df['Sheffield Total 0-19'].iloc[-1] + df['Manchester Total 0-19'].iloc[-1] + df['Bradford Total 0-19'].iloc[-1]\
    + df['Liverpool Total 0-19'].iloc[-1] + df['Bristol Total 0-19'].iloc[-1]
    Total2029 = df['London Total 20-29'].iloc[-1] + df['Birmingham Total 20-29'].iloc[-1] + df['Leeds Total 20-29'].iloc[-1]\
    + df['Sheffield Total 20-29'].iloc[-1] + df['Manchester Total 20-29'].iloc[-1] + df['Bradford Total 20-29'].iloc[-1]\
    + df['Liverpool Total 20-29'].iloc[-1] + df['Bristol Total 20-29'].iloc[-1]
    Total3039 = df['London Total 30-39'].iloc[-1] + df['Birmingham Total 30-39'].iloc[-1] + df['Leeds Total 30-39'].iloc[-1]\
    + df['Sheffield Total 30-39'].iloc[-1] + df['Manchester Total 30-39'].iloc[-1] + df['Bradford Total 30-39'].iloc[-1]\
    + df['Liverpool Total 30-39'].iloc[-1] + df['Bristol Total 30-39'].iloc[-1]
    Total4049 = df['London Total 40-49'].iloc[-1] + df['Birmingham Total 40-49'].iloc[-1] + df['Leeds Total 40-49'].iloc[-1]\
    + df['Sheffield Total 40-49'].iloc[-1] + df['Manchester Total 40-49'].iloc[-1] + df['Bradford Total 40-49'].iloc[-1]\
    + df['Liverpool Total 40-49'].iloc[-1] + df['Bristol Total 40-49'].iloc[-1]
    Total5059 = df['London Total 50-59'].iloc[-1] + df['Birmingham Total 50-59'].iloc[-1] + df['Leeds Total 50-59'].iloc[-1]\
    + df['Sheffield Total 50-59'].iloc[-1] + df['Manchester Total 50-59'].iloc[-1] + df['Bradford Total 50-59'].iloc[-1]\
    + df['Liverpool Total 50-59'].iloc[-1] + df['Bristol Total 50-59'].iloc[-1]
    Total6069 = df['London Total 60-69'].iloc[-1] + df['Birmingham Total 60-69'].iloc[-1] + df['Leeds Total 60-69'].iloc[-1]\
    + df['Sheffield Total 60-69'].iloc[-1] + df['Manchester Total 60-69'].iloc[-1] + df['Bradford Total 60-69'].iloc[-1]\
    + df['Liverpool Total 60-69'].iloc[-1] + df['Bristol Total 60-69'].iloc[-1]
    Total7079 = df['London Total 70-79'].iloc[-1] + df['Birmingham Total 70-79'].iloc[-1] + df['Leeds Total 70-79'].iloc[-1]\
    + df['Sheffield Total 70-79'].iloc[-1] + df['Manchester Total 70-79'].iloc[-1] + df['Bradford Total 70-79'].iloc[-1]\
    + df['Liverpool Total 70-79'].iloc[-1] + df['Bristol Total 70-79'].iloc[-1]
    Total8089 = df['London Total 80-89'].iloc[-1] + df['Birmingham Total 80-89'].iloc[-1] + df['Leeds Total 80-89'].iloc[-1]\
    + df['Sheffield Total 80-89'].iloc[-1] + df['Manchester Total 80-89'].iloc[-1] + df['Bradford Total 80-89'].iloc[-1]\
    + df['Liverpool Total 80-89'].iloc[-1] + df['Bristol Total 80-89'].iloc[-1]
    Total90 = df['London Total 90+'].iloc[-1] + df['Birmingham Total 90+'].iloc[-1] + df['Leeds Total 90+'].iloc[-1]\
    + df['Sheffield Total 90+'].iloc[-1] + df['Manchester Total 90+'].iloc[-1] + df['Bradford Total 90+'].iloc[-1]\
    + df['Liverpool Total 90+'].iloc[-1] + df['Bristol Total 90+'].iloc[-1]
    Ilift = df.loc[1050]['I']
    TotCas = df['Total Cases'].iloc[-1]
    TotalCases.append(TotCas)
    Dead.append(dead)
    IPeak.append(Imax)
    PeakTime.append(time)
    Dead019.append(dead019)
    Dead2029.append(dead2029)
    Dead3039.append(dead3039) 
    Dead4049.append(dead4049) 
    Dead5059.append(dead5059) 
    Dead6069.append(dead6069) 
    Dead7079.append(dead7079) 
    Dead8089.append(dead8089) 
    Dead90.append(dead90)
    ILifting.append(Ilift)
print(np.mean(IPeak),u"\u00B1",np.std(IPeak))
print(np.mean(PeakTime),u"\u00B1",np.std(PeakTime))  
print(np.mean(Dead),u"\u00B1",np.std(Dead))
print(np.mean(Dead019),u"\u00B1",np.std(Dead019))
print(np.mean(Dead2029),u"\u00B1",np.std(Dead2029))
print(np.mean(Dead3039),u"\u00B1",np.std(Dead3039))
print(np.mean(Dead4049),u"\u00B1",np.std(Dead4049))
print(np.mean(Dead5059),u"\u00B1",np.std(Dead5059))
print(np.mean(Dead6069),u"\u00B1",np.std(Dead6069))
print(np.mean(Dead7079),u"\u00B1",np.std(Dead7079))
print(np.mean(Dead8089),u"\u00B1",np.std(Dead8089))
print(np.mean(Dead90),u"\u00B1",np.std(Dead90))
print(np.mean(ILifting),u"\u00B1",np.std(ILifting))
IPeak_PCH_35 = np.mean(IPeak)
PeakTime_PCH_35 = np.mean(PeakTime)
Dead_PCH_35 = np.mean(Dead)
Dead019_PCH_35 = np.mean(Dead019)
Dead2029_PCH_35 = np.mean(Dead2029)
Dead3039_PCH_35 = np.mean(Dead3039)
Dead4049_PCH_35 = np.mean(Dead4049)
Dead5059_PCH_35 = np.mean(Dead5059)
Dead6069_PCH_35 = np.mean(Dead6069)
Dead7079_PCH_35 = np.mean(Dead7079)
Dead8089_PCH_35 = np.mean(Dead8089)
Dead90_PCH_35 = np.mean(Dead90)
ILifting_PCH_35 = np.mean(ILifting)
IPeak_PCH_35_Err = np.std(IPeak)
PeakTime_PCH_35_Err = np.std(PeakTime)
Dead_PCH_35_Err = np.std(Dead)
Dead019_PCH_35_Err = np.std(Dead019)
Dead2029_PCH_35_Err = np.std(Dead2029)
Dead3039_PCH_35_Err = np.std(Dead3039)
Dead4049_PCH_35_Err = np.std(Dead4049)
Dead5059_PCH_35_Err = np.std(Dead5059)
Dead6069_PCH_35_Err = np.std(Dead6069)
Dead7079_PCH_35_Err = np.std(Dead7079)
Dead8089_PCH_35_Err = np.std(Dead8089)
Dead90_PCH_35_Err = np.std(Dead90)
ILifting_PCH_35_Err = np.std(ILifting)
PeakTimeArray_PCH_35 = PeakTime
TotalCases_PCH_35 = np.mean(TotalCases)
TotalCases_PCH_35_Err = np.std(TotalCases)
Total019_PCH_35 = np.mean(Total019)
Total2029_PCH_35 = np.mean(Total2029)
Total3039_PCH_35 = np.mean(Total3039)
Total4049_PCH_35 = np.mean(Total4049)
Total5059_PCH_35 = np.mean(Total5059)
Total6069_PCH_35 = np.mean(Total6069)
Total7079_PCH_35 = np.mean(Total7079)
Total8089_PCH_35 = np.mean(Total8089)
Total90_PCH_35 = np.mean(Total90)
Total019_PCH_35_Err = np.std(Total019)
Total2029_PCH_35_Err = np.std(Total2029)
Total3039_PCH_35_Err = np.std(Total3039)
Total4049_PCH_35_Err = np.std(Total4049)
Total5059_PCH_35_Err = np.std(Total5059)
Total6069_PCH_35_Err = np.std(Total6069)
Total7079_PCH_35_Err = np.std(Total7079)
Total8089_PCH_35_Err = np.std(Total8089)
Total90_PCH_35_Err = np.std(Total90)
# Out:
# 3280962.79 ± 19026.62533729773
# 61.804000000000016 ± 1.2925107349650904
# 97847.17 ± 339.4398342858422
# 762.18 ± 30.505861731804924
# 716.53 ± 29.071104210194697
# 2441.67 ± 49.64051873218087
# 8837.53 ± 92.05579340812831
# 18157.64 ± 130.05687371300294
# 30545.82 ± 181.2563587850092
# 26631.76 ± 178.00298424464688
# 8638.02 ± 88.27898730728622
# 1116.02 ± 31.888863259765156
# 78724.37 ± 11419.395046722046

# %%
#PopnChanged R = 3.25
IPeak = []
PeakTime = []
Dead = []
Dead019 = []
Dead2029 = []
Dead3039 = []
Dead4049 = []
Dead5059 = []
Dead6069 = []
Dead7079 = []
Dead8089 = []
Dead90 = []
ILifting = []
TotalCases = []
Total019 = []
Total2029 = []
Total3039 = []
Total4049 = []
Total5059 = []
Total6069 = []
Total7079 = []
Total8089 = []
Total90 = []
z = 1.960
for i in range(1,101):
    df = pd.read_csv (r'E:\Users\Michael\Project Notebook\Sim Data\PopnChanged\3.25\PopnChanged_R3.25_{}.csv'.format(i))
    Imax = pd.DataFrame.max(df['I'])
    time = pd.DataFrame.max(df.loc[df['I'] == Imax]['t'])
    dead = df['D'].iloc[-1]
    dead019 = df['London Dead 0-19'].iloc[-1] + df['Birmingham Dead 0-19'].iloc[-1] + df['Leeds Dead 0-19'].iloc[-1]\
    + df['Sheffield Dead 0-19'].iloc[-1] + df['Manchester Dead 0-19'].iloc[-1] + df['Bradford Dead 0-19'].iloc[-1]\
    + df['Liverpool Dead 0-19'].iloc[-1] + df['Bristol Dead 0-19'].iloc[-1]
    dead2029 = df['London Dead 20-29'].iloc[-1] + df['Birmingham Dead 20-29'].iloc[-1] + df['Leeds Dead 20-29'].iloc[-1]\
    + df['Sheffield Dead 20-29'].iloc[-1] + df['Manchester Dead 20-29'].iloc[-1] + df['Bradford Dead 20-29'].iloc[-1]\
    + df['Liverpool Dead 20-29'].iloc[-1] + df['Bristol Dead 20-29'].iloc[-1]
    dead3039 = df['London Dead 30-39'].iloc[-1] + df['Birmingham Dead 30-39'].iloc[-1] + df['Leeds Dead 30-39'].iloc[-1]\
    + df['Sheffield Dead 30-39'].iloc[-1] + df['Manchester Dead 30-39'].iloc[-1] + df['Bradford Dead 30-39'].iloc[-1]\
    + df['Liverpool Dead 30-39'].iloc[-1] + df['Bristol Dead 30-39'].iloc[-1]
    dead4049 = df['London Dead 40-49'].iloc[-1] + df['Birmingham Dead 40-49'].iloc[-1] + df['Leeds Dead 40-49'].iloc[-1]\
    + df['Sheffield Dead 40-49'].iloc[-1] + df['Manchester Dead 40-49'].iloc[-1] + df['Bradford Dead 40-49'].iloc[-1]\
    + df['Liverpool Dead 40-49'].iloc[-1] + df['Bristol Dead 40-49'].iloc[-1]
    dead5059 = df['London Dead 50-59'].iloc[-1] + df['Birmingham Dead 50-59'].iloc[-1] + df['Leeds Dead 50-59'].iloc[-1]\
    + df['Sheffield Dead 50-59'].iloc[-1] + df['Manchester Dead 50-59'].iloc[-1] + df['Bradford Dead 50-59'].iloc[-1]\
    + df['Liverpool Dead 50-59'].iloc[-1] + df['Bristol Dead 50-59'].iloc[-1]
    dead6069 = df['London Dead 60-69'].iloc[-1] + df['Birmingham Dead 60-69'].iloc[-1] + df['Leeds Dead 60-69'].iloc[-1]\
    + df['Sheffield Dead 60-69'].iloc[-1] + df['Manchester Dead 60-69'].iloc[-1] + df['Bradford Dead 60-69'].iloc[-1]\
    + df['Liverpool Dead 60-69'].iloc[-1] + df['Bristol Dead 60-69'].iloc[-1]
    dead7079 = df['London Dead 70-79'].iloc[-1] + df['Birmingham Dead 70-79'].iloc[-1] + df['Leeds Dead 70-79'].iloc[-1]\
    + df['Sheffield Dead 70-79'].iloc[-1] + df['Manchester Dead 70-79'].iloc[-1] + df['Bradford Dead 70-79'].iloc[-1]\
    + df['Liverpool Dead 70-79'].iloc[-1] + df['Bristol Dead 70-79'].iloc[-1]
    dead8089 = df['London Dead 80-89'].iloc[-1] + df['Birmingham Dead 80-89'].iloc[-1] + df['Leeds Dead 80-89'].iloc[-1]\
    + df['Sheffield Dead 80-89'].iloc[-1] + df['Manchester Dead 80-89'].iloc[-1] + df['Bradford Dead 80-89'].iloc[-1]\
    + df['Liverpool Dead 80-89'].iloc[-1] + df['Bristol Dead 80-89'].iloc[-1]
    dead90 = df['London Dead 90+'].iloc[-1] + df['Birmingham Dead 90+'].iloc[-1] + df['Leeds Dead 90+'].iloc[-1]\
    + df['Sheffield Dead 90+'].iloc[-1] + df['Manchester Dead 90+'].iloc[-1] + df['Bradford Dead 90+'].iloc[-1]\
    + df['Liverpool Dead 90+'].iloc[-1] + df['Bristol Dead 90+'].iloc[-1]
    Total019 = df['London Total 0-19'].iloc[-1] + df['Birmingham Total 0-19'].iloc[-1] + df['Leeds Total 0-19'].iloc[-1]\
    + df['Sheffield Total 0-19'].iloc[-1] + df['Manchester Total 0-19'].iloc[-1] + df['Bradford Total 0-19'].iloc[-1]\
    + df['Liverpool Total 0-19'].iloc[-1] + df['Bristol Total 0-19'].iloc[-1]
    Total2029 = df['London Total 20-29'].iloc[-1] + df['Birmingham Total 20-29'].iloc[-1] + df['Leeds Total 20-29'].iloc[-1]\
    + df['Sheffield Total 20-29'].iloc[-1] + df['Manchester Total 20-29'].iloc[-1] + df['Bradford Total 20-29'].iloc[-1]\
    + df['Liverpool Total 20-29'].iloc[-1] + df['Bristol Total 20-29'].iloc[-1]
    Total3039 = df['London Total 30-39'].iloc[-1] + df['Birmingham Total 30-39'].iloc[-1] + df['Leeds Total 30-39'].iloc[-1]\
    + df['Sheffield Total 30-39'].iloc[-1] + df['Manchester Total 30-39'].iloc[-1] + df['Bradford Total 30-39'].iloc[-1]\
    + df['Liverpool Total 30-39'].iloc[-1] + df['Bristol Total 30-39'].iloc[-1]
    Total4049 = df['London Total 40-49'].iloc[-1] + df['Birmingham Total 40-49'].iloc[-1] + df['Leeds Total 40-49'].iloc[-1]\
    + df['Sheffield Total 40-49'].iloc[-1] + df['Manchester Total 40-49'].iloc[-1] + df['Bradford Total 40-49'].iloc[-1]\
    + df['Liverpool Total 40-49'].iloc[-1] + df['Bristol Total 40-49'].iloc[-1]
    Total5059 = df['London Total 50-59'].iloc[-1] + df['Birmingham Total 50-59'].iloc[-1] + df['Leeds Total 50-59'].iloc[-1]\
    + df['Sheffield Total 50-59'].iloc[-1] + df['Manchester Total 50-59'].iloc[-1] + df['Bradford Total 50-59'].iloc[-1]\
    + df['Liverpool Total 50-59'].iloc[-1] + df['Bristol Total 50-59'].iloc[-1]
    Total6069 = df['London Total 60-69'].iloc[-1] + df['Birmingham Total 60-69'].iloc[-1] + df['Leeds Total 60-69'].iloc[-1]\
    + df['Sheffield Total 60-69'].iloc[-1] + df['Manchester Total 60-69'].iloc[-1] + df['Bradford Total 60-69'].iloc[-1]\
    + df['Liverpool Total 60-69'].iloc[-1] + df['Bristol Total 60-69'].iloc[-1]
    Total7079 = df['London Total 70-79'].iloc[-1] + df['Birmingham Total 70-79'].iloc[-1] + df['Leeds Total 70-79'].iloc[-1]\
    + df['Sheffield Total 70-79'].iloc[-1] + df['Manchester Total 70-79'].iloc[-1] + df['Bradford Total 70-79'].iloc[-1]\
    + df['Liverpool Total 70-79'].iloc[-1] + df['Bristol Total 70-79'].iloc[-1]
    Total8089 = df['London Total 80-89'].iloc[-1] + df['Birmingham Total 80-89'].iloc[-1] + df['Leeds Total 80-89'].iloc[-1]\
    + df['Sheffield Total 80-89'].iloc[-1] + df['Manchester Total 80-89'].iloc[-1] + df['Bradford Total 80-89'].iloc[-1]\
    + df['Liverpool Total 80-89'].iloc[-1] + df['Bristol Total 80-89'].iloc[-1]
    Total90 = df['London Total 90+'].iloc[-1] + df['Birmingham Total 90+'].iloc[-1] + df['Leeds Total 90+'].iloc[-1]\
    + df['Sheffield Total 90+'].iloc[-1] + df['Manchester Total 90+'].iloc[-1] + df['Bradford Total 90+'].iloc[-1]\
    + df['Liverpool Total 90+'].iloc[-1] + df['Bristol Total 90+'].iloc[-1]
    Ilift = df.loc[1050]['I']
    TotCas = df['Total Cases'].iloc[-1]
    TotalCases.append(TotCas)
    Dead.append(dead)
    IPeak.append(Imax)
    PeakTime.append(time)
    Dead019.append(dead019)
    Dead2029.append(dead2029)
    Dead3039.append(dead3039) 
    Dead4049.append(dead4049) 
    Dead5059.append(dead5059) 
    Dead6069.append(dead6069) 
    Dead7079.append(dead7079) 
    Dead8089.append(dead8089) 
    Dead90.append(dead90)
    ILifting.append(Ilift)
print(np.mean(IPeak),u"\u00B1",np.std(IPeak))
print(np.mean(PeakTime),u"\u00B1",np.std(PeakTime))  
print(np.mean(Dead),u"\u00B1",np.std(Dead))
print(np.mean(Dead019),u"\u00B1",np.std(Dead019))
print(np.mean(Dead2029),u"\u00B1",np.std(Dead2029))
print(np.mean(Dead3039),u"\u00B1",np.std(Dead3039))
print(np.mean(Dead4049),u"\u00B1",np.std(Dead4049))
print(np.mean(Dead5059),u"\u00B1",np.std(Dead5059))
print(np.mean(Dead6069),u"\u00B1",np.std(Dead6069))
print(np.mean(Dead7079),u"\u00B1",np.std(Dead7079))
print(np.mean(Dead8089),u"\u00B1",np.std(Dead8089))
print(np.mean(Dead90),u"\u00B1",np.std(Dead90))
print(np.mean(ILifting),u"\u00B1",np.std(ILifting))
IPeak_PCH_325 = np.mean(IPeak)
PeakTime_PCH_325 = np.mean(PeakTime)
Dead_PCH_325 = np.mean(Dead)
Dead019_PCH_325 = np.mean(Dead019)
Dead2029_PCH_325 = np.mean(Dead2029)
Dead3039_PCH_325 = np.mean(Dead3039)
Dead4049_PCH_325 = np.mean(Dead4049)
Dead5059_PCH_325 = np.mean(Dead5059)
Dead6069_PCH_325 = np.mean(Dead6069)
Dead7079_PCH_325 = np.mean(Dead7079)
Dead8089_PCH_325 = np.mean(Dead8089)
Dead90_PCH_325 = np.mean(Dead90)
ILifting_PCH_325 = np.mean(ILifting)
IPeak_PCH_325_Err = np.std(IPeak)
PeakTime_PCH_325_Err = np.std(PeakTime)
Dead_PCH_325_Err = np.std(Dead)
Dead019_PCH_325_Err = np.std(Dead019)
Dead2029_PCH_325_Err = np.std(Dead2029)
Dead3039_PCH_325_Err = np.std(Dead3039)
Dead4049_PCH_325_Err = np.std(Dead4049)
Dead5059_PCH_325_Err = np.std(Dead5059)
Dead6069_PCH_325_Err = np.std(Dead6069)
Dead7079_PCH_325_Err = np.std(Dead7079)
Dead8089_PCH_325_Err = np.std(Dead8089)
Dead90_PCH_325_Err = np.std(Dead90)
ILifting_PCH_325_Err = np.std(ILifting)
PeakTimeArray_PCH_325 = PeakTime
TotalCases_PCH_325 = np.mean(TotalCases)
TotalCases_PCH_325_Err = np.std(TotalCases)
Total019_PCH_325 = np.mean(Total019)
Total2029_PCH_325 = np.mean(Total2029)
Total3039_PCH_325 = np.mean(Total3039)
Total4049_PCH_325 = np.mean(Total4049)
Total5059_PCH_325 = np.mean(Total5059)
Total6069_PCH_325 = np.mean(Total6069)
Total7079_PCH_325 = np.mean(Total7079)
Total8089_PCH_325 = np.mean(Total8089)
Total90_PCH_325 = np.mean(Total90)
Total019_PCH_325_Err = np.std(Total019)
Total2029_PCH_325_Err = np.std(Total2029)
Total3039_PCH_325_Err = np.std(Total3039)
Total4049_PCH_325_Err = np.std(Total4049)
Total5059_PCH_325_Err = np.std(Total5059)
Total6069_PCH_325_Err = np.std(Total6069)
Total7079_PCH_325_Err = np.std(Total7079)
Total8089_PCH_325_Err = np.std(Total8089)
Total90_PCH_325_Err = np.std(Total90)
# Out:
# 3074816.63 ± 17634.916439640423
# 67.20100000000001 ± 1.5426921274188181
# 93484.22 ± 293.63860713468864
# 754.81 ± 25.535346091251633
# 705.06 ± 25.0398961659189
# 2411.16 ± 50.940106006956846
# 8768.51 ± 93.80836796363104
# 17747.63 ± 123.45441709392176
# 29064.2 ± 175.386259438988
# 24905.23 ± 146.27705595888918
# 8081.92 ± 76.63885176592875
# 1045.7 ± 30.216717227389214
# 158326.38 ± 28025.71199052042

# %%
#PopnChanged R = 3
IPeak = []
PeakTime = []
Dead = []
Dead019 = []
Dead2029 = []
Dead3039 = []
Dead4049 = []
Dead5059 = []
Dead6069 = []
Dead7079 = []
Dead8089 = []
Dead90 = []
ILifting = []
TotalCases = []
Total019 = []
Total2029 = []
Total3039 = []
Total4049 = []
Total5059 = []
Total6069 = []
Total7079 = []
Total8089 = []
Total90 = []
z = 1.960
for i in range(1,101):
    df = pd.read_csv (r'E:\Users\Michael\Project Notebook\Sim Data\PopnChanged\3\PopnChanged_R3_{}.csv'.format(i))
    Imax = pd.DataFrame.max(df['I'])
    time = pd.DataFrame.max(df.loc[df['I'] == Imax]['t'])
    dead = df['D'].iloc[-1]
    dead019 = df['London Dead 0-19'].iloc[-1] + df['Birmingham Dead 0-19'].iloc[-1] + df['Leeds Dead 0-19'].iloc[-1]\
    + df['Sheffield Dead 0-19'].iloc[-1] + df['Manchester Dead 0-19'].iloc[-1] + df['Bradford Dead 0-19'].iloc[-1]\
    + df['Liverpool Dead 0-19'].iloc[-1] + df['Bristol Dead 0-19'].iloc[-1]
    dead2029 = df['London Dead 20-29'].iloc[-1] + df['Birmingham Dead 20-29'].iloc[-1] + df['Leeds Dead 20-29'].iloc[-1]\
    + df['Sheffield Dead 20-29'].iloc[-1] + df['Manchester Dead 20-29'].iloc[-1] + df['Bradford Dead 20-29'].iloc[-1]\
    + df['Liverpool Dead 20-29'].iloc[-1] + df['Bristol Dead 20-29'].iloc[-1]
    dead3039 = df['London Dead 30-39'].iloc[-1] + df['Birmingham Dead 30-39'].iloc[-1] + df['Leeds Dead 30-39'].iloc[-1]\
    + df['Sheffield Dead 30-39'].iloc[-1] + df['Manchester Dead 30-39'].iloc[-1] + df['Bradford Dead 30-39'].iloc[-1]\
    + df['Liverpool Dead 30-39'].iloc[-1] + df['Bristol Dead 30-39'].iloc[-1]
    dead4049 = df['London Dead 40-49'].iloc[-1] + df['Birmingham Dead 40-49'].iloc[-1] + df['Leeds Dead 40-49'].iloc[-1]\
    + df['Sheffield Dead 40-49'].iloc[-1] + df['Manchester Dead 40-49'].iloc[-1] + df['Bradford Dead 40-49'].iloc[-1]\
    + df['Liverpool Dead 40-49'].iloc[-1] + df['Bristol Dead 40-49'].iloc[-1]
    dead5059 = df['London Dead 50-59'].iloc[-1] + df['Birmingham Dead 50-59'].iloc[-1] + df['Leeds Dead 50-59'].iloc[-1]\
    + df['Sheffield Dead 50-59'].iloc[-1] + df['Manchester Dead 50-59'].iloc[-1] + df['Bradford Dead 50-59'].iloc[-1]\
    + df['Liverpool Dead 50-59'].iloc[-1] + df['Bristol Dead 50-59'].iloc[-1]
    dead6069 = df['London Dead 60-69'].iloc[-1] + df['Birmingham Dead 60-69'].iloc[-1] + df['Leeds Dead 60-69'].iloc[-1]\
    + df['Sheffield Dead 60-69'].iloc[-1] + df['Manchester Dead 60-69'].iloc[-1] + df['Bradford Dead 60-69'].iloc[-1]\
    + df['Liverpool Dead 60-69'].iloc[-1] + df['Bristol Dead 60-69'].iloc[-1]
    dead7079 = df['London Dead 70-79'].iloc[-1] + df['Birmingham Dead 70-79'].iloc[-1] + df['Leeds Dead 70-79'].iloc[-1]\
    + df['Sheffield Dead 70-79'].iloc[-1] + df['Manchester Dead 70-79'].iloc[-1] + df['Bradford Dead 70-79'].iloc[-1]\
    + df['Liverpool Dead 70-79'].iloc[-1] + df['Bristol Dead 70-79'].iloc[-1]
    dead8089 = df['London Dead 80-89'].iloc[-1] + df['Birmingham Dead 80-89'].iloc[-1] + df['Leeds Dead 80-89'].iloc[-1]\
    + df['Sheffield Dead 80-89'].iloc[-1] + df['Manchester Dead 80-89'].iloc[-1] + df['Bradford Dead 80-89'].iloc[-1]\
    + df['Liverpool Dead 80-89'].iloc[-1] + df['Bristol Dead 80-89'].iloc[-1]
    dead90 = df['London Dead 90+'].iloc[-1] + df['Birmingham Dead 90+'].iloc[-1] + df['Leeds Dead 90+'].iloc[-1]\
    + df['Sheffield Dead 90+'].iloc[-1] + df['Manchester Dead 90+'].iloc[-1] + df['Bradford Dead 90+'].iloc[-1]\
    + df['Liverpool Dead 90+'].iloc[-1] + df['Bristol Dead 90+'].iloc[-1]
    Total019 = df['London Total 0-19'].iloc[-1] + df['Birmingham Total 0-19'].iloc[-1] + df['Leeds Total 0-19'].iloc[-1]\
    + df['Sheffield Total 0-19'].iloc[-1] + df['Manchester Total 0-19'].iloc[-1] + df['Bradford Total 0-19'].iloc[-1]\
    + df['Liverpool Total 0-19'].iloc[-1] + df['Bristol Total 0-19'].iloc[-1]
    Total2029 = df['London Total 20-29'].iloc[-1] + df['Birmingham Total 20-29'].iloc[-1] + df['Leeds Total 20-29'].iloc[-1]\
    + df['Sheffield Total 20-29'].iloc[-1] + df['Manchester Total 20-29'].iloc[-1] + df['Bradford Total 20-29'].iloc[-1]\
    + df['Liverpool Total 20-29'].iloc[-1] + df['Bristol Total 20-29'].iloc[-1]
    Total3039 = df['London Total 30-39'].iloc[-1] + df['Birmingham Total 30-39'].iloc[-1] + df['Leeds Total 30-39'].iloc[-1]\
    + df['Sheffield Total 30-39'].iloc[-1] + df['Manchester Total 30-39'].iloc[-1] + df['Bradford Total 30-39'].iloc[-1]\
    + df['Liverpool Total 30-39'].iloc[-1] + df['Bristol Total 30-39'].iloc[-1]
    Total4049 = df['London Total 40-49'].iloc[-1] + df['Birmingham Total 40-49'].iloc[-1] + df['Leeds Total 40-49'].iloc[-1]\
    + df['Sheffield Total 40-49'].iloc[-1] + df['Manchester Total 40-49'].iloc[-1] + df['Bradford Total 40-49'].iloc[-1]\
    + df['Liverpool Total 40-49'].iloc[-1] + df['Bristol Total 40-49'].iloc[-1]
    Total5059 = df['London Total 50-59'].iloc[-1] + df['Birmingham Total 50-59'].iloc[-1] + df['Leeds Total 50-59'].iloc[-1]\
    + df['Sheffield Total 50-59'].iloc[-1] + df['Manchester Total 50-59'].iloc[-1] + df['Bradford Total 50-59'].iloc[-1]\
    + df['Liverpool Total 50-59'].iloc[-1] + df['Bristol Total 50-59'].iloc[-1]
    Total6069 = df['London Total 60-69'].iloc[-1] + df['Birmingham Total 60-69'].iloc[-1] + df['Leeds Total 60-69'].iloc[-1]\
    + df['Sheffield Total 60-69'].iloc[-1] + df['Manchester Total 60-69'].iloc[-1] + df['Bradford Total 60-69'].iloc[-1]\
    + df['Liverpool Total 60-69'].iloc[-1] + df['Bristol Total 60-69'].iloc[-1]
    Total7079 = df['London Total 70-79'].iloc[-1] + df['Birmingham Total 70-79'].iloc[-1] + df['Leeds Total 70-79'].iloc[-1]\
    + df['Sheffield Total 70-79'].iloc[-1] + df['Manchester Total 70-79'].iloc[-1] + df['Bradford Total 70-79'].iloc[-1]\
    + df['Liverpool Total 70-79'].iloc[-1] + df['Bristol Total 70-79'].iloc[-1]
    Total8089 = df['London Total 80-89'].iloc[-1] + df['Birmingham Total 80-89'].iloc[-1] + df['Leeds Total 80-89'].iloc[-1]\
    + df['Sheffield Total 80-89'].iloc[-1] + df['Manchester Total 80-89'].iloc[-1] + df['Bradford Total 80-89'].iloc[-1]\
    + df['Liverpool Total 80-89'].iloc[-1] + df['Bristol Total 80-89'].iloc[-1]
    Total90 = df['London Total 90+'].iloc[-1] + df['Birmingham Total 90+'].iloc[-1] + df['Leeds Total 90+'].iloc[-1]\
    + df['Sheffield Total 90+'].iloc[-1] + df['Manchester Total 90+'].iloc[-1] + df['Bradford Total 90+'].iloc[-1]\
    + df['Liverpool Total 90+'].iloc[-1] + df['Bristol Total 90+'].iloc[-1]
    Ilift = df.loc[1050]['I']
    TotCas = df['Total Cases'].iloc[-1]
    TotalCases.append(TotCas)
    Dead.append(dead)
    IPeak.append(Imax)
    PeakTime.append(time)
    Dead019.append(dead019)
    Dead2029.append(dead2029)
    Dead3039.append(dead3039) 
    Dead4049.append(dead4049) 
    Dead5059.append(dead5059) 
    Dead6069.append(dead6069) 
    Dead7079.append(dead7079) 
    Dead8089.append(dead8089) 
    Dead90.append(dead90)
    ILifting.append(Ilift)
print(np.mean(IPeak),u"\u00B1",np.std(IPeak))
print(np.mean(PeakTime),u"\u00B1",np.std(PeakTime))  
print(np.mean(Dead),u"\u00B1",np.std(Dead))
print(np.mean(Dead019),u"\u00B1",np.std(Dead019))
print(np.mean(Dead2029),u"\u00B1",np.std(Dead2029))
print(np.mean(Dead3039),u"\u00B1",np.std(Dead3039))
print(np.mean(Dead4049),u"\u00B1",np.std(Dead4049))
print(np.mean(Dead5059),u"\u00B1",np.std(Dead5059))
print(np.mean(Dead6069),u"\u00B1",np.std(Dead6069))
print(np.mean(Dead7079),u"\u00B1",np.std(Dead7079))
print(np.mean(Dead8089),u"\u00B1",np.std(Dead8089))
print(np.mean(Dead90),u"\u00B1",np.std(Dead90))
print(np.mean(ILifting),u"\u00B1",np.std(ILifting))
IPeak_PCH_3 = np.mean(IPeak)
PeakTime_PCH_3 = np.mean(PeakTime)
Dead_PCH_3 = np.mean(Dead)
Dead019_PCH_3 = np.mean(Dead019)
Dead2029_PCH_3 = np.mean(Dead2029)
Dead3039_PCH_3 = np.mean(Dead3039)
Dead4049_PCH_3 = np.mean(Dead4049)
Dead5059_PCH_3 = np.mean(Dead5059)
Dead6069_PCH_3 = np.mean(Dead6069)
Dead7079_PCH_3 = np.mean(Dead7079)
Dead8089_PCH_3 = np.mean(Dead8089)
Dead90_PCH_3 = np.mean(Dead90)
ILifting_PCH_3 = np.mean(ILifting)
IPeak_PCH_3_Err = np.std(IPeak)
PeakTime_PCH_3_Err = np.std(PeakTime)
Dead_PCH_3_Err = np.std(Dead)
Dead019_PCH_3_Err = np.std(Dead019)
Dead2029_PCH_3_Err = np.std(Dead2029)
Dead3039_PCH_3_Err = np.std(Dead3039)
Dead4049_PCH_3_Err = np.std(Dead4049)
Dead5059_PCH_3_Err = np.std(Dead5059)
Dead6069_PCH_3_Err = np.std(Dead6069)
Dead7079_PCH_3_Err = np.std(Dead7079)
Dead8089_PCH_3_Err = np.std(Dead8089)
Dead90_PCH_3_Err = np.std(Dead90)
ILifting_PCH_3_Err = np.std(ILifting)
PeakTimeArray_PCH_3 = PeakTime
TotalCases_PCH_3 = np.mean(TotalCases)
TotalCases_PCH_3_Err = np.std(TotalCases)
Total019_PCH_3 = np.mean(Total019)
Total2029_PCH_3 = np.mean(Total2029)
Total3039_PCH_3 = np.mean(Total3039)
Total4049_PCH_3 = np.mean(Total4049)
Total5059_PCH_3 = np.mean(Total5059)
Total6069_PCH_3 = np.mean(Total6069)
Total7079_PCH_3 = np.mean(Total7079)
Total8089_PCH_3 = np.mean(Total8089)
Total90_PCH_3 = np.mean(Total90)
Total019_PCH_3_Err = np.std(Total019)
Total2029_PCH_3_Err = np.std(Total2029)
Total3039_PCH_3_Err = np.std(Total3039)
Total4049_PCH_3_Err = np.std(Total4049)
Total5059_PCH_3_Err = np.std(Total5059)
Total6069_PCH_3_Err = np.std(Total6069)
Total7079_PCH_3_Err = np.std(Total7079)
Total8089_PCH_3_Err = np.std(Total8089)
Total90_PCH_3_Err = np.std(Total90)
# Out:
# 2841924.06 ± 17513.673299350994
# 73.688 ± 1.6048850426120873
# 88719.21 ± 291.7166191700432
# 752.55 ± 28.514338498376567
# 699.0 ± 24.698178070456937
# 2403.88 ± 48.29726286240246
# 8676.67 ± 75.8671279277132
# 17247.38 ± 122.34727459163118
# 27414.1 ± 159.12652198800802
# 23073.88 ± 164.96558913906864
# 7484.93 ± 86.46354781062364
# 966.82 ± 28.976673377045884
# 336323.87 ± 57199.2452533519

# %%
#PopnChanged R = 2.75
IPeak = []
PeakTime = []
Dead = []
Dead019 = []
Dead2029 = []
Dead3039 = []
Dead4049 = []
Dead5059 = []
Dead6069 = []
Dead7079 = []
Dead8089 = []
Dead90 = []
ILifting = []
TotalCases = []
Total019 = []
Total2029 = []
Total3039 = []
Total4049 = []
Total5059 = []
Total6069 = []
Total7079 = []
Total8089 = []
Total90 = []
z = 1.960
for i in range(1,101):
    df = pd.read_csv (r'E:\Users\Michael\Project Notebook\Sim Data\PopnChanged\2.75\PopnChanged_R2.75_{}.csv'.format(i))
    Imax = pd.DataFrame.max(df['I'])
    time = pd.DataFrame.max(df.loc[df['I'] == Imax]['t'])
    dead = df['D'].iloc[-1]
    dead019 = df['London Dead 0-19'].iloc[-1] + df['Birmingham Dead 0-19'].iloc[-1] + df['Leeds Dead 0-19'].iloc[-1]\
    + df['Sheffield Dead 0-19'].iloc[-1] + df['Manchester Dead 0-19'].iloc[-1] + df['Bradford Dead 0-19'].iloc[-1]\
    + df['Liverpool Dead 0-19'].iloc[-1] + df['Bristol Dead 0-19'].iloc[-1]
    dead2029 = df['London Dead 20-29'].iloc[-1] + df['Birmingham Dead 20-29'].iloc[-1] + df['Leeds Dead 20-29'].iloc[-1]\
    + df['Sheffield Dead 20-29'].iloc[-1] + df['Manchester Dead 20-29'].iloc[-1] + df['Bradford Dead 20-29'].iloc[-1]\
    + df['Liverpool Dead 20-29'].iloc[-1] + df['Bristol Dead 20-29'].iloc[-1]
    dead3039 = df['London Dead 30-39'].iloc[-1] + df['Birmingham Dead 30-39'].iloc[-1] + df['Leeds Dead 30-39'].iloc[-1]\
    + df['Sheffield Dead 30-39'].iloc[-1] + df['Manchester Dead 30-39'].iloc[-1] + df['Bradford Dead 30-39'].iloc[-1]\
    + df['Liverpool Dead 30-39'].iloc[-1] + df['Bristol Dead 30-39'].iloc[-1]
    dead4049 = df['London Dead 40-49'].iloc[-1] + df['Birmingham Dead 40-49'].iloc[-1] + df['Leeds Dead 40-49'].iloc[-1]\
    + df['Sheffield Dead 40-49'].iloc[-1] + df['Manchester Dead 40-49'].iloc[-1] + df['Bradford Dead 40-49'].iloc[-1]\
    + df['Liverpool Dead 40-49'].iloc[-1] + df['Bristol Dead 40-49'].iloc[-1]
    dead5059 = df['London Dead 50-59'].iloc[-1] + df['Birmingham Dead 50-59'].iloc[-1] + df['Leeds Dead 50-59'].iloc[-1]\
    + df['Sheffield Dead 50-59'].iloc[-1] + df['Manchester Dead 50-59'].iloc[-1] + df['Bradford Dead 50-59'].iloc[-1]\
    + df['Liverpool Dead 50-59'].iloc[-1] + df['Bristol Dead 50-59'].iloc[-1]
    dead6069 = df['London Dead 60-69'].iloc[-1] + df['Birmingham Dead 60-69'].iloc[-1] + df['Leeds Dead 60-69'].iloc[-1]\
    + df['Sheffield Dead 60-69'].iloc[-1] + df['Manchester Dead 60-69'].iloc[-1] + df['Bradford Dead 60-69'].iloc[-1]\
    + df['Liverpool Dead 60-69'].iloc[-1] + df['Bristol Dead 60-69'].iloc[-1]
    dead7079 = df['London Dead 70-79'].iloc[-1] + df['Birmingham Dead 70-79'].iloc[-1] + df['Leeds Dead 70-79'].iloc[-1]\
    + df['Sheffield Dead 70-79'].iloc[-1] + df['Manchester Dead 70-79'].iloc[-1] + df['Bradford Dead 70-79'].iloc[-1]\
    + df['Liverpool Dead 70-79'].iloc[-1] + df['Bristol Dead 70-79'].iloc[-1]
    dead8089 = df['London Dead 80-89'].iloc[-1] + df['Birmingham Dead 80-89'].iloc[-1] + df['Leeds Dead 80-89'].iloc[-1]\
    + df['Sheffield Dead 80-89'].iloc[-1] + df['Manchester Dead 80-89'].iloc[-1] + df['Bradford Dead 80-89'].iloc[-1]\
    + df['Liverpool Dead 80-89'].iloc[-1] + df['Bristol Dead 80-89'].iloc[-1]
    dead90 = df['London Dead 90+'].iloc[-1] + df['Birmingham Dead 90+'].iloc[-1] + df['Leeds Dead 90+'].iloc[-1]\
    + df['Sheffield Dead 90+'].iloc[-1] + df['Manchester Dead 90+'].iloc[-1] + df['Bradford Dead 90+'].iloc[-1]\
    + df['Liverpool Dead 90+'].iloc[-1] + df['Bristol Dead 90+'].iloc[-1]
    Total019 = df['London Total 0-19'].iloc[-1] + df['Birmingham Total 0-19'].iloc[-1] + df['Leeds Total 0-19'].iloc[-1]\
    + df['Sheffield Total 0-19'].iloc[-1] + df['Manchester Total 0-19'].iloc[-1] + df['Bradford Total 0-19'].iloc[-1]\
    + df['Liverpool Total 0-19'].iloc[-1] + df['Bristol Total 0-19'].iloc[-1]
    Total2029 = df['London Total 20-29'].iloc[-1] + df['Birmingham Total 20-29'].iloc[-1] + df['Leeds Total 20-29'].iloc[-1]\
    + df['Sheffield Total 20-29'].iloc[-1] + df['Manchester Total 20-29'].iloc[-1] + df['Bradford Total 20-29'].iloc[-1]\
    + df['Liverpool Total 20-29'].iloc[-1] + df['Bristol Total 20-29'].iloc[-1]
    Total3039 = df['London Total 30-39'].iloc[-1] + df['Birmingham Total 30-39'].iloc[-1] + df['Leeds Total 30-39'].iloc[-1]\
    + df['Sheffield Total 30-39'].iloc[-1] + df['Manchester Total 30-39'].iloc[-1] + df['Bradford Total 30-39'].iloc[-1]\
    + df['Liverpool Total 30-39'].iloc[-1] + df['Bristol Total 30-39'].iloc[-1]
    Total4049 = df['London Total 40-49'].iloc[-1] + df['Birmingham Total 40-49'].iloc[-1] + df['Leeds Total 40-49'].iloc[-1]\
    + df['Sheffield Total 40-49'].iloc[-1] + df['Manchester Total 40-49'].iloc[-1] + df['Bradford Total 40-49'].iloc[-1]\
    + df['Liverpool Total 40-49'].iloc[-1] + df['Bristol Total 40-49'].iloc[-1]
    Total5059 = df['London Total 50-59'].iloc[-1] + df['Birmingham Total 50-59'].iloc[-1] + df['Leeds Total 50-59'].iloc[-1]\
    + df['Sheffield Total 50-59'].iloc[-1] + df['Manchester Total 50-59'].iloc[-1] + df['Bradford Total 50-59'].iloc[-1]\
    + df['Liverpool Total 50-59'].iloc[-1] + df['Bristol Total 50-59'].iloc[-1]
    Total6069 = df['London Total 60-69'].iloc[-1] + df['Birmingham Total 60-69'].iloc[-1] + df['Leeds Total 60-69'].iloc[-1]\
    + df['Sheffield Total 60-69'].iloc[-1] + df['Manchester Total 60-69'].iloc[-1] + df['Bradford Total 60-69'].iloc[-1]\
    + df['Liverpool Total 60-69'].iloc[-1] + df['Bristol Total 60-69'].iloc[-1]
    Total7079 = df['London Total 70-79'].iloc[-1] + df['Birmingham Total 70-79'].iloc[-1] + df['Leeds Total 70-79'].iloc[-1]\
    + df['Sheffield Total 70-79'].iloc[-1] + df['Manchester Total 70-79'].iloc[-1] + df['Bradford Total 70-79'].iloc[-1]\
    + df['Liverpool Total 70-79'].iloc[-1] + df['Bristol Total 70-79'].iloc[-1]
    Total8089 = df['London Total 80-89'].iloc[-1] + df['Birmingham Total 80-89'].iloc[-1] + df['Leeds Total 80-89'].iloc[-1]\
    + df['Sheffield Total 80-89'].iloc[-1] + df['Manchester Total 80-89'].iloc[-1] + df['Bradford Total 80-89'].iloc[-1]\
    + df['Liverpool Total 80-89'].iloc[-1] + df['Bristol Total 80-89'].iloc[-1]
    Total90 = df['London Total 90+'].iloc[-1] + df['Birmingham Total 90+'].iloc[-1] + df['Leeds Total 90+'].iloc[-1]\
    + df['Sheffield Total 90+'].iloc[-1] + df['Manchester Total 90+'].iloc[-1] + df['Bradford Total 90+'].iloc[-1]\
    + df['Liverpool Total 90+'].iloc[-1] + df['Bristol Total 90+'].iloc[-1]
    Ilift = df.loc[1050]['I']
    TotCas = df['Total Cases'].iloc[-1]
    TotalCases.append(TotCas)
    Dead.append(dead)
    IPeak.append(Imax)
    PeakTime.append(time)
    Dead019.append(dead019)
    Dead2029.append(dead2029)
    Dead3039.append(dead3039) 
    Dead4049.append(dead4049) 
    Dead5059.append(dead5059) 
    Dead6069.append(dead6069) 
    Dead7079.append(dead7079) 
    Dead8089.append(dead8089) 
    Dead90.append(dead90)
    ILifting.append(Ilift)
print(np.mean(IPeak),u"\u00B1",np.std(IPeak))
print(np.mean(PeakTime),u"\u00B1",np.std(PeakTime))  
print(np.mean(Dead),u"\u00B1",np.std(Dead))
print(np.mean(Dead019),u"\u00B1",np.std(Dead019))
print(np.mean(Dead2029),u"\u00B1",np.std(Dead2029))
print(np.mean(Dead3039),u"\u00B1",np.std(Dead3039))
print(np.mean(Dead4049),u"\u00B1",np.std(Dead4049))
print(np.mean(Dead5059),u"\u00B1",np.std(Dead5059))
print(np.mean(Dead6069),u"\u00B1",np.std(Dead6069))
print(np.mean(Dead7079),u"\u00B1",np.std(Dead7079))
print(np.mean(Dead8089),u"\u00B1",np.std(Dead8089))
print(np.mean(Dead90),u"\u00B1",np.std(Dead90))
print(np.mean(ILifting),u"\u00B1",np.std(ILifting))
IPeak_PCH_275 = np.mean(IPeak)
PeakTime_PCH_275 = np.mean(PeakTime)
Dead_PCH_275 = np.mean(Dead)
Dead019_PCH_275 = np.mean(Dead019)
Dead2029_PCH_275 = np.mean(Dead2029)
Dead3039_PCH_275 = np.mean(Dead3039)
Dead4049_PCH_275 = np.mean(Dead4049)
Dead5059_PCH_275 = np.mean(Dead5059)
Dead6069_PCH_275 = np.mean(Dead6069)
Dead7079_PCH_275 = np.mean(Dead7079)
Dead8089_PCH_275 = np.mean(Dead8089)
Dead90_PCH_275 = np.mean(Dead90)
ILifting_PCH_275 = np.mean(ILifting)
IPeak_PCH_275_Err = np.std(IPeak)
PeakTime_PCH_275_Err = np.std(PeakTime)
Dead_PCH_275_Err = np.std(Dead)
Dead019_PCH_275_Err = np.std(Dead019)
Dead2029_PCH_275_Err = np.std(Dead2029)
Dead3039_PCH_275_Err = np.std(Dead3039)
Dead4049_PCH_275_Err = np.std(Dead4049)
Dead5059_PCH_275_Err = np.std(Dead5059)
Dead6069_PCH_275_Err = np.std(Dead6069)
Dead7079_PCH_275_Err = np.std(Dead7079)
Dead8089_PCH_275_Err = np.std(Dead8089)
Dead90_PCH_275_Err = np.std(Dead90)
ILifting_PCH_275_Err = np.std(ILifting)
PeakTimeArray_PCH_275 = PeakTime
TotalCases_PCH_275 = np.mean(TotalCases)
TotalCases_PCH_275_Err = np.std(TotalCases)
Total019_PCH_275 = np.mean(Total019)
Total2029_PCH_275 = np.mean(Total2029)
Total3039_PCH_275 = np.mean(Total3039)
Total4049_PCH_275 = np.mean(Total4049)
Total5059_PCH_275 = np.mean(Total5059)
Total6069_PCH_275 = np.mean(Total6069)
Total7079_PCH_275 = np.mean(Total7079)
Total8089_PCH_275 = np.mean(Total8089)
Total90_PCH_275 = np.mean(Total90)
Total019_PCH_275_Err = np.std(Total019)
Total2029_PCH_275_Err = np.std(Total2029)
Total3039_PCH_275_Err = np.std(Total3039)
Total4049_PCH_275_Err = np.std(Total4049)
Total5059_PCH_275_Err = np.std(Total5059)
Total6069_PCH_275_Err = np.std(Total6069)
Total7079_PCH_275_Err = np.std(Total7079)
Total8089_PCH_275_Err = np.std(Total8089)
Total90_PCH_275_Err = np.std(Total90)
# Out:
# 2576230.34 ± 15638.694122732883
# 81.79200000000002 ± 1.823769722305971
# 83395.38 ± 332.4447256311943
# 731.8 ± 30.01799460323757
# 683.99 ± 27.654835020299796
# 2371.93 ± 43.171114185297554
# 8588.31 ± 89.36964753203405
# 16602.5 ± 124.47975739050908
# 25571.13 ± 153.3702484186552
# 21115.88 ± 144.3508420481155
# 6843.25 ± 70.00162498113883
# 886.59 ± 27.022248241032795
# 744980.78 ± 116334.05389932735

# %%
#PopnChanged R = 2.5
IPeak = []
PeakTime = []
Dead = []
Dead019 = []
Dead2029 = []
Dead3039 = []
Dead4049 = []
Dead5059 = []
Dead6069 = []
Dead7079 = []
Dead8089 = []
Dead90 = []
ILifting = []
TotalCases = []
Total019 = []
Total2029 = []
Total3039 = []
Total4049 = []
Total5059 = []
Total6069 = []
Total7079 = []
Total8089 = []
Total90 = []
z = 1.960
for i in range(1,101):
    df = pd.read_csv (r'E:\Users\Michael\Project Notebook\Sim Data\PopnChanged\2.5\PopnChanged_R2.5_{}.csv'.format(i))
    Imax = pd.DataFrame.max(df['I'])
    time = pd.DataFrame.max(df.loc[df['I'] == Imax]['t'])
    dead = df['D'].iloc[-1]
    dead019 = df['London Dead 0-19'].iloc[-1] + df['Birmingham Dead 0-19'].iloc[-1] + df['Leeds Dead 0-19'].iloc[-1]\
    + df['Sheffield Dead 0-19'].iloc[-1] + df['Manchester Dead 0-19'].iloc[-1] + df['Bradford Dead 0-19'].iloc[-1]\
    + df['Liverpool Dead 0-19'].iloc[-1] + df['Bristol Dead 0-19'].iloc[-1]
    dead2029 = df['London Dead 20-29'].iloc[-1] + df['Birmingham Dead 20-29'].iloc[-1] + df['Leeds Dead 20-29'].iloc[-1]\
    + df['Sheffield Dead 20-29'].iloc[-1] + df['Manchester Dead 20-29'].iloc[-1] + df['Bradford Dead 20-29'].iloc[-1]\
    + df['Liverpool Dead 20-29'].iloc[-1] + df['Bristol Dead 20-29'].iloc[-1]
    dead3039 = df['London Dead 30-39'].iloc[-1] + df['Birmingham Dead 30-39'].iloc[-1] + df['Leeds Dead 30-39'].iloc[-1]\
    + df['Sheffield Dead 30-39'].iloc[-1] + df['Manchester Dead 30-39'].iloc[-1] + df['Bradford Dead 30-39'].iloc[-1]\
    + df['Liverpool Dead 30-39'].iloc[-1] + df['Bristol Dead 30-39'].iloc[-1]
    dead4049 = df['London Dead 40-49'].iloc[-1] + df['Birmingham Dead 40-49'].iloc[-1] + df['Leeds Dead 40-49'].iloc[-1]\
    + df['Sheffield Dead 40-49'].iloc[-1] + df['Manchester Dead 40-49'].iloc[-1] + df['Bradford Dead 40-49'].iloc[-1]\
    + df['Liverpool Dead 40-49'].iloc[-1] + df['Bristol Dead 40-49'].iloc[-1]
    dead5059 = df['London Dead 50-59'].iloc[-1] + df['Birmingham Dead 50-59'].iloc[-1] + df['Leeds Dead 50-59'].iloc[-1]\
    + df['Sheffield Dead 50-59'].iloc[-1] + df['Manchester Dead 50-59'].iloc[-1] + df['Bradford Dead 50-59'].iloc[-1]\
    + df['Liverpool Dead 50-59'].iloc[-1] + df['Bristol Dead 50-59'].iloc[-1]
    dead6069 = df['London Dead 60-69'].iloc[-1] + df['Birmingham Dead 60-69'].iloc[-1] + df['Leeds Dead 60-69'].iloc[-1]\
    + df['Sheffield Dead 60-69'].iloc[-1] + df['Manchester Dead 60-69'].iloc[-1] + df['Bradford Dead 60-69'].iloc[-1]\
    + df['Liverpool Dead 60-69'].iloc[-1] + df['Bristol Dead 60-69'].iloc[-1]
    dead7079 = df['London Dead 70-79'].iloc[-1] + df['Birmingham Dead 70-79'].iloc[-1] + df['Leeds Dead 70-79'].iloc[-1]\
    + df['Sheffield Dead 70-79'].iloc[-1] + df['Manchester Dead 70-79'].iloc[-1] + df['Bradford Dead 70-79'].iloc[-1]\
    + df['Liverpool Dead 70-79'].iloc[-1] + df['Bristol Dead 70-79'].iloc[-1]
    dead8089 = df['London Dead 80-89'].iloc[-1] + df['Birmingham Dead 80-89'].iloc[-1] + df['Leeds Dead 80-89'].iloc[-1]\
    + df['Sheffield Dead 80-89'].iloc[-1] + df['Manchester Dead 80-89'].iloc[-1] + df['Bradford Dead 80-89'].iloc[-1]\
    + df['Liverpool Dead 80-89'].iloc[-1] + df['Bristol Dead 80-89'].iloc[-1]
    dead90 = df['London Dead 90+'].iloc[-1] + df['Birmingham Dead 90+'].iloc[-1] + df['Leeds Dead 90+'].iloc[-1]\
    + df['Sheffield Dead 90+'].iloc[-1] + df['Manchester Dead 90+'].iloc[-1] + df['Bradford Dead 90+'].iloc[-1]\
    + df['Liverpool Dead 90+'].iloc[-1] + df['Bristol Dead 90+'].iloc[-1]
    Total019 = df['London Total 0-19'].iloc[-1] + df['Birmingham Total 0-19'].iloc[-1] + df['Leeds Total 0-19'].iloc[-1]\
    + df['Sheffield Total 0-19'].iloc[-1] + df['Manchester Total 0-19'].iloc[-1] + df['Bradford Total 0-19'].iloc[-1]\
    + df['Liverpool Total 0-19'].iloc[-1] + df['Bristol Total 0-19'].iloc[-1]
    Total2029 = df['London Total 20-29'].iloc[-1] + df['Birmingham Total 20-29'].iloc[-1] + df['Leeds Total 20-29'].iloc[-1]\
    + df['Sheffield Total 20-29'].iloc[-1] + df['Manchester Total 20-29'].iloc[-1] + df['Bradford Total 20-29'].iloc[-1]\
    + df['Liverpool Total 20-29'].iloc[-1] + df['Bristol Total 20-29'].iloc[-1]
    Total3039 = df['London Total 30-39'].iloc[-1] + df['Birmingham Total 30-39'].iloc[-1] + df['Leeds Total 30-39'].iloc[-1]\
    + df['Sheffield Total 30-39'].iloc[-1] + df['Manchester Total 30-39'].iloc[-1] + df['Bradford Total 30-39'].iloc[-1]\
    + df['Liverpool Total 30-39'].iloc[-1] + df['Bristol Total 30-39'].iloc[-1]
    Total4049 = df['London Total 40-49'].iloc[-1] + df['Birmingham Total 40-49'].iloc[-1] + df['Leeds Total 40-49'].iloc[-1]\
    + df['Sheffield Total 40-49'].iloc[-1] + df['Manchester Total 40-49'].iloc[-1] + df['Bradford Total 40-49'].iloc[-1]\
    + df['Liverpool Total 40-49'].iloc[-1] + df['Bristol Total 40-49'].iloc[-1]
    Total5059 = df['London Total 50-59'].iloc[-1] + df['Birmingham Total 50-59'].iloc[-1] + df['Leeds Total 50-59'].iloc[-1]\
    + df['Sheffield Total 50-59'].iloc[-1] + df['Manchester Total 50-59'].iloc[-1] + df['Bradford Total 50-59'].iloc[-1]\
    + df['Liverpool Total 50-59'].iloc[-1] + df['Bristol Total 50-59'].iloc[-1]
    Total6069 = df['London Total 60-69'].iloc[-1] + df['Birmingham Total 60-69'].iloc[-1] + df['Leeds Total 60-69'].iloc[-1]\
    + df['Sheffield Total 60-69'].iloc[-1] + df['Manchester Total 60-69'].iloc[-1] + df['Bradford Total 60-69'].iloc[-1]\
    + df['Liverpool Total 60-69'].iloc[-1] + df['Bristol Total 60-69'].iloc[-1]
    Total7079 = df['London Total 70-79'].iloc[-1] + df['Birmingham Total 70-79'].iloc[-1] + df['Leeds Total 70-79'].iloc[-1]\
    + df['Sheffield Total 70-79'].iloc[-1] + df['Manchester Total 70-79'].iloc[-1] + df['Bradford Total 70-79'].iloc[-1]\
    + df['Liverpool Total 70-79'].iloc[-1] + df['Bristol Total 70-79'].iloc[-1]
    Total8089 = df['London Total 80-89'].iloc[-1] + df['Birmingham Total 80-89'].iloc[-1] + df['Leeds Total 80-89'].iloc[-1]\
    + df['Sheffield Total 80-89'].iloc[-1] + df['Manchester Total 80-89'].iloc[-1] + df['Bradford Total 80-89'].iloc[-1]\
    + df['Liverpool Total 80-89'].iloc[-1] + df['Bristol Total 80-89'].iloc[-1]
    Total90 = df['London Total 90+'].iloc[-1] + df['Birmingham Total 90+'].iloc[-1] + df['Leeds Total 90+'].iloc[-1]\
    + df['Sheffield Total 90+'].iloc[-1] + df['Manchester Total 90+'].iloc[-1] + df['Bradford Total 90+'].iloc[-1]\
    + df['Liverpool Total 90+'].iloc[-1] + df['Bristol Total 90+'].iloc[-1]
    Ilift = df.loc[1050]['I']
    TotCas = df['Total Cases'].iloc[-1]
    TotalCases.append(TotCas)
    Dead.append(dead)
    IPeak.append(Imax)
    PeakTime.append(time)
    Dead019.append(dead019)
    Dead2029.append(dead2029)
    Dead3039.append(dead3039) 
    Dead4049.append(dead4049) 
    Dead5059.append(dead5059) 
    Dead6069.append(dead6069) 
    Dead7079.append(dead7079) 
    Dead8089.append(dead8089) 
    Dead90.append(dead90)
    ILifting.append(Ilift)
print(np.mean(IPeak),u"\u00B1",np.std(IPeak))
print(np.mean(PeakTime),u"\u00B1",np.std(PeakTime))  
print(np.mean(Dead),u"\u00B1",np.std(Dead))
print(np.mean(Dead019),u"\u00B1",np.std(Dead019))
print(np.mean(Dead2029),u"\u00B1",np.std(Dead2029))
print(np.mean(Dead3039),u"\u00B1",np.std(Dead3039))
print(np.mean(Dead4049),u"\u00B1",np.std(Dead4049))
print(np.mean(Dead5059),u"\u00B1",np.std(Dead5059))
print(np.mean(Dead6069),u"\u00B1",np.std(Dead6069))
print(np.mean(Dead7079),u"\u00B1",np.std(Dead7079))
print(np.mean(Dead8089),u"\u00B1",np.std(Dead8089))
print(np.mean(Dead90),u"\u00B1",np.std(Dead90))
print(np.mean(ILifting),u"\u00B1",np.std(ILifting))
IPeak_PCH_25 = np.mean(IPeak)
PeakTime_PCH_25 = np.mean(PeakTime)
Dead_PCH_25 = np.mean(Dead)
Dead019_PCH_25 = np.mean(Dead019)
Dead2029_PCH_25 = np.mean(Dead2029)
Dead3039_PCH_25 = np.mean(Dead3039)
Dead4049_PCH_25 = np.mean(Dead4049)
Dead5059_PCH_25 = np.mean(Dead5059)
Dead6069_PCH_25 = np.mean(Dead6069)
Dead7079_PCH_25 = np.mean(Dead7079)
Dead8089_PCH_25 = np.mean(Dead8089)
Dead90_PCH_25 = np.mean(Dead90)
ILifting_PCH_25 = np.mean(ILifting)
IPeak_PCH_25_Err = np.std(IPeak)
PeakTime_PCH_25_Err = np.std(PeakTime)
Dead_PCH_25_Err = np.std(Dead)
Dead019_PCH_25_Err = np.std(Dead019)
Dead2029_PCH_25_Err = np.std(Dead2029)
Dead3039_PCH_25_Err = np.std(Dead3039)
Dead4049_PCH_25_Err = np.std(Dead4049)
Dead5059_PCH_25_Err = np.std(Dead5059)
Dead6069_PCH_25_Err = np.std(Dead6069)
Dead7079_PCH_25_Err = np.std(Dead7079)
Dead8089_PCH_25_Err = np.std(Dead8089)
Dead90_PCH_25_Err = np.std(Dead90)
ILifting_PCH_25_Err = np.std(ILifting)
PeakTimeArray_PCH_25 = PeakTime
TotalCases_PCH_25 = np.mean(TotalCases)
TotalCases_PCH_25_Err = np.std(TotalCases)
Total019_PCH_25 = np.mean(Total019)
Total2029_PCH_25 = np.mean(Total2029)
Total3039_PCH_25 = np.mean(Total3039)
Total4049_PCH_25 = np.mean(Total4049)
Total5059_PCH_25 = np.mean(Total5059)
Total6069_PCH_25 = np.mean(Total6069)
Total7079_PCH_25 = np.mean(Total7079)
Total8089_PCH_25 = np.mean(Total8089)
Total90_PCH_25 = np.mean(Total90)
Total019_PCH_25_Err = np.std(Total019)
Total2029_PCH_25_Err = np.std(Total2029)
Total3039_PCH_25_Err = np.std(Total3039)
Total4049_PCH_25_Err = np.std(Total4049)
Total5059_PCH_25_Err = np.std(Total5059)
Total6069_PCH_25_Err = np.std(Total6069)
Total7079_PCH_25_Err = np.std(Total7079)
Total8089_PCH_25_Err = np.std(Total8089)
Total90_PCH_25_Err = np.std(Total90)
# Out:
# 2281931.06 ± 15238.801809735569
# 92.46499999999997 ± 2.289339424375509
# 77437.09 ± 255.70674981314045
# 706.24 ± 31.25415812336016
# 667.71 ± 25.679678736308208
# 2324.21 ± 45.09507622789876
# 8418.01 ± 91.39414587379216
# 15815.29 ± 126.21816786817973
# 23498.35 ± 144.5249026984623
# 19033.22 ± 142.585173142231
# 6172.45 ± 71.09618484841504
# 801.61 ± 28.755832451869658
# 1545035.16 ± 188802.53746609023

# %%
#PopnChanged R = 2.25
IPeak = []
PeakTime = []
Dead = []
Dead019 = []
Dead2029 = []
Dead3039 = []
Dead4049 = []
Dead5059 = []
Dead6069 = []
Dead7079 = []
Dead8089 = []
Dead90 = []
ILifting = []
TotalCases = []
Total019 = []
Total2029 = []
Total3039 = []
Total4049 = []
Total5059 = []
Total6069 = []
Total7079 = []
Total8089 = []
Total90 = []
z = 1.960
for i in range(1,101):
    df = pd.read_csv (r'E:\Users\Michael\Project Notebook\Sim Data\PopnChanged\2.25\PopnChanged_R2.25_{}.csv'.format(i))
    Imax = pd.DataFrame.max(df['I'])
    time = pd.DataFrame.max(df.loc[df['I'] == Imax]['t'])
    dead = df['D'].iloc[-1]
    dead019 = df['London Dead 0-19'].iloc[-1] + df['Birmingham Dead 0-19'].iloc[-1] + df['Leeds Dead 0-19'].iloc[-1]\
    + df['Sheffield Dead 0-19'].iloc[-1] + df['Manchester Dead 0-19'].iloc[-1] + df['Bradford Dead 0-19'].iloc[-1]\
    + df['Liverpool Dead 0-19'].iloc[-1] + df['Bristol Dead 0-19'].iloc[-1]
    dead2029 = df['London Dead 20-29'].iloc[-1] + df['Birmingham Dead 20-29'].iloc[-1] + df['Leeds Dead 20-29'].iloc[-1]\
    + df['Sheffield Dead 20-29'].iloc[-1] + df['Manchester Dead 20-29'].iloc[-1] + df['Bradford Dead 20-29'].iloc[-1]\
    + df['Liverpool Dead 20-29'].iloc[-1] + df['Bristol Dead 20-29'].iloc[-1]
    dead3039 = df['London Dead 30-39'].iloc[-1] + df['Birmingham Dead 30-39'].iloc[-1] + df['Leeds Dead 30-39'].iloc[-1]\
    + df['Sheffield Dead 30-39'].iloc[-1] + df['Manchester Dead 30-39'].iloc[-1] + df['Bradford Dead 30-39'].iloc[-1]\
    + df['Liverpool Dead 30-39'].iloc[-1] + df['Bristol Dead 30-39'].iloc[-1]
    dead4049 = df['London Dead 40-49'].iloc[-1] + df['Birmingham Dead 40-49'].iloc[-1] + df['Leeds Dead 40-49'].iloc[-1]\
    + df['Sheffield Dead 40-49'].iloc[-1] + df['Manchester Dead 40-49'].iloc[-1] + df['Bradford Dead 40-49'].iloc[-1]\
    + df['Liverpool Dead 40-49'].iloc[-1] + df['Bristol Dead 40-49'].iloc[-1]
    dead5059 = df['London Dead 50-59'].iloc[-1] + df['Birmingham Dead 50-59'].iloc[-1] + df['Leeds Dead 50-59'].iloc[-1]\
    + df['Sheffield Dead 50-59'].iloc[-1] + df['Manchester Dead 50-59'].iloc[-1] + df['Bradford Dead 50-59'].iloc[-1]\
    + df['Liverpool Dead 50-59'].iloc[-1] + df['Bristol Dead 50-59'].iloc[-1]
    dead6069 = df['London Dead 60-69'].iloc[-1] + df['Birmingham Dead 60-69'].iloc[-1] + df['Leeds Dead 60-69'].iloc[-1]\
    + df['Sheffield Dead 60-69'].iloc[-1] + df['Manchester Dead 60-69'].iloc[-1] + df['Bradford Dead 60-69'].iloc[-1]\
    + df['Liverpool Dead 60-69'].iloc[-1] + df['Bristol Dead 60-69'].iloc[-1]
    dead7079 = df['London Dead 70-79'].iloc[-1] + df['Birmingham Dead 70-79'].iloc[-1] + df['Leeds Dead 70-79'].iloc[-1]\
    + df['Sheffield Dead 70-79'].iloc[-1] + df['Manchester Dead 70-79'].iloc[-1] + df['Bradford Dead 70-79'].iloc[-1]\
    + df['Liverpool Dead 70-79'].iloc[-1] + df['Bristol Dead 70-79'].iloc[-1]
    dead8089 = df['London Dead 80-89'].iloc[-1] + df['Birmingham Dead 80-89'].iloc[-1] + df['Leeds Dead 80-89'].iloc[-1]\
    + df['Sheffield Dead 80-89'].iloc[-1] + df['Manchester Dead 80-89'].iloc[-1] + df['Bradford Dead 80-89'].iloc[-1]\
    + df['Liverpool Dead 80-89'].iloc[-1] + df['Bristol Dead 80-89'].iloc[-1]
    dead90 = df['London Dead 90+'].iloc[-1] + df['Birmingham Dead 90+'].iloc[-1] + df['Leeds Dead 90+'].iloc[-1]\
    + df['Sheffield Dead 90+'].iloc[-1] + df['Manchester Dead 90+'].iloc[-1] + df['Bradford Dead 90+'].iloc[-1]\
    + df['Liverpool Dead 90+'].iloc[-1] + df['Bristol Dead 90+'].iloc[-1]
    Total019 = df['London Total 0-19'].iloc[-1] + df['Birmingham Total 0-19'].iloc[-1] + df['Leeds Total 0-19'].iloc[-1]\
    + df['Sheffield Total 0-19'].iloc[-1] + df['Manchester Total 0-19'].iloc[-1] + df['Bradford Total 0-19'].iloc[-1]\
    + df['Liverpool Total 0-19'].iloc[-1] + df['Bristol Total 0-19'].iloc[-1]
    Total2029 = df['London Total 20-29'].iloc[-1] + df['Birmingham Total 20-29'].iloc[-1] + df['Leeds Total 20-29'].iloc[-1]\
    + df['Sheffield Total 20-29'].iloc[-1] + df['Manchester Total 20-29'].iloc[-1] + df['Bradford Total 20-29'].iloc[-1]\
    + df['Liverpool Total 20-29'].iloc[-1] + df['Bristol Total 20-29'].iloc[-1]
    Total3039 = df['London Total 30-39'].iloc[-1] + df['Birmingham Total 30-39'].iloc[-1] + df['Leeds Total 30-39'].iloc[-1]\
    + df['Sheffield Total 30-39'].iloc[-1] + df['Manchester Total 30-39'].iloc[-1] + df['Bradford Total 30-39'].iloc[-1]\
    + df['Liverpool Total 30-39'].iloc[-1] + df['Bristol Total 30-39'].iloc[-1]
    Total4049 = df['London Total 40-49'].iloc[-1] + df['Birmingham Total 40-49'].iloc[-1] + df['Leeds Total 40-49'].iloc[-1]\
    + df['Sheffield Total 40-49'].iloc[-1] + df['Manchester Total 40-49'].iloc[-1] + df['Bradford Total 40-49'].iloc[-1]\
    + df['Liverpool Total 40-49'].iloc[-1] + df['Bristol Total 40-49'].iloc[-1]
    Total5059 = df['London Total 50-59'].iloc[-1] + df['Birmingham Total 50-59'].iloc[-1] + df['Leeds Total 50-59'].iloc[-1]\
    + df['Sheffield Total 50-59'].iloc[-1] + df['Manchester Total 50-59'].iloc[-1] + df['Bradford Total 50-59'].iloc[-1]\
    + df['Liverpool Total 50-59'].iloc[-1] + df['Bristol Total 50-59'].iloc[-1]
    Total6069 = df['London Total 60-69'].iloc[-1] + df['Birmingham Total 60-69'].iloc[-1] + df['Leeds Total 60-69'].iloc[-1]\
    + df['Sheffield Total 60-69'].iloc[-1] + df['Manchester Total 60-69'].iloc[-1] + df['Bradford Total 60-69'].iloc[-1]\
    + df['Liverpool Total 60-69'].iloc[-1] + df['Bristol Total 60-69'].iloc[-1]
    Total7079 = df['London Total 70-79'].iloc[-1] + df['Birmingham Total 70-79'].iloc[-1] + df['Leeds Total 70-79'].iloc[-1]\
    + df['Sheffield Total 70-79'].iloc[-1] + df['Manchester Total 70-79'].iloc[-1] + df['Bradford Total 70-79'].iloc[-1]\
    + df['Liverpool Total 70-79'].iloc[-1] + df['Bristol Total 70-79'].iloc[-1]
    Total8089 = df['London Total 80-89'].iloc[-1] + df['Birmingham Total 80-89'].iloc[-1] + df['Leeds Total 80-89'].iloc[-1]\
    + df['Sheffield Total 80-89'].iloc[-1] + df['Manchester Total 80-89'].iloc[-1] + df['Bradford Total 80-89'].iloc[-1]\
    + df['Liverpool Total 80-89'].iloc[-1] + df['Bristol Total 80-89'].iloc[-1]
    Total90 = df['London Total 90+'].iloc[-1] + df['Birmingham Total 90+'].iloc[-1] + df['Leeds Total 90+'].iloc[-1]\
    + df['Sheffield Total 90+'].iloc[-1] + df['Manchester Total 90+'].iloc[-1] + df['Bradford Total 90+'].iloc[-1]\
    + df['Liverpool Total 90+'].iloc[-1] + df['Bristol Total 90+'].iloc[-1]
    Ilift = df.loc[1050]['I']
    TotCas = df['Total Cases'].iloc[-1]
    TotalCases.append(TotCas)
    Dead.append(dead)
    IPeak.append(Imax)
    PeakTime.append(time)
    Dead019.append(dead019)
    Dead2029.append(dead2029)
    Dead3039.append(dead3039) 
    Dead4049.append(dead4049) 
    Dead5059.append(dead5059) 
    Dead6069.append(dead6069) 
    Dead7079.append(dead7079) 
    Dead8089.append(dead8089) 
    Dead90.append(dead90)
    ILifting.append(Ilift)
print(np.mean(IPeak),u"\u00B1",np.std(IPeak))
print(np.mean(PeakTime),u"\u00B1",np.std(PeakTime))  
print(np.mean(Dead),u"\u00B1",np.std(Dead))
print(np.mean(Dead019),u"\u00B1",np.std(Dead019))
print(np.mean(Dead2029),u"\u00B1",np.std(Dead2029))
print(np.mean(Dead3039),u"\u00B1",np.std(Dead3039))
print(np.mean(Dead4049),u"\u00B1",np.std(Dead4049))
print(np.mean(Dead5059),u"\u00B1",np.std(Dead5059))
print(np.mean(Dead6069),u"\u00B1",np.std(Dead6069))
print(np.mean(Dead7079),u"\u00B1",np.std(Dead7079))
print(np.mean(Dead8089),u"\u00B1",np.std(Dead8089))
print(np.mean(Dead90),u"\u00B1",np.std(Dead90))
print(np.mean(ILifting),u"\u00B1",np.std(ILifting))
IPeak_PCH_225 = np.mean(IPeak)
PeakTime_PCH_225 = np.mean(PeakTime)
Dead_PCH_225 = np.mean(Dead)
Dead019_PCH_225 = np.mean(Dead019)
Dead2029_PCH_225 = np.mean(Dead2029)
Dead3039_PCH_225 = np.mean(Dead3039)
Dead4049_PCH_225 = np.mean(Dead4049)
Dead5059_PCH_225 = np.mean(Dead5059)
Dead6069_PCH_225 = np.mean(Dead6069)
Dead7079_PCH_225 = np.mean(Dead7079)
Dead8089_PCH_225 = np.mean(Dead8089)
Dead90_PCH_225 = np.mean(Dead90)
ILifting_PCH_225 = np.mean(ILifting)
IPeak_PCH_225_Err = np.std(IPeak)
PeakTime_PCH_225_Err = np.std(PeakTime)
Dead_PCH_225_Err = np.std(Dead)
Dead019_PCH_225_Err = np.std(Dead019)
Dead2029_PCH_225_Err = np.std(Dead2029)
Dead3039_PCH_225_Err = np.std(Dead3039)
Dead4049_PCH_225_Err = np.std(Dead4049)
Dead5059_PCH_225_Err = np.std(Dead5059)
Dead6069_PCH_225_Err = np.std(Dead6069)
Dead7079_PCH_225_Err = np.std(Dead7079)
Dead8089_PCH_225_Err = np.std(Dead8089)
Dead90_PCH_225_Err = np.std(Dead90)
ILifting_PCH_225_Err = np.std(ILifting)
PeakTimeArray_PCH_225 = PeakTime
TotalCases_PCH_225 = np.mean(TotalCases)
TotalCases_PCH_225_Err = np.std(TotalCases)
Total019_PCH_225 = np.mean(Total019)
Total2029_PCH_225 = np.mean(Total2029)
Total3039_PCH_225 = np.mean(Total3039)
Total4049_PCH_225 = np.mean(Total4049)
Total5059_PCH_225 = np.mean(Total5059)
Total6069_PCH_225 = np.mean(Total6069)
Total7079_PCH_225 = np.mean(Total7079)
Total8089_PCH_225 = np.mean(Total8089)
Total90_PCH_225 = np.mean(Total90)
Total019_PCH_225_Err = np.std(Total019)
Total2029_PCH_225_Err = np.std(Total2029)
Total3039_PCH_225_Err = np.std(Total3039)
Total4049_PCH_225_Err = np.std(Total4049)
Total5059_PCH_225_Err = np.std(Total5059)
Total6069_PCH_225_Err = np.std(Total6069)
Total7079_PCH_225_Err = np.std(Total7079)
Total8089_PCH_225_Err = np.std(Total8089)
Total90_PCH_225_Err = np.std(Total90)
# Out:
# 1948376.06 ± 19592.61435634357
# 106.88 ± 2.86980835597083
# 70612.16 ± 246.30094275093631
# 682.76 ± 26.337471404825482
# 645.58 ± 23.465370229340085
# 2251.97 ± 48.203413779523956
# 8146.0 ± 80.239890328938
# 14804.52 ± 123.92929274388683
# 21169.51 ± 139.13292169720293
# 16771.02 ± 116.09892161428546
# 5436.14 ± 66.91113808627081
# 704.66 ± 24.641923626210676
# 1893967.02 ± 93935.11874107362

# %%
#PopnChanged R = 2
IPeak = []
PeakTime = []
Dead = []
Dead019 = []
Dead2029 = []
Dead3039 = []
Dead4049 = []
Dead5059 = []
Dead6069 = []
Dead7079 = []
Dead8089 = []
Dead90 = []
ILifting = []
TotalCases = []
Total019 = []
Total2029 = []
Total3039 = []
Total4049 = []
Total5059 = []
Total6069 = []
Total7079 = []
Total8089 = []
Total90 = []
z = 1.960
for i in range(1,101):
    df = pd.read_csv (r'E:\Users\Michael\Project Notebook\Sim Data\PopnChanged\2\PopnChanged_R2_{}.csv'.format(i))
    Imax = pd.DataFrame.max(df['I'])
    time = pd.DataFrame.max(df.loc[df['I'] == Imax]['t'])
    dead = df['D'].iloc[-1]
    dead019 = df['London Dead 0-19'].iloc[-1] + df['Birmingham Dead 0-19'].iloc[-1] + df['Leeds Dead 0-19'].iloc[-1]\
    + df['Sheffield Dead 0-19'].iloc[-1] + df['Manchester Dead 0-19'].iloc[-1] + df['Bradford Dead 0-19'].iloc[-1]\
    + df['Liverpool Dead 0-19'].iloc[-1] + df['Bristol Dead 0-19'].iloc[-1]
    dead2029 = df['London Dead 20-29'].iloc[-1] + df['Birmingham Dead 20-29'].iloc[-1] + df['Leeds Dead 20-29'].iloc[-1]\
    + df['Sheffield Dead 20-29'].iloc[-1] + df['Manchester Dead 20-29'].iloc[-1] + df['Bradford Dead 20-29'].iloc[-1]\
    + df['Liverpool Dead 20-29'].iloc[-1] + df['Bristol Dead 20-29'].iloc[-1]
    dead3039 = df['London Dead 30-39'].iloc[-1] + df['Birmingham Dead 30-39'].iloc[-1] + df['Leeds Dead 30-39'].iloc[-1]\
    + df['Sheffield Dead 30-39'].iloc[-1] + df['Manchester Dead 30-39'].iloc[-1] + df['Bradford Dead 30-39'].iloc[-1]\
    + df['Liverpool Dead 30-39'].iloc[-1] + df['Bristol Dead 30-39'].iloc[-1]
    dead4049 = df['London Dead 40-49'].iloc[-1] + df['Birmingham Dead 40-49'].iloc[-1] + df['Leeds Dead 40-49'].iloc[-1]\
    + df['Sheffield Dead 40-49'].iloc[-1] + df['Manchester Dead 40-49'].iloc[-1] + df['Bradford Dead 40-49'].iloc[-1]\
    + df['Liverpool Dead 40-49'].iloc[-1] + df['Bristol Dead 40-49'].iloc[-1]
    dead5059 = df['London Dead 50-59'].iloc[-1] + df['Birmingham Dead 50-59'].iloc[-1] + df['Leeds Dead 50-59'].iloc[-1]\
    + df['Sheffield Dead 50-59'].iloc[-1] + df['Manchester Dead 50-59'].iloc[-1] + df['Bradford Dead 50-59'].iloc[-1]\
    + df['Liverpool Dead 50-59'].iloc[-1] + df['Bristol Dead 50-59'].iloc[-1]
    dead6069 = df['London Dead 60-69'].iloc[-1] + df['Birmingham Dead 60-69'].iloc[-1] + df['Leeds Dead 60-69'].iloc[-1]\
    + df['Sheffield Dead 60-69'].iloc[-1] + df['Manchester Dead 60-69'].iloc[-1] + df['Bradford Dead 60-69'].iloc[-1]\
    + df['Liverpool Dead 60-69'].iloc[-1] + df['Bristol Dead 60-69'].iloc[-1]
    dead7079 = df['London Dead 70-79'].iloc[-1] + df['Birmingham Dead 70-79'].iloc[-1] + df['Leeds Dead 70-79'].iloc[-1]\
    + df['Sheffield Dead 70-79'].iloc[-1] + df['Manchester Dead 70-79'].iloc[-1] + df['Bradford Dead 70-79'].iloc[-1]\
    + df['Liverpool Dead 70-79'].iloc[-1] + df['Bristol Dead 70-79'].iloc[-1]
    dead8089 = df['London Dead 80-89'].iloc[-1] + df['Birmingham Dead 80-89'].iloc[-1] + df['Leeds Dead 80-89'].iloc[-1]\
    + df['Sheffield Dead 80-89'].iloc[-1] + df['Manchester Dead 80-89'].iloc[-1] + df['Bradford Dead 80-89'].iloc[-1]\
    + df['Liverpool Dead 80-89'].iloc[-1] + df['Bristol Dead 80-89'].iloc[-1]
    dead90 = df['London Dead 90+'].iloc[-1] + df['Birmingham Dead 90+'].iloc[-1] + df['Leeds Dead 90+'].iloc[-1]\
    + df['Sheffield Dead 90+'].iloc[-1] + df['Manchester Dead 90+'].iloc[-1] + df['Bradford Dead 90+'].iloc[-1]\
    + df['Liverpool Dead 90+'].iloc[-1] + df['Bristol Dead 90+'].iloc[-1]
    Total019 = df['London Total 0-19'].iloc[-1] + df['Birmingham Total 0-19'].iloc[-1] + df['Leeds Total 0-19'].iloc[-1]\
    + df['Sheffield Total 0-19'].iloc[-1] + df['Manchester Total 0-19'].iloc[-1] + df['Bradford Total 0-19'].iloc[-1]\
    + df['Liverpool Total 0-19'].iloc[-1] + df['Bristol Total 0-19'].iloc[-1]
    Total2029 = df['London Total 20-29'].iloc[-1] + df['Birmingham Total 20-29'].iloc[-1] + df['Leeds Total 20-29'].iloc[-1]\
    + df['Sheffield Total 20-29'].iloc[-1] + df['Manchester Total 20-29'].iloc[-1] + df['Bradford Total 20-29'].iloc[-1]\
    + df['Liverpool Total 20-29'].iloc[-1] + df['Bristol Total 20-29'].iloc[-1]
    Total3039 = df['London Total 30-39'].iloc[-1] + df['Birmingham Total 30-39'].iloc[-1] + df['Leeds Total 30-39'].iloc[-1]\
    + df['Sheffield Total 30-39'].iloc[-1] + df['Manchester Total 30-39'].iloc[-1] + df['Bradford Total 30-39'].iloc[-1]\
    + df['Liverpool Total 30-39'].iloc[-1] + df['Bristol Total 30-39'].iloc[-1]
    Total4049 = df['London Total 40-49'].iloc[-1] + df['Birmingham Total 40-49'].iloc[-1] + df['Leeds Total 40-49'].iloc[-1]\
    + df['Sheffield Total 40-49'].iloc[-1] + df['Manchester Total 40-49'].iloc[-1] + df['Bradford Total 40-49'].iloc[-1]\
    + df['Liverpool Total 40-49'].iloc[-1] + df['Bristol Total 40-49'].iloc[-1]
    Total5059 = df['London Total 50-59'].iloc[-1] + df['Birmingham Total 50-59'].iloc[-1] + df['Leeds Total 50-59'].iloc[-1]\
    + df['Sheffield Total 50-59'].iloc[-1] + df['Manchester Total 50-59'].iloc[-1] + df['Bradford Total 50-59'].iloc[-1]\
    + df['Liverpool Total 50-59'].iloc[-1] + df['Bristol Total 50-59'].iloc[-1]
    Total6069 = df['London Total 60-69'].iloc[-1] + df['Birmingham Total 60-69'].iloc[-1] + df['Leeds Total 60-69'].iloc[-1]\
    + df['Sheffield Total 60-69'].iloc[-1] + df['Manchester Total 60-69'].iloc[-1] + df['Bradford Total 60-69'].iloc[-1]\
    + df['Liverpool Total 60-69'].iloc[-1] + df['Bristol Total 60-69'].iloc[-1]
    Total7079 = df['London Total 70-79'].iloc[-1] + df['Birmingham Total 70-79'].iloc[-1] + df['Leeds Total 70-79'].iloc[-1]\
    + df['Sheffield Total 70-79'].iloc[-1] + df['Manchester Total 70-79'].iloc[-1] + df['Bradford Total 70-79'].iloc[-1]\
    + df['Liverpool Total 70-79'].iloc[-1] + df['Bristol Total 70-79'].iloc[-1]
    Total8089 = df['London Total 80-89'].iloc[-1] + df['Birmingham Total 80-89'].iloc[-1] + df['Leeds Total 80-89'].iloc[-1]\
    + df['Sheffield Total 80-89'].iloc[-1] + df['Manchester Total 80-89'].iloc[-1] + df['Bradford Total 80-89'].iloc[-1]\
    + df['Liverpool Total 80-89'].iloc[-1] + df['Bristol Total 80-89'].iloc[-1]
    Total90 = df['London Total 90+'].iloc[-1] + df['Birmingham Total 90+'].iloc[-1] + df['Leeds Total 90+'].iloc[-1]\
    + df['Sheffield Total 90+'].iloc[-1] + df['Manchester Total 90+'].iloc[-1] + df['Bradford Total 90+'].iloc[-1]\
    + df['Liverpool Total 90+'].iloc[-1] + df['Bristol Total 90+'].iloc[-1]
    Ilift = df.loc[1050]['I']
    TotCas = df['Total Cases'].iloc[-1]
    TotalCases.append(TotCas)
    Dead.append(dead)
    IPeak.append(Imax)
    PeakTime.append(time)
    Dead019.append(dead019)
    Dead2029.append(dead2029)
    Dead3039.append(dead3039) 
    Dead4049.append(dead4049) 
    Dead5059.append(dead5059) 
    Dead6069.append(dead6069) 
    Dead7079.append(dead7079) 
    Dead8089.append(dead8089) 
    Dead90.append(dead90)
    ILifting.append(Ilift)
print(np.mean(IPeak),u"\u00B1",np.std(IPeak))
print(np.mean(PeakTime),u"\u00B1",np.std(PeakTime))  
print(np.mean(Dead),u"\u00B1",np.std(Dead))
print(np.mean(Dead019),u"\u00B1",np.std(Dead019))
print(np.mean(Dead2029),u"\u00B1",np.std(Dead2029))
print(np.mean(Dead3039),u"\u00B1",np.std(Dead3039))
print(np.mean(Dead4049),u"\u00B1",np.std(Dead4049))
print(np.mean(Dead5059),u"\u00B1",np.std(Dead5059))
print(np.mean(Dead6069),u"\u00B1",np.std(Dead6069))
print(np.mean(Dead7079),u"\u00B1",np.std(Dead7079))
print(np.mean(Dead8089),u"\u00B1",np.std(Dead8089))
print(np.mean(Dead90),u"\u00B1",np.std(Dead90))
print(np.mean(ILifting),u"\u00B1",np.std(ILifting))
IPeak_PCH_2 = np.mean(IPeak)
PeakTime_PCH_2 = np.mean(PeakTime)
Dead_PCH_2 = np.mean(Dead)
Dead019_PCH_2 = np.mean(Dead019)
Dead2029_PCH_2 = np.mean(Dead2029)
Dead3039_PCH_2 = np.mean(Dead3039)
Dead4049_PCH_2 = np.mean(Dead4049)
Dead5059_PCH_2 = np.mean(Dead5059)
Dead6069_PCH_2 = np.mean(Dead6069)
Dead7079_PCH_2 = np.mean(Dead7079)
Dead8089_PCH_2 = np.mean(Dead8089)
Dead90_PCH_2 = np.mean(Dead90)
ILifting_PCH_2 = np.mean(ILifting)
IPeak_PCH_2_Err = np.std(IPeak)
PeakTime_PCH_2_Err = np.std(PeakTime)
Dead_PCH_2_Err = np.std(Dead)
Dead019_PCH_2_Err = np.std(Dead019)
Dead2029_PCH_2_Err = np.std(Dead2029)
Dead3039_PCH_2_Err = np.std(Dead3039)
Dead4049_PCH_2_Err = np.std(Dead4049)
Dead5059_PCH_2_Err = np.std(Dead5059)
Dead6069_PCH_2_Err = np.std(Dead6069)
Dead7079_PCH_2_Err = np.std(Dead7079)
Dead8089_PCH_2_Err = np.std(Dead8089)
Dead90_PCH_2_Err = np.std(Dead90)
ILifting_PCH_2_Err = np.std(ILifting)
PeakTimeArray_PCH_2 = PeakTime
TotalCases_PCH_2 = np.mean(TotalCases)
TotalCases_PCH_2_Err = np.std(TotalCases)
Total019_PCH_2 = np.mean(Total019)
Total2029_PCH_2 = np.mean(Total2029)
Total3039_PCH_2 = np.mean(Total3039)
Total4049_PCH_2 = np.mean(Total4049)
Total5059_PCH_2 = np.mean(Total5059)
Total6069_PCH_2 = np.mean(Total6069)
Total7079_PCH_2 = np.mean(Total7079)
Total8089_PCH_2 = np.mean(Total8089)
Total90_PCH_2 = np.mean(Total90)
Total019_PCH_2_Err = np.std(Total019)
Total2029_PCH_2_Err = np.std(Total2029)
Total3039_PCH_2_Err = np.std(Total3039)
Total4049_PCH_2_Err = np.std(Total4049)
Total5059_PCH_2_Err = np.std(Total5059)
Total6069_PCH_2_Err = np.std(Total6069)
Total7079_PCH_2_Err = np.std(Total7079)
Total8089_PCH_2_Err = np.std(Total8089)
Total90_PCH_2_Err = np.std(Total90)
# Out:
# 1573608.37 ± 13586.74046609782
# 128.209 ± 3.8268288438340194
# 62673.65 ± 255.82921549346156
# 641.42 ± 26.651896743008745
# 608.69 ± 21.395184037535174
# 2135.17 ± 48.387613084342156
# 7750.25 ± 82.92675985470552
# 13471.55 ± 126.57174842752234
# 18480.3 ± 144.98844781567942
# 14337.84 ± 116.04841403483289
# 4648.72 ± 60.84473354366834
# 599.71 ± 22.938742336928588
# 592764.97 ± 169534.9904111511

# %%
[IPeak_PCH_2,IPeak_PCH_225,IPeak_PCH_25,IPeak_PCH_275,IPeak_PCH_3,IPeak_PCH_325,IPeak_PCH_35,IPeak_PCH_375,IPeak_PCH_4]
[IPeak_PCH_2_Err,IPeak_PCH_225_Err,IPeak_PCH_25_Err,IPeak_PCH_275_Err,IPeak_PCH_3_Err,IPeak_PCH_325_Err,IPeak_PCH_35_Err,IPeak_PCH_375_Err,IPeak_PCH_4_Err]
# Out:
# [13586.74046609782,
#  19592.61435634357,
#  15238.801809735569,
#  15638.694122732883,
#  17513.673299350994,
#  17634.916439640423,
#  19026.62533729773,
#  20802.80699296131,
#  18294.18326370161]

# %%
[IPeak_PCO_2,IPeak_PCO_225,IPeak_PCO_25,IPeak_PCO_275,IPeak_PCO_3,IPeak_PCO_325,IPeak_PCO_35,IPeak_PCO_375,IPeak_PCO_4]
[IPeak_PCO_2_Err,IPeak_PCO_225_Err,IPeak_PCO_25_Err,IPeak_PCO_275_Err,IPeak_PCO_3_Err,IPeak_PCO_325_Err,IPeak_PCO_35_Err,IPeak_PCO_375_Err,IPeak_PCO_4_Err]
# Out:
# [8747.007108057018,
#  12046.72761131005,
#  12121.344768213634,
#  14590.69859592405,
#  18397.26378464743,
#  18697.336273480243,
#  19010.12675880674,
#  18833.467761076292,
#  20487.063030546866]

# %%
#Total deaths
TotalDeaths_PCO = [Dead_PCO_2,Dead_PCO_225,Dead_PCO_25,Dead_PCO_275,Dead_PCO_3,Dead_PCO_325,Dead_PCO_35,Dead_PCO_375,Dead_PCO_4]
TotalDeaths_PCO_Err = [Dead_PCO_2_Err,Dead_PCO_225_Err,Dead_PCO_25_Err,Dead_PCO_275_Err,Dead_PCO_3_Err,Dead_PCO_325_Err,Dead_PCO_35_Err,Dead_PCO_375_Err,Dead_PCO_4_Err]
TotalDeaths_PCH = [Dead_PCH_2,Dead_PCH_225,Dead_PCH_25,Dead_PCH_275,Dead_PCH_3,Dead_PCH_325,Dead_PCH_35,Dead_PCH_375,Dead_PCH_4]
TotalDeaths_PCH_Err = [Dead_PCH_2_Err,Dead_PCH_225_Err,Dead_PCH_25_Err,Dead_PCH_275_Err,Dead_PCH_3_Err,Dead_PCH_325_Err,Dead_PCH_35_Err,Dead_PCH_375_Err,Dead_PCH_4_Err]
R = [2,2.25,2.5,2.75,3,3.25,3.5,3.75,4]
plt.errorbar(R, TotalDeaths_PCO,yerr = TotalDeaths_PCO_Err,fmt='o',label = 'PCOcination')
plt.errorbar(R, TotalDeaths_PCH,yerr=TotalDeaths_PCH_Err,marker = 'x',fmt='o',label = 'No PCOcination',color = 'red')
legend = plt.legend(title="Scenario",loc=5,bbox_to_anchor=(1.37,0.5))
frame = legend.get_frame()
plt.xlabel("$R_{0}$")
plt.ylabel("Total Deaths")
plt.rcParams["figure.figsize"] = (6,4)

# %%
#Peak cases
PeakCases_PCO = [IPeak_PCO_2,IPeak_PCO_225,IPeak_PCO_25,IPeak_PCO_275,IPeak_PCO_3,IPeak_PCO_325,IPeak_PCO_35,IPeak_PCO_375,IPeak_PCO_4]
PeakCases_PCH = [IPeak_PCH_2,IPeak_PCH_225,IPeak_PCH_25,IPeak_PCH_275,IPeak_PCH_3,IPeak_PCH_325,IPeak_PCH_35,IPeak_PCH_375,IPeak_PCH_4]
PeakCases_PCO_Err = [IPeak_PCO_2_Err,IPeak_PCO_225_Err,IPeak_PCO_25_Err,IPeak_PCO_275_Err,IPeak_PCO_3_Err,IPeak_PCO_325_Err,IPeak_PCO_35_Err,IPeak_PCO_375_Err,IPeak_PCO_4_Err]
PeakCases_PCH_Err = [IPeak_PCH_2_Err,IPeak_PCH_225_Err,IPeak_PCH_25_Err,IPeak_PCH_275_Err,IPeak_PCH_3_Err,IPeak_PCH_325_Err,IPeak_PCH_35_Err,IPeak_PCH_375_Err,IPeak_PCH_4_Err]
R = [2,2.25,2.5,2.75,3,3.25,3.5,3.75,4]
plt.errorbar(R,PeakCases_PCO, yerr = PeakCases_PCO_Err,fmt='o',label = 'PCOcination')
plt.errorbar(R,PeakCases_PCH,yerr = PeakCases_PCH_Err,marker = 'x',fmt='o',label = 'No PCOcination',color = 'red')
legend = plt.legend(title="Scenario",loc=5,bbox_to_anchor=(1.37,0.5))
frame = legend.get_frame()
plt.xlabel("$R_{0}$")
plt.ylabel("Peak Cases")
plt.rcParams["figure.figsize"] = (6,4)

# %%
#Day of peak, PCOc


plt.boxplot(PeakTimeArray_PCO_2,notch = False,positions = [1])

plt.boxplot(PeakTimeArray_PCO_225,notch = False,positions = [1.5])

plt.boxplot(PeakTimeArray_PCO_25,notch = False,positions = [2])

plt.boxplot(PeakTimeArray_PCO_275,notch = False,positions = [2.5])

plt.boxplot(PeakTimeArray_PCO_3,notch = False,positions = [3])

plt.boxplot(PeakTimeArray_PCO_325,notch = False,positions = [3.5])

plt.boxplot(PeakTimeArray_PCO_35,notch = False,positions = [4])

plt.boxplot(PeakTimeArray_PCO_375,notch = False,positions = [4.5])

plt.boxplot(PeakTimeArray_PCO_4,notch = False,positions = [5])

plt.xticks(ticks = [1,1.5,2,2.5,3,3.5,4,4.5,5],labels = [2, 2.25, 2.5, 2.75, 3, 3.25, 3.5, 3.75, 4])

plt.xlabel("$R_{0}$")
plt.ylabel("Day of infected peak (from 08/03/21)")
plt.rcParams["figure.figsize"] = (6,9)

# %%
#Day of peak, no NoPCHc


plt.boxplot(PeakTimeArray_PCH_2,notch = False,positions = [1])

plt.boxplot(PeakTimeArray_PCH_225,notch = False,positions = [1.5])

plt.boxplot(PeakTimeArray_PCH_25,notch = False,positions = [2])

plt.boxplot(PeakTimeArray_PCH_275,notch = False,positions = [2.5])

plt.boxplot(PeakTimeArray_PCH_3,notch = False,positions = [3])

plt.boxplot(PeakTimeArray_PCH_325,notch = False,positions = [3.5])

plt.boxplot(PeakTimeArray_PCH_35,notch = False,positions = [4])

plt.boxplot(PeakTimeArray_PCH_375,notch = False,positions = [4.5])

plt.boxplot(PeakTimeArray_PCH_4,notch = False,positions = [5])

plt.xticks(ticks = [1,1.5,2,2.5,3,3.5,4,4.5,5],labels = [2, 2.25, 2.5, 2.75, 3, 3.25, 3.5, 3.75, 4])


plt.xlabel("$R_{0}$")
plt.ylabel("Day of infected peak (from 01/01/21)")
plt.rcParams["figure.figsize"] = (6,9)

# %%
TotalDeaths90 = [Dead90_PCO_2,Dead90_PCO_225,Dead90_PCO_25,Dead90_PCO_275,Dead90_PCO_3,Dead90_PCO_325,Dead90_PCO_35,Dead90_PCO_375,Dead90_PCO_4]

# %%
TotalDeaths90_Err = [Dead90_PCO_2_Err,Dead90_PCO_225_Err,Dead90_PCO_25_Err,Dead90_PCO_275_Err,Dead90_PCO_3_Err,Dead90_PCO_325_Err,Dead90_PCO_35_Err,Dead90_PCO_375_Err,Dead90_PCO_4]

# %%
#Deaths by age, PopnControl
labels = ['2','2.25','2.5','2.75','3','3.25','3.5','3.75','4']
x = np.arange(len(labels))
print(x)
L=12
TotalDeaths019 = [Dead019_PCO_2,Dead019_PCO_225,Dead019_PCO_25,Dead019_PCO_275,Dead019_PCO_3,Dead019_PCO_325,Dead019_PCO_35,Dead019_PCO_375,Dead019_PCO_4]
TotalDeaths2029 = [Dead2029_PCO_2,Dead2029_PCO_225,Dead2029_PCO_25,Dead2029_PCO_275,Dead2029_PCO_3,Dead2029_PCO_325,Dead2029_PCO_35,Dead2029_PCO_375,Dead2029_PCO_4]
TotalDeaths3039 = [Dead3039_PCO_2,Dead3039_PCO_225,Dead3039_PCO_25,Dead3039_PCO_275,Dead3039_PCO_3,Dead3039_PCO_325,Dead3039_PCO_35,Dead3039_PCO_375,Dead3039_PCO_4]
TotalDeaths4049 = [Dead4049_PCO_2,Dead4049_PCO_225,Dead4049_PCO_25,Dead4049_PCO_275,Dead4049_PCO_3,Dead4049_PCO_325,Dead4049_PCO_35,Dead4049_PCO_375,Dead4049_PCO_4]
TotalDeaths5059 = [Dead5059_PCO_2,Dead5059_PCO_225,Dead5059_PCO_25,Dead5059_PCO_275,Dead5059_PCO_3,Dead5059_PCO_325,Dead5059_PCO_35,Dead5059_PCO_375,Dead5059_PCO_4]
TotalDeaths6069 = [Dead6069_PCO_2,Dead6069_PCO_225,Dead6069_PCO_25,Dead6069_PCO_275,Dead6069_PCO_3,Dead6069_PCO_325,Dead6069_PCO_35,Dead6069_PCO_375,Dead6069_PCO_4]
TotalDeaths7079 = [Dead7079_PCO_2,Dead7079_PCO_225,Dead7079_PCO_25,Dead7079_PCO_275,Dead7079_PCO_3,Dead7079_PCO_325,Dead7079_PCO_35,Dead7079_PCO_375,Dead7079_PCO_4]
TotalDeaths8089 = [Dead8089_PCO_2,Dead8089_PCO_225,Dead8089_PCO_25,Dead8089_PCO_275,Dead8089_PCO_3,Dead8089_PCO_325,Dead8089_PCO_35,Dead8089_PCO_375,Dead8089_PCO_4]
TotalDeaths90 = [Dead90_PCO_2,Dead90_PCO_225,Dead90_PCO_25,Dead90_PCO_275,Dead90_PCO_3,Dead90_PCO_325,Dead90_PCO_35,Dead90_PCO_375,Dead90_PCO_4]
TotalDeaths019_Err = [Dead019_PCO_2_Err,Dead019_PCO_225_Err,Dead019_PCO_25_Err,Dead019_PCO_275_Err,Dead019_PCO_3_Err,Dead019_PCO_325_Err,Dead019_PCO_35_Err,Dead019_PCO_375_Err,Dead019_PCO_4_Err]
TotalDeaths2029_Err = [Dead2029_PCO_2_Err,Dead2029_PCO_225_Err,Dead2029_PCO_25_Err,Dead2029_PCO_275_Err,Dead2029_PCO_3_Err,Dead2029_PCO_325_Err,Dead2029_PCO_35_Err,Dead2029_PCO_375_Err,Dead2029_PCO_4_Err]
TotalDeaths3039_Err = [Dead3039_PCO_2_Err,Dead3039_PCO_225_Err,Dead3039_PCO_25_Err,Dead3039_PCO_275_Err,Dead3039_PCO_3_Err,Dead3039_PCO_325_Err,Dead3039_PCO_35_Err,Dead3039_PCO_375_Err,Dead3039_PCO_4_Err]
TotalDeaths4049_Err = [Dead4049_PCO_2_Err,Dead4049_PCO_225_Err,Dead4049_PCO_25_Err,Dead4049_PCO_275_Err,Dead4049_PCO_3_Err,Dead4049_PCO_325_Err,Dead4049_PCO_35_Err,Dead4049_PCO_375_Err,Dead4049_PCO_4_Err]
TotalDeaths5059_Err = [Dead5059_PCO_2_Err,Dead5059_PCO_225_Err,Dead5059_PCO_25_Err,Dead5059_PCO_275_Err,Dead5059_PCO_3_Err,Dead5059_PCO_325_Err,Dead5059_PCO_35_Err,Dead5059_PCO_375_Err,Dead5059_PCO_4_Err]
TotalDeaths6069_Err = [Dead6069_PCO_2_Err,Dead6069_PCO_225_Err,Dead6069_PCO_25_Err,Dead6069_PCO_275_Err,Dead6069_PCO_3_Err,Dead6069_PCO_325_Err,Dead6069_PCO_35_Err,Dead6069_PCO_375_Err,Dead6069_PCO_4_Err]
TotalDeaths7079_Err = [Dead7079_PCO_2_Err,Dead7079_PCO_225_Err,Dead7079_PCO_25_Err,Dead7079_PCO_275_Err,Dead7079_PCO_3_Err,Dead7079_PCO_325_Err,Dead7079_PCO_35_Err,Dead7079_PCO_375_Err,Dead7079_PCO_4_Err]
TotalDeaths8089_Err = [Dead8089_PCO_2_Err,Dead8089_PCO_225_Err,Dead8089_PCO_25_Err,Dead8089_PCO_275_Err,Dead8089_PCO_3_Err,Dead8089_PCO_325_Err,Dead8089_PCO_35_Err,Dead8089_PCO_375_Err,Dead8089_PCO_4_Err]
TotalDeaths90_Err = [Dead90_PCO_2_Err,Dead90_PCO_225_Err,Dead90_PCO_25_Err,Dead90_PCO_275_Err,Dead90_PCO_3_Err,Dead90_PCO_325_Err,Dead90_PCO_35_Err,Dead90_PCO_375_Err,Dead90_PCO_4_Err]
plt.bar(x-(4/L),TotalDeaths019,width=1/L,label = '0-19', yerr = TotalDeaths019_Err)
plt.bar(x-(3/L),TotalDeaths2029,width=1/L,label = '20-29',yerr = TotalDeaths2029_Err)
plt.bar(x-(2/L),TotalDeaths3039,width=1/L,label = '30-39',yerr = TotalDeaths3039_Err)
plt.bar(x-(1/L),TotalDeaths4049,width=1/L,label = '40-49',yerr = TotalDeaths4049_Err)
plt.bar(x,TotalDeaths5059,width=1/L,label = '50-59',yerr = TotalDeaths5059_Err)
plt.bar(x+(1/L),TotalDeaths6069,width=1/L,label = '60-69',yerr = TotalDeaths6069_Err)
plt.bar(x+(2/L),TotalDeaths7079,width=1/L,label = '70-79',yerr = TotalDeaths7079_Err)
plt.bar(x+(3/L),TotalDeaths8089,width=1/L,label = '80-89',yerr = TotalDeaths8089_Err)
plt.bar(x+(4/L),TotalDeaths90,width=1/L,label = '90+',yerr = TotalDeaths90_Err)
Labels = ['0','2','2.5','3','3.5','4']
plt.xticks(ticks = [0,1,2,3,4],labels = [2, 2.5, 3, 3.5, 4])
legend = plt.legend(title="Age Group",loc=5,bbox_to_anchor=(1.25,0.5))
frame = legend.get_frame()
plt.xlabel("$R_{0}$")
plt.ylabel("Total Deaths")
plt.rcParams["figure.figsize"] = (6,4)
# Out:
# [0 1 2 3 4 5 6 7 8]

# %%
#Deaths by age, PCH
labels = ['2','2.25','2.5','2.75','3','3.25','3.5','3.75','4']
x = np.arange(len(labels))
print(x)
L=12
TotalDeaths019 = [Dead019_PCH_2,Dead019_PCH_225,Dead019_PCH_25,Dead019_PCH_275,Dead019_PCH_3,Dead019_PCH_325,Dead019_PCH_35,Dead019_PCH_375,Dead019_PCH_4]
TotalDeaths2029 = [Dead2029_PCH_2,Dead2029_PCH_225,Dead2029_PCH_25,Dead2029_PCH_275,Dead2029_PCH_3,Dead2029_PCH_325,Dead2029_PCH_35,Dead2029_PCH_375,Dead2029_PCH_4]
TotalDeaths3039 = [Dead3039_PCH_2,Dead3039_PCH_225,Dead3039_PCH_25,Dead3039_PCH_275,Dead3039_PCH_3,Dead3039_PCH_325,Dead3039_PCH_35,Dead3039_PCH_375,Dead3039_PCH_4]
TotalDeaths4049 = [Dead4049_PCH_2,Dead4049_PCH_225,Dead4049_PCH_25,Dead4049_PCH_275,Dead4049_PCH_3,Dead4049_PCH_325,Dead4049_PCH_35,Dead4049_PCH_375,Dead4049_PCH_4]
TotalDeaths5059 = [Dead5059_PCH_2,Dead5059_PCH_225,Dead5059_PCH_25,Dead5059_PCH_275,Dead5059_PCH_3,Dead5059_PCH_325,Dead5059_PCH_35,Dead5059_PCH_375,Dead5059_PCH_4]
TotalDeaths6069 = [Dead6069_PCH_2,Dead6069_PCH_225,Dead6069_PCH_25,Dead6069_PCH_275,Dead6069_PCH_3,Dead6069_PCH_325,Dead6069_PCH_35,Dead6069_PCH_375,Dead6069_PCH_4]
TotalDeaths7079 = [Dead7079_PCH_2,Dead7079_PCH_225,Dead7079_PCH_25,Dead7079_PCH_275,Dead7079_PCH_3,Dead7079_PCH_325,Dead7079_PCH_35,Dead7079_PCH_375,Dead7079_PCH_4]
TotalDeaths8089 = [Dead8089_PCH_2,Dead8089_PCH_225,Dead8089_PCH_25,Dead8089_PCH_275,Dead8089_PCH_3,Dead8089_PCH_325,Dead8089_PCH_35,Dead8089_PCH_375,Dead8089_PCH_4]
TotalDeaths90 = [Dead90_PCH_2,Dead90_PCH_225,Dead90_PCH_25,Dead90_PCH_275,Dead90_PCH_3,Dead90_PCH_325,Dead90_PCH_35,Dead90_PCH_375,Dead90_PCH_4]
TotalDeaths019_Err = [Dead019_PCH_2_Err,Dead019_PCH_225_Err,Dead019_PCH_25_Err,Dead019_PCH_275_Err,Dead019_PCH_3_Err,Dead019_PCH_325_Err,Dead019_PCH_35_Err,Dead019_PCH_375_Err,Dead019_PCH_4_Err]
TotalDeaths2029_Err = [Dead2029_PCH_2_Err,Dead2029_PCH_225_Err,Dead2029_PCH_25_Err,Dead2029_PCH_275_Err,Dead2029_PCH_3_Err,Dead2029_PCH_325_Err,Dead2029_PCH_35_Err,Dead2029_PCH_375_Err,Dead2029_PCH_4_Err]
TotalDeaths3039_Err = [Dead3039_PCH_2_Err,Dead3039_PCH_225_Err,Dead3039_PCH_25_Err,Dead3039_PCH_275_Err,Dead3039_PCH_3_Err,Dead3039_PCH_325_Err,Dead3039_PCH_35_Err,Dead3039_PCH_375_Err,Dead3039_PCH_4_Err]
TotalDeaths4049_Err = [Dead4049_PCH_2_Err,Dead4049_PCH_225_Err,Dead4049_PCH_25_Err,Dead4049_PCH_275_Err,Dead4049_PCH_3_Err,Dead4049_PCH_325_Err,Dead4049_PCH_35_Err,Dead4049_PCH_375_Err,Dead4049_PCH_4_Err]
TotalDeaths5059_Err = [Dead5059_PCH_2_Err,Dead5059_PCH_225_Err,Dead5059_PCH_25_Err,Dead5059_PCH_275_Err,Dead5059_PCH_3_Err,Dead5059_PCH_325_Err,Dead5059_PCH_35_Err,Dead5059_PCH_375_Err,Dead5059_PCH_4_Err]
TotalDeaths6069_Err = [Dead6069_PCH_2_Err,Dead6069_PCH_225_Err,Dead6069_PCH_25_Err,Dead6069_PCH_275_Err,Dead6069_PCH_3_Err,Dead6069_PCH_325_Err,Dead6069_PCH_35_Err,Dead6069_PCH_375_Err,Dead6069_PCH_4_Err]
TotalDeaths7079_Err = [Dead7079_PCH_2_Err,Dead7079_PCH_225_Err,Dead7079_PCH_25_Err,Dead7079_PCH_275_Err,Dead7079_PCH_3_Err,Dead7079_PCH_325_Err,Dead7079_PCH_35_Err,Dead7079_PCH_375_Err,Dead7079_PCH_4_Err]
TotalDeaths8089_Err = [Dead8089_PCH_2_Err,Dead8089_PCH_225_Err,Dead8089_PCH_25_Err,Dead8089_PCH_275_Err,Dead8089_PCH_3_Err,Dead8089_PCH_325_Err,Dead8089_PCH_35_Err,Dead8089_PCH_375_Err,Dead8089_PCH_4_Err]
TotalDeaths90_Err = [Dead90_PCH_2_Err,Dead90_PCH_225_Err,Dead90_PCH_25_Err,Dead90_PCH_275_Err,Dead90_PCH_3_Err,Dead90_PCH_325_Err,Dead90_PCH_35_Err,Dead90_PCH_375_Err,Dead90_PCH_4_Err]
plt.bar(x-(4/L),TotalDeaths019,width=1/L,label = '0-19', yerr = TotalDeaths019_Err)
plt.bar(x-(3/L),TotalDeaths2029,width=1/L,label = '20-29',yerr = TotalDeaths2029_Err)
plt.bar(x-(2/L),TotalDeaths3039,width=1/L,label = '30-39',yerr = TotalDeaths3039_Err)
plt.bar(x-(1/L),TotalDeaths4049,width=1/L,label = '40-49',yerr = TotalDeaths4049_Err)
plt.bar(x,TotalDeaths5059,width=1/L,label = '50-59',yerr = TotalDeaths5059_Err)
plt.bar(x+(1/L),TotalDeaths6069,width=1/L,label = '60-69',yerr = TotalDeaths6069_Err)
plt.bar(x+(2/L),TotalDeaths7079,width=1/L,label = '70-79',yerr = TotalDeaths7079_Err)
plt.bar(x+(3/L),TotalDeaths8089,width=1/L,label = '80-89',yerr = TotalDeaths8089_Err)
plt.bar(x+(4/L),TotalDeaths90,width=1/L,label = '90+',yerr = TotalDeaths90_Err)
Labels = ['0','2','2.5','3','3.5','4']
plt.xticks(ticks = [0,1,2,3,4],labels = [2, 2.5, 3, 3.5, 4])
legend = plt.legend(title="Age Group",loc=5,bbox_to_anchor=(1.25,0.5))
frame = legend.get_frame()
plt.xlabel("$R_{0}$")
plt.ylabel("Total Deaths")
plt.rcParams["figure.figsize"] = (6,4)
# Out:
# [0 1 2 3 4 5 6 7 8]

# %%
#Deaths as Percent of cases, PopnControl
labels = ['2','2.25','2.5','2.75','3','3.25','3.5','3.75','4']
x = np.arange(len(labels))
print(x)
L=12
DeathsPercent019 = [(Dead019_PCO_2/Total019_PCO_2)*100,(Dead019_PCO_225/Total019_PCO_225)*100,\
                    (Dead019_PCO_25/Total019_PCO_25)*100,(Dead019_PCO_275/Total019_PCO_275)*100,\
                    (Dead019_PCO_3/Total019_PCO_3)*100,(Dead019_PCO_325/Total019_PCO_325)*100,\
                    (Dead019_PCO_35/Total019_PCO_35)*100,(Dead019_PCO_375/Total019_PCO_375)*100,\
                    (Dead019_PCO_4/Total019_PCO_4)*100]
DeathsPercent2029 = [(Dead2029_PCO_2/Total2029_PCO_2)*100,(Dead2029_PCO_225/Total2029_PCO_225)*100,\
                    (Dead2029_PCO_25/Total2029_PCO_25)*100,(Dead2029_PCO_275/Total2029_PCO_275)*100,\
                    (Dead2029_PCO_3/Total2029_PCO_3)*100,(Dead2029_PCO_325/Total2029_PCO_325)*100,\
                    (Dead2029_PCO_35/Total2029_PCO_35)*100,(Dead2029_PCO_375/Total2029_PCO_375)*100,\
                    (Dead2029_PCO_4/Total2029_PCO_4)*100]
DeathsPercent3039 = [(Dead3039_PCO_2/Total3039_PCO_2)*100,(Dead3039_PCO_225/Total3039_PCO_225)*100,\
                    (Dead3039_PCO_25/Total3039_PCO_25)*100,(Dead3039_PCO_275/Total3039_PCO_275)*100,\
                    (Dead3039_PCO_3/Total3039_PCO_3)*100,(Dead3039_PCO_325/Total3039_PCO_325)*100,\
                    (Dead3039_PCO_35/Total3039_PCO_35)*100,(Dead3039_PCO_375/Total3039_PCO_375)*100,\
                    (Dead3039_PCO_4/Total3039_PCO_4)*100]
DeathsPercent4049 = [(Dead4049_PCO_2/Total4049_PCO_2)*100,(Dead4049_PCO_225/Total4049_PCO_225)*100,\
                    (Dead4049_PCO_25/Total4049_PCO_25)*100,(Dead4049_PCO_275/Total4049_PCO_275)*100,\
                    (Dead4049_PCO_3/Total4049_PCO_3)*100,(Dead4049_PCO_325/Total4049_PCO_325)*100,\
                    (Dead4049_PCO_35/Total4049_PCO_35)*100,(Dead4049_PCO_375/Total4049_PCO_375)*100,\
                    (Dead4049_PCO_4/Total4049_PCO_4)*100]
DeathsPercent5059 = [(Dead5059_PCO_2/Total5059_PCO_2)*100,(Dead5059_PCO_225/Total5059_PCO_225)*100,\
                    (Dead5059_PCO_25/Total5059_PCO_25)*100,(Dead5059_PCO_275/Total5059_PCO_275)*100,\
                    (Dead5059_PCO_3/Total5059_PCO_3)*100,(Dead5059_PCO_325/Total5059_PCO_325)*100,\
                    (Dead5059_PCO_35/Total5059_PCO_35)*100,(Dead5059_PCO_375/Total5059_PCO_375)*100,\
                    (Dead5059_PCO_4/Total5059_PCO_4)*100]
DeathsPercent6069 = [(Dead6069_PCO_2/Total6069_PCO_2)*100,(Dead6069_PCO_225/Total6069_PCO_225)*100,\
                    (Dead6069_PCO_25/Total6069_PCO_25)*100,(Dead6069_PCO_275/Total6069_PCO_275)*100,\
                    (Dead6069_PCO_3/Total6069_PCO_3)*100,(Dead6069_PCO_325/Total6069_PCO_325)*100,\
                    (Dead6069_PCO_35/Total6069_PCO_35)*100,(Dead6069_PCO_375/Total6069_PCO_375)*100,\
                    (Dead6069_PCO_4/Total6069_PCO_4)*100]
DeathsPercent7079 = [(Dead7079_PCO_2/Total7079_PCO_2)*100,(Dead7079_PCO_225/Total7079_PCO_225)*100,\
                    (Dead7079_PCO_25/Total7079_PCO_25)*100,(Dead7079_PCO_275/Total7079_PCO_275)*100,\
                    (Dead7079_PCO_3/Total7079_PCO_3)*100,(Dead7079_PCO_325/Total7079_PCO_325)*100,\
                    (Dead7079_PCO_35/Total7079_PCO_35)*100,(Dead7079_PCO_375/Total7079_PCO_375)*100,\
                    (Dead7079_PCO_4/Total7079_PCO_4)*100]
DeathsPercent8089 = [(Dead8089_PCO_2/Total8089_PCO_2)*100,(Dead8089_PCO_225/Total8089_PCO_225)*100,\
                    (Dead8089_PCO_25/Total8089_PCO_25)*100,(Dead8089_PCO_275/Total8089_PCO_275)*100,\
                    (Dead8089_PCO_3/Total8089_PCO_3)*100,(Dead8089_PCO_325/Total8089_PCO_325)*100,\
                    (Dead8089_PCO_35/Total8089_PCO_35)*100,(Dead8089_PCO_375/Total8089_PCO_375)*100,\
                    (Dead8089_PCO_4/Total8089_PCO_4)*100]
DeathsPercent90 = [(Dead90_PCO_2/Total90_PCO_2)*100,(Dead90_PCO_225/Total90_PCO_225)*100,\
                    (Dead90_PCO_25/Total90_PCO_25)*100,(Dead90_PCO_275/Total90_PCO_275)*100,\
                    (Dead90_PCO_3/Total90_PCO_3)*100,(Dead90_PCO_325/Total90_PCO_325)*100,\
                    (Dead90_PCO_35/Total90_PCO_35)*100,(Dead90_PCO_375/Total90_PCO_375)*100,\
                    (Dead90_PCO_4/Total90_PCO_4)*100]
DeathsPercent019_Err = [(Dead019_PCO_2/Total019_PCO_2)*100*np.sqrt(((Dead019_PCO_2_Err/Dead019_PCO_2)**2)\
                        +(Total019_PCO_2_Err/Total019_PCO_2)**2),\
                        (Dead019_PCO_225/Total019_PCO_225)*100*np.sqrt(((Dead019_PCO_225_Err/Dead019_PCO_225)**2)\
                        +(Total019_PCO_225_Err/Total019_PCO_225)**2),\
                        (Dead019_PCO_25/Total019_PCO_25)*100*np.sqrt(((Dead019_PCO_25_Err/Dead019_PCO_25)**2)\
                        +(Total019_PCO_25_Err/Total019_PCO_25)**2),\
                        (Dead019_PCO_275/Total019_PCO_275)*100*np.sqrt(((Dead019_PCO_275_Err/Dead019_PCO_275)**2)\
                        +(Total019_PCO_275_Err/Total019_PCO_275)**2),\
                        (Dead019_PCO_3/Total019_PCO_3)*100*np.sqrt(((Dead019_PCO_3_Err/Dead019_PCO_3)**2)\
                        +(Total019_PCO_3_Err/Total019_PCO_3)**2),\
                        (Dead019_PCO_325/Total019_PCO_325)*100*np.sqrt(((Dead019_PCO_325_Err/Dead019_PCO_325)**2)\
                        +(Total019_PCO_325_Err/Total019_PCO_325)**2),\
                        (Dead019_PCO_35/Total019_PCO_35)*100*np.sqrt(((Dead019_PCO_35_Err/Dead019_PCO_35)**2)\
                        +(Total019_PCO_35_Err/Total019_PCO_35)**2),\
                        (Dead019_PCO_375/Total019_PCO_375)*100*np.sqrt(((Dead019_PCO_375_Err/Dead019_PCO_375)**2)\
                        +(Total019_PCO_375_Err/Total019_PCO_375)**2),\
                        (Dead019_PCO_4/Total019_PCO_4)*100*np.sqrt(((Dead019_PCO_4_Err/Dead019_PCO_4)**2)\
                        +(Total019_PCO_4_Err/Total019_PCO_4)**2)]
DeathsPercent2029_Err = [(Dead2029_PCO_2/Total2029_PCO_2)*100*np.sqrt(((Dead2029_PCO_2_Err/Dead2029_PCO_2)**2)\
                        +(Total2029_PCO_2_Err/Total2029_PCO_2)**2),\
                        (Dead2029_PCO_225/Total2029_PCO_225)*100*np.sqrt(((Dead2029_PCO_225_Err/Dead2029_PCO_225)**2)\
                        +(Total2029_PCO_225_Err/Total2029_PCO_225)**2),\
                        (Dead2029_PCO_25/Total2029_PCO_25)*100*np.sqrt(((Dead2029_PCO_25_Err/Dead2029_PCO_25)**2)\
                        +(Total2029_PCO_25_Err/Total2029_PCO_25)**2),\
                        (Dead2029_PCO_275/Total2029_PCO_275)*100*np.sqrt(((Dead2029_PCO_275_Err/Dead2029_PCO_275)**2)\
                        +(Total2029_PCO_275_Err/Total2029_PCO_275)**2),\
                        (Dead2029_PCO_3/Total2029_PCO_3)*100*np.sqrt(((Dead2029_PCO_3_Err/Dead2029_PCO_3)**2)\
                        +(Total2029_PCO_3_Err/Total2029_PCO_3)**2),\
                        (Dead2029_PCO_325/Total2029_PCO_325)*100*np.sqrt(((Dead2029_PCO_325_Err/Dead2029_PCO_325)**2)\
                        +(Total2029_PCO_325_Err/Total2029_PCO_325)**2),\
                        (Dead2029_PCO_35/Total2029_PCO_35)*100*np.sqrt(((Dead2029_PCO_35_Err/Dead2029_PCO_35)**2)\
                        +(Total2029_PCO_35_Err/Total2029_PCO_35)**2),\
                        (Dead2029_PCO_375/Total2029_PCO_375)*100*np.sqrt(((Dead2029_PCO_375_Err/Dead2029_PCO_375)**2)\
                        +(Total2029_PCO_375_Err/Total2029_PCO_375)**2),\
                        (Dead2029_PCO_4/Total2029_PCO_4)*100*np.sqrt(((Dead2029_PCO_4_Err/Dead2029_PCO_4)**2)\
                        +(Total2029_PCO_4_Err/Total2029_PCO_4)**2)]       
DeathsPercent3039_Err = [(Dead3039_PCO_2/Total3039_PCO_2)*100*np.sqrt(((Dead3039_PCO_2_Err/Dead3039_PCO_2)**2)\
                        +(Total3039_PCO_2_Err/Total3039_PCO_2)**2),\
                        (Dead3039_PCO_225/Total3039_PCO_225)*100*np.sqrt(((Dead3039_PCO_225_Err/Dead3039_PCO_225)**2)\
                        +(Total3039_PCO_225_Err/Total3039_PCO_225)**2),\
                        (Dead3039_PCO_25/Total3039_PCO_25)*100*np.sqrt(((Dead3039_PCO_25_Err/Dead3039_PCO_25)**2)\
                        +(Total3039_PCO_25_Err/Total3039_PCO_25)**2),\
                        (Dead3039_PCO_275/Total3039_PCO_275)*100*np.sqrt(((Dead3039_PCO_275_Err/Dead3039_PCO_275)**2)\
                        +(Total3039_PCO_275_Err/Total3039_PCO_275)**2),\
                        (Dead3039_PCO_3/Total3039_PCO_3)*100*np.sqrt(((Dead3039_PCO_3_Err/Dead3039_PCO_3)**2)\
                        +(Total3039_PCO_3_Err/Total3039_PCO_3)**2),\
                        (Dead3039_PCO_325/Total3039_PCO_325)*100*np.sqrt(((Dead3039_PCO_325_Err/Dead3039_PCO_325)**2)\
                        +(Total3039_PCO_325_Err/Total3039_PCO_325)**2),\
                        (Dead3039_PCO_35/Total3039_PCO_35)*100*np.sqrt(((Dead3039_PCO_35_Err/Dead3039_PCO_35)**2)\
                        +(Total3039_PCO_35_Err/Total3039_PCO_35)**2),\
                        (Dead3039_PCO_375/Total3039_PCO_375)*100*np.sqrt(((Dead3039_PCO_375_Err/Dead3039_PCO_375)**2)\
                        +(Total3039_PCO_375_Err/Total3039_PCO_375)**2),\
                        (Dead3039_PCO_4/Total3039_PCO_4)*100*np.sqrt(((Dead3039_PCO_4_Err/Dead3039_PCO_4)**2)\
                        +(Total3039_PCO_4_Err/Total3039_PCO_4)**2)]
DeathsPercent4049_Err = [(Dead4049_PCO_2/Total4049_PCO_2)*100*np.sqrt(((Dead4049_PCO_2_Err/Dead4049_PCO_2)**2)\
                        +(Total4049_PCO_2_Err/Total4049_PCO_2)**2),\
                        (Dead4049_PCO_225/Total4049_PCO_225)*100*np.sqrt(((Dead4049_PCO_225_Err/Dead4049_PCO_225)**2)\
                        +(Total4049_PCO_225_Err/Total4049_PCO_225)**2),\
                        (Dead4049_PCO_25/Total4049_PCO_25)*100*np.sqrt(((Dead4049_PCO_25_Err/Dead4049_PCO_25)**2)\
                        +(Total4049_PCO_25_Err/Total4049_PCO_25)**2),\
                        (Dead4049_PCO_275/Total4049_PCO_275)*100*np.sqrt(((Dead4049_PCO_275_Err/Dead4049_PCO_275)**2)\
                        +(Total4049_PCO_275_Err/Total4049_PCO_275)**2),\
                        (Dead4049_PCO_3/Total4049_PCO_3)*100*np.sqrt(((Dead4049_PCO_3_Err/Dead4049_PCO_3)**2)\
                        +(Total4049_PCO_3_Err/Total4049_PCO_3)**2),\
                        (Dead4049_PCO_325/Total4049_PCO_325)*100*np.sqrt(((Dead4049_PCO_325_Err/Dead4049_PCO_325)**2)\
                        +(Total4049_PCO_325_Err/Total4049_PCO_325)**2),\
                        (Dead4049_PCO_35/Total4049_PCO_35)*100*np.sqrt(((Dead4049_PCO_35_Err/Dead4049_PCO_35)**2)\
                        +(Total4049_PCO_35_Err/Total4049_PCO_35)**2),\
                        (Dead4049_PCO_375/Total4049_PCO_375)*100*np.sqrt(((Dead4049_PCO_375_Err/Dead4049_PCO_375)**2)\
                        +(Total4049_PCO_375_Err/Total4049_PCO_375)**2),\
                        (Dead4049_PCO_4/Total4049_PCO_4)*100*np.sqrt(((Dead4049_PCO_4_Err/Dead4049_PCO_4)**2)\
                        +(Total4049_PCO_4_Err/Total4049_PCO_4)**2)]
DeathsPercent5059_Err = [(Dead5059_PCO_2/Total5059_PCO_2)*100*np.sqrt(((Dead5059_PCO_2_Err/Dead5059_PCO_2)**2)\
                        +(Total5059_PCO_2_Err/Total5059_PCO_2)**2),\
                        (Dead5059_PCO_225/Total5059_PCO_225)*100*np.sqrt(((Dead5059_PCO_225_Err/Dead5059_PCO_225)**2)\
                        +(Total5059_PCO_225_Err/Total5059_PCO_225)**2),\
                        (Dead5059_PCO_25/Total5059_PCO_25)*100*np.sqrt(((Dead5059_PCO_25_Err/Dead5059_PCO_25)**2)\
                        +(Total5059_PCO_25_Err/Total5059_PCO_25)**2),\
                        (Dead5059_PCO_275/Total5059_PCO_275)*100*np.sqrt(((Dead5059_PCO_275_Err/Dead5059_PCO_275)**2)\
                        +(Total5059_PCO_275_Err/Total5059_PCO_275)**2),\
                        (Dead5059_PCO_3/Total5059_PCO_3)*100*np.sqrt(((Dead5059_PCO_3_Err/Dead5059_PCO_3)**2)\
                        +(Total5059_PCO_3_Err/Total5059_PCO_3)**2),\
                        (Dead5059_PCO_325/Total5059_PCO_325)*100*np.sqrt(((Dead5059_PCO_325_Err/Dead5059_PCO_325)**2)\
                        +(Total5059_PCO_325_Err/Total5059_PCO_325)**2),\
                        (Dead5059_PCO_35/Total5059_PCO_35)*100*np.sqrt(((Dead5059_PCO_35_Err/Dead5059_PCO_35)**2)\
                        +(Total5059_PCO_35_Err/Total5059_PCO_35)**2),\
                        (Dead5059_PCO_375/Total5059_PCO_375)*100*np.sqrt(((Dead5059_PCO_375_Err/Dead5059_PCO_375)**2)\
                        +(Total5059_PCO_375_Err/Total5059_PCO_375)**2),\
                        (Dead5059_PCO_4/Total5059_PCO_4)*100*np.sqrt(((Dead5059_PCO_4_Err/Dead5059_PCO_4)**2)\
                        +(Total5059_PCO_4_Err/Total5059_PCO_4)**2)]
DeathsPercent6069_Err = [(Dead6069_PCO_2/Total6069_PCO_2)*100*np.sqrt(((Dead6069_PCO_2_Err/Dead6069_PCO_2)**2)\
                        +(Total6069_PCO_2_Err/Total6069_PCO_2)**2),\
                        (Dead6069_PCO_225/Total6069_PCO_225)*100*np.sqrt(((Dead6069_PCO_225_Err/Dead6069_PCO_225)**2)\
                        +(Total6069_PCO_225_Err/Total6069_PCO_225)**2),\
                        (Dead6069_PCO_25/Total6069_PCO_25)*100*np.sqrt(((Dead6069_PCO_25_Err/Dead6069_PCO_25)**2)\
                        +(Total6069_PCO_25_Err/Total6069_PCO_25)**2),\
                        (Dead6069_PCO_275/Total6069_PCO_275)*100*np.sqrt(((Dead6069_PCO_275_Err/Dead6069_PCO_275)**2)\
                        +(Total6069_PCO_275_Err/Total6069_PCO_275)**2),\
                        (Dead6069_PCO_3/Total6069_PCO_3)*100*np.sqrt(((Dead6069_PCO_3_Err/Dead6069_PCO_3)**2)\
                        +(Total6069_PCO_3_Err/Total6069_PCO_3)**2),\
                        (Dead6069_PCO_325/Total6069_PCO_325)*100*np.sqrt(((Dead6069_PCO_325_Err/Dead6069_PCO_325)**2)\
                        +(Total6069_PCO_325_Err/Total6069_PCO_325)**2),\
                        (Dead6069_PCO_35/Total6069_PCO_35)*100*np.sqrt(((Dead6069_PCO_35_Err/Dead6069_PCO_35)**2)\
                        +(Total6069_PCO_35_Err/Total6069_PCO_35)**2),\
                        (Dead6069_PCO_375/Total6069_PCO_375)*100*np.sqrt(((Dead6069_PCO_375_Err/Dead6069_PCO_375)**2)\
                        +(Total6069_PCO_375_Err/Total6069_PCO_375)**2),\
                        (Dead6069_PCO_4/Total6069_PCO_4)*100*np.sqrt(((Dead6069_PCO_4_Err/Dead6069_PCO_4)**2)\
                        +(Total6069_PCO_4_Err/Total6069_PCO_4)**2)]                      
DeathsPercent7079_Err = [(Dead7079_PCO_2/Total7079_PCO_2)*100*np.sqrt(((Dead7079_PCO_2_Err/Dead7079_PCO_2)**2)\
                        +(Total7079_PCO_2_Err/Total7079_PCO_2)**2),\
                        (Dead7079_PCO_225/Total7079_PCO_225)*100*np.sqrt(((Dead7079_PCO_225_Err/Dead7079_PCO_225)**2)\
                        +(Total7079_PCO_225_Err/Total7079_PCO_225)**2),\
                        (Dead7079_PCO_25/Total7079_PCO_25)*100*np.sqrt(((Dead7079_PCO_25_Err/Dead7079_PCO_25)**2)\
                        +(Total7079_PCO_25_Err/Total7079_PCO_25)**2),\
                        (Dead7079_PCO_275/Total7079_PCO_275)*100*np.sqrt(((Dead7079_PCO_275_Err/Dead7079_PCO_275)**2)\
                        +(Total7079_PCO_275_Err/Total7079_PCO_275)**2),\
                        (Dead7079_PCO_3/Total7079_PCO_3)*100*np.sqrt(((Dead7079_PCO_3_Err/Dead7079_PCO_3)**2)\
                        +(Total7079_PCO_3_Err/Total7079_PCO_3)**2),\
                        (Dead7079_PCO_325/Total7079_PCO_325)*100*np.sqrt(((Dead7079_PCO_325_Err/Dead7079_PCO_325)**2)\
                        +(Total7079_PCO_325_Err/Total7079_PCO_325)**2),\
                        (Dead7079_PCO_35/Total7079_PCO_35)*100*np.sqrt(((Dead7079_PCO_35_Err/Dead7079_PCO_35)**2)\
                        +(Total7079_PCO_35_Err/Total7079_PCO_35)**2),\
                        (Dead7079_PCO_375/Total7079_PCO_375)*100*np.sqrt(((Dead7079_PCO_375_Err/Dead7079_PCO_375)**2)\
                        +(Total7079_PCO_375_Err/Total7079_PCO_375)**2),\
                        (Dead7079_PCO_4/Total7079_PCO_4)*100*np.sqrt(((Dead7079_PCO_4_Err/Dead7079_PCO_4)**2)\
                        +(Total7079_PCO_4_Err/Total7079_PCO_4)**2)]
DeathsPercent8089_Err = [(Dead8089_PCO_2/Total8089_PCO_2)*100*np.sqrt(((Dead8089_PCO_2_Err/Dead8089_PCO_2)**2)\
                        +(Total8089_PCO_2_Err/Total8089_PCO_2)**2),\
                        (Dead8089_PCO_225/Total8089_PCO_225)*100*np.sqrt(((Dead8089_PCO_225_Err/Dead8089_PCO_225)**2)\
                        +(Total8089_PCO_225_Err/Total8089_PCO_225)**2),\
                        (Dead8089_PCO_25/Total8089_PCO_25)*100*np.sqrt(((Dead8089_PCO_25_Err/Dead8089_PCO_25)**2)\
                        +(Total8089_PCO_25_Err/Total8089_PCO_25)**2),\
                        (Dead8089_PCO_275/Total8089_PCO_275)*100*np.sqrt(((Dead8089_PCO_275_Err/Dead8089_PCO_275)**2)\
                        +(Total8089_PCO_275_Err/Total8089_PCO_275)**2),\
                        (Dead8089_PCO_3/Total8089_PCO_3)*100*np.sqrt(((Dead8089_PCO_3_Err/Dead8089_PCO_3)**2)\
                        +(Total8089_PCO_3_Err/Total8089_PCO_3)**2),\
                        (Dead8089_PCO_325/Total8089_PCO_325)*100*np.sqrt(((Dead8089_PCO_325_Err/Dead8089_PCO_325)**2)\
                        +(Total8089_PCO_325_Err/Total8089_PCO_325)**2),\
                        (Dead8089_PCO_35/Total8089_PCO_35)*100*np.sqrt(((Dead8089_PCO_35_Err/Dead8089_PCO_35)**2)\
                        +(Total8089_PCO_35_Err/Total8089_PCO_35)**2),\
                        (Dead8089_PCO_375/Total8089_PCO_375)*100*np.sqrt(((Dead8089_PCO_375_Err/Dead8089_PCO_375)**2)\
                        +(Total8089_PCO_375_Err/Total8089_PCO_375)**2),\
                        (Dead8089_PCO_4/Total8089_PCO_4)*100*np.sqrt(((Dead8089_PCO_4_Err/Dead8089_PCO_4)**2)\
                        +(Total8089_PCO_4_Err/Total8089_PCO_4)**2)]
DeathsPercent90_Err = [(Dead90_PCO_2/Total90_PCO_2)*100*np.sqrt(((Dead90_PCO_2_Err/Dead90_PCO_2)**2)\
                        +(Total90_PCO_2_Err/Total90_PCO_2)**2),\
                        (Dead90_PCO_225/Total90_PCO_225)*100*np.sqrt(((Dead90_PCO_225_Err/Dead90_PCO_225)**2)\
                        +(Total90_PCO_225_Err/Total90_PCO_225)**2),\
                        (Dead90_PCO_25/Total90_PCO_25)*100*np.sqrt(((Dead90_PCO_25_Err/Dead90_PCO_25)**2)\
                        +(Total90_PCO_25_Err/Total90_PCO_25)**2),\
                        (Dead90_PCO_275/Total90_PCO_275)*100*np.sqrt(((Dead90_PCO_275_Err/Dead90_PCO_275)**2)\
                        +(Total90_PCO_275_Err/Total90_PCO_275)**2),\
                        (Dead90_PCO_3/Total90_PCO_3)*100*np.sqrt(((Dead90_PCO_3_Err/Dead90_PCO_3)**2)\
                        +(Total90_PCO_3_Err/Total90_PCO_3)**2),\
                        (Dead90_PCO_325/Total90_PCO_325)*100*np.sqrt(((Dead90_PCO_325_Err/Dead90_PCO_325)**2)\
                        +(Total90_PCO_325_Err/Total90_PCO_325)**2),\
                        (Dead90_PCO_35/Total90_PCO_35)*100*np.sqrt(((Dead90_PCO_35_Err/Dead90_PCO_35)**2)\
                        +(Total90_PCO_35_Err/Total90_PCO_35)**2),\
                        (Dead90_PCO_375/Total90_PCO_375)*100*np.sqrt(((Dead90_PCO_375_Err/Dead90_PCO_375)**2)\
                        +(Total90_PCO_375_Err/Total90_PCO_375)**2),\
                        (Dead90_PCO_4/Total90_PCO_4)*100*np.sqrt(((Dead90_PCO_4_Err/Dead90_PCO_4)**2)\
                        +(Total90_PCO_4_Err/Total90_PCO_4)**2)] 
plt.bar(x-(4/L),DeathsPercent019,width=1/L,label = '0-19', yerr = DeathsPercent019_Err)
plt.bar(x-(3/L),DeathsPercent2029,width=1/L,label = '20-29',yerr = DeathsPercent2029_Err)
plt.bar(x-(2/L),DeathsPercent3039,width=1/L,label = '30-39',yerr = DeathsPercent3039_Err)
plt.bar(x-(1/L),DeathsPercent4049,width=1/L,label = '40-49',yerr = DeathsPercent4049_Err)
plt.bar(x,DeathsPercent5059,width=1/L,label = '50-59',yerr = DeathsPercent5059_Err)
plt.bar(x+(1/L),DeathsPercent6069,width=1/L,label = '60-69',yerr = DeathsPercent6069_Err)
plt.bar(x+(2/L),DeathsPercent7079,width=1/L,label = '70-79',yerr = DeathsPercent7079_Err)
plt.bar(x+(3/L),DeathsPercent8089,width=1/L,label = '80-89',yerr = DeathsPercent8089_Err)
plt.bar(x+(4/L),DeathsPercent90,width=1/L,label = '90+',yerr = DeathsPercent90_Err)
Labels = ['0','2','2.5','3','3.5','4']
plt.xticks(ticks = [0,1,2,3,4],labels = [2, 2.5, 3, 3.5, 4])
legend = plt.legend(title="Age Group",loc=5,bbox_to_anchor=(1.25,0.5))
frame = legend.get_frame()
plt.xlabel("$R_{0}$")
plt.ylabel("Deaths as Percent of total cases")
plt.rcParams["figure.figsize"] = (6,4)
# Out:
# [0 1 2 3 4 5 6 7 8]

# %%
#Deaths as Percent of cases, PopnChanged
labels = ['2','2.25','2.5','2.75','3','3.25','3.5','3.75','4']
x = np.arange(len(labels))
print(x)
L=12
DeathsPercent019 = [(Dead019_PCH_2/Total019_PCH_2)*100,(Dead019_PCH_225/Total019_PCH_225)*100,\
                    (Dead019_PCH_25/Total019_PCH_25)*100,(Dead019_PCH_275/Total019_PCH_275)*100,\
                    (Dead019_PCH_3/Total019_PCH_3)*100,(Dead019_PCH_325/Total019_PCH_325)*100,\
                    (Dead019_PCH_35/Total019_PCH_35)*100,(Dead019_PCH_375/Total019_PCH_375)*100,\
                    (Dead019_PCH_4/Total019_PCH_4)*100]
DeathsPercent2029 = [(Dead2029_PCH_2/Total2029_PCH_2)*100,(Dead2029_PCH_225/Total2029_PCH_225)*100,\
                    (Dead2029_PCH_25/Total2029_PCH_25)*100,(Dead2029_PCH_275/Total2029_PCH_275)*100,\
                    (Dead2029_PCH_3/Total2029_PCH_3)*100,(Dead2029_PCH_325/Total2029_PCH_325)*100,\
                    (Dead2029_PCH_35/Total2029_PCH_35)*100,(Dead2029_PCH_375/Total2029_PCH_375)*100,\
                    (Dead2029_PCH_4/Total2029_PCH_4)*100]
DeathsPercent3039 = [(Dead3039_PCH_2/Total3039_PCH_2)*100,(Dead3039_PCH_225/Total3039_PCH_225)*100,\
                    (Dead3039_PCH_25/Total3039_PCH_25)*100,(Dead3039_PCH_275/Total3039_PCH_275)*100,\
                    (Dead3039_PCH_3/Total3039_PCH_3)*100,(Dead3039_PCH_325/Total3039_PCH_325)*100,\
                    (Dead3039_PCH_35/Total3039_PCH_35)*100,(Dead3039_PCH_375/Total3039_PCH_375)*100,\
                    (Dead3039_PCH_4/Total3039_PCH_4)*100]
DeathsPercent4049 = [(Dead4049_PCH_2/Total4049_PCH_2)*100,(Dead4049_PCH_225/Total4049_PCH_225)*100,\
                    (Dead4049_PCH_25/Total4049_PCH_25)*100,(Dead4049_PCH_275/Total4049_PCH_275)*100,\
                    (Dead4049_PCH_3/Total4049_PCH_3)*100,(Dead4049_PCH_325/Total4049_PCH_325)*100,\
                    (Dead4049_PCH_35/Total4049_PCH_35)*100,(Dead4049_PCH_375/Total4049_PCH_375)*100,\
                    (Dead4049_PCH_4/Total4049_PCH_4)*100]
DeathsPercent5059 = [(Dead5059_PCH_2/Total5059_PCH_2)*100,(Dead5059_PCH_225/Total5059_PCH_225)*100,\
                    (Dead5059_PCH_25/Total5059_PCH_25)*100,(Dead5059_PCH_275/Total5059_PCH_275)*100,\
                    (Dead5059_PCH_3/Total5059_PCH_3)*100,(Dead5059_PCH_325/Total5059_PCH_325)*100,\
                    (Dead5059_PCH_35/Total5059_PCH_35)*100,(Dead5059_PCH_375/Total5059_PCH_375)*100,\
                    (Dead5059_PCH_4/Total5059_PCH_4)*100]
DeathsPercent6069 = [(Dead6069_PCH_2/Total6069_PCH_2)*100,(Dead6069_PCH_225/Total6069_PCH_225)*100,\
                    (Dead6069_PCH_25/Total6069_PCH_25)*100,(Dead6069_PCH_275/Total6069_PCH_275)*100,\
                    (Dead6069_PCH_3/Total6069_PCH_3)*100,(Dead6069_PCH_325/Total6069_PCH_325)*100,\
                    (Dead6069_PCH_35/Total6069_PCH_35)*100,(Dead6069_PCH_375/Total6069_PCH_375)*100,\
                    (Dead6069_PCH_4/Total6069_PCH_4)*100]
DeathsPercent7079 = [(Dead7079_PCH_2/Total7079_PCH_2)*100,(Dead7079_PCH_225/Total7079_PCH_225)*100,\
                    (Dead7079_PCH_25/Total7079_PCH_25)*100,(Dead7079_PCH_275/Total7079_PCH_275)*100,\
                    (Dead7079_PCH_3/Total7079_PCH_3)*100,(Dead7079_PCH_325/Total7079_PCH_325)*100,\
                    (Dead7079_PCH_35/Total7079_PCH_35)*100,(Dead7079_PCH_375/Total7079_PCH_375)*100,\
                    (Dead7079_PCH_4/Total7079_PCH_4)*100]
DeathsPercent8089 = [(Dead8089_PCH_2/Total8089_PCH_2)*100,(Dead8089_PCH_225/Total8089_PCH_225)*100,\
                    (Dead8089_PCH_25/Total8089_PCH_25)*100,(Dead8089_PCH_275/Total8089_PCH_275)*100,\
                    (Dead8089_PCH_3/Total8089_PCH_3)*100,(Dead8089_PCH_325/Total8089_PCH_325)*100,\
                    (Dead8089_PCH_35/Total8089_PCH_35)*100,(Dead8089_PCH_375/Total8089_PCH_375)*100,\
                    (Dead8089_PCH_4/Total8089_PCH_4)*100]
DeathsPercent90 = [(Dead90_PCH_2/Total90_PCH_2)*100,(Dead90_PCH_225/Total90_PCH_225)*100,\
                    (Dead90_PCH_25/Total90_PCH_25)*100,(Dead90_PCH_275/Total90_PCH_275)*100,\
                    (Dead90_PCH_3/Total90_PCH_3)*100,(Dead90_PCH_325/Total90_PCH_325)*100,\
                    (Dead90_PCH_35/Total90_PCH_35)*100,(Dead90_PCH_375/Total90_PCH_375)*100,\
                    (Dead90_PCH_4/Total90_PCH_4)*100]
DeathsPercent019_Err = [(Dead019_PCH_2/Total019_PCH_2)*100*np.sqrt(((Dead019_PCH_2_Err/Dead019_PCH_2)**2)\
                        +(Total019_PCH_2_Err/Total019_PCH_2)**2),\
                        (Dead019_PCH_225/Total019_PCH_225)*100*np.sqrt(((Dead019_PCH_225_Err/Dead019_PCH_225)**2)\
                        +(Total019_PCH_225_Err/Total019_PCH_225)**2),\
                        (Dead019_PCH_25/Total019_PCH_25)*100*np.sqrt(((Dead019_PCH_25_Err/Dead019_PCH_25)**2)\
                        +(Total019_PCH_25_Err/Total019_PCH_25)**2),\
                        (Dead019_PCH_275/Total019_PCH_275)*100*np.sqrt(((Dead019_PCH_275_Err/Dead019_PCH_275)**2)\
                        +(Total019_PCH_275_Err/Total019_PCH_275)**2),\
                        (Dead019_PCH_3/Total019_PCH_3)*100*np.sqrt(((Dead019_PCH_3_Err/Dead019_PCH_3)**2)\
                        +(Total019_PCH_3_Err/Total019_PCH_3)**2),\
                        (Dead019_PCH_325/Total019_PCH_325)*100*np.sqrt(((Dead019_PCH_325_Err/Dead019_PCH_325)**2)\
                        +(Total019_PCH_325_Err/Total019_PCH_325)**2),\
                        (Dead019_PCH_35/Total019_PCH_35)*100*np.sqrt(((Dead019_PCH_35_Err/Dead019_PCH_35)**2)\
                        +(Total019_PCH_35_Err/Total019_PCH_35)**2),\
                        (Dead019_PCH_375/Total019_PCH_375)*100*np.sqrt(((Dead019_PCH_375_Err/Dead019_PCH_375)**2)\
                        +(Total019_PCH_375_Err/Total019_PCH_375)**2),\
                        (Dead019_PCH_4/Total019_PCH_4)*100*np.sqrt(((Dead019_PCH_4_Err/Dead019_PCH_4)**2)\
                        +(Total019_PCH_4_Err/Total019_PCH_4)**2)]
DeathsPercent2029_Err = [(Dead2029_PCH_2/Total2029_PCH_2)*100*np.sqrt(((Dead2029_PCH_2_Err/Dead2029_PCH_2)**2)\
                        +(Total2029_PCH_2_Err/Total2029_PCH_2)**2),\
                        (Dead2029_PCH_225/Total2029_PCH_225)*100*np.sqrt(((Dead2029_PCH_225_Err/Dead2029_PCH_225)**2)\
                        +(Total2029_PCH_225_Err/Total2029_PCH_225)**2),\
                        (Dead2029_PCH_25/Total2029_PCH_25)*100*np.sqrt(((Dead2029_PCH_25_Err/Dead2029_PCH_25)**2)\
                        +(Total2029_PCH_25_Err/Total2029_PCH_25)**2),\
                        (Dead2029_PCH_275/Total2029_PCH_275)*100*np.sqrt(((Dead2029_PCH_275_Err/Dead2029_PCH_275)**2)\
                        +(Total2029_PCH_275_Err/Total2029_PCH_275)**2),\
                        (Dead2029_PCH_3/Total2029_PCH_3)*100*np.sqrt(((Dead2029_PCH_3_Err/Dead2029_PCH_3)**2)\
                        +(Total2029_PCH_3_Err/Total2029_PCH_3)**2),\
                        (Dead2029_PCH_325/Total2029_PCH_325)*100*np.sqrt(((Dead2029_PCH_325_Err/Dead2029_PCH_325)**2)\
                        +(Total2029_PCH_325_Err/Total2029_PCH_325)**2),\
                        (Dead2029_PCH_35/Total2029_PCH_35)*100*np.sqrt(((Dead2029_PCH_35_Err/Dead2029_PCH_35)**2)\
                        +(Total2029_PCH_35_Err/Total2029_PCH_35)**2),\
                        (Dead2029_PCH_375/Total2029_PCH_375)*100*np.sqrt(((Dead2029_PCH_375_Err/Dead2029_PCH_375)**2)\
                        +(Total2029_PCH_375_Err/Total2029_PCH_375)**2),\
                        (Dead2029_PCH_4/Total2029_PCH_4)*100*np.sqrt(((Dead2029_PCH_4_Err/Dead2029_PCH_4)**2)\
                        +(Total2029_PCH_4_Err/Total2029_PCH_4)**2)]       
DeathsPercent3039_Err = [(Dead3039_PCH_2/Total3039_PCH_2)*100*np.sqrt(((Dead3039_PCH_2_Err/Dead3039_PCH_2)**2)\
                        +(Total3039_PCH_2_Err/Total3039_PCH_2)**2),\
                        (Dead3039_PCH_225/Total3039_PCH_225)*100*np.sqrt(((Dead3039_PCH_225_Err/Dead3039_PCH_225)**2)\
                        +(Total3039_PCH_225_Err/Total3039_PCH_225)**2),\
                        (Dead3039_PCH_25/Total3039_PCH_25)*100*np.sqrt(((Dead3039_PCH_25_Err/Dead3039_PCH_25)**2)\
                        +(Total3039_PCH_25_Err/Total3039_PCH_25)**2),\
                        (Dead3039_PCH_275/Total3039_PCH_275)*100*np.sqrt(((Dead3039_PCH_275_Err/Dead3039_PCH_275)**2)\
                        +(Total3039_PCH_275_Err/Total3039_PCH_275)**2),\
                        (Dead3039_PCH_3/Total3039_PCH_3)*100*np.sqrt(((Dead3039_PCH_3_Err/Dead3039_PCH_3)**2)\
                        +(Total3039_PCH_3_Err/Total3039_PCH_3)**2),\
                        (Dead3039_PCH_325/Total3039_PCH_325)*100*np.sqrt(((Dead3039_PCH_325_Err/Dead3039_PCH_325)**2)\
                        +(Total3039_PCH_325_Err/Total3039_PCH_325)**2),\
                        (Dead3039_PCH_35/Total3039_PCH_35)*100*np.sqrt(((Dead3039_PCH_35_Err/Dead3039_PCH_35)**2)\
                        +(Total3039_PCH_35_Err/Total3039_PCH_35)**2),\
                        (Dead3039_PCH_375/Total3039_PCH_375)*100*np.sqrt(((Dead3039_PCH_375_Err/Dead3039_PCH_375)**2)\
                        +(Total3039_PCH_375_Err/Total3039_PCH_375)**2),\
                        (Dead3039_PCH_4/Total3039_PCH_4)*100*np.sqrt(((Dead3039_PCH_4_Err/Dead3039_PCH_4)**2)\
                        +(Total3039_PCH_4_Err/Total3039_PCH_4)**2)]
DeathsPercent4049_Err = [(Dead4049_PCH_2/Total4049_PCH_2)*100*np.sqrt(((Dead4049_PCH_2_Err/Dead4049_PCH_2)**2)\
                        +(Total4049_PCH_2_Err/Total4049_PCH_2)**2),\
                        (Dead4049_PCH_225/Total4049_PCH_225)*100*np.sqrt(((Dead4049_PCH_225_Err/Dead4049_PCH_225)**2)\
                        +(Total4049_PCH_225_Err/Total4049_PCH_225)**2),\
                        (Dead4049_PCH_25/Total4049_PCH_25)*100*np.sqrt(((Dead4049_PCH_25_Err/Dead4049_PCH_25)**2)\
                        +(Total4049_PCH_25_Err/Total4049_PCH_25)**2),\
                        (Dead4049_PCH_275/Total4049_PCH_275)*100*np.sqrt(((Dead4049_PCH_275_Err/Dead4049_PCH_275)**2)\
                        +(Total4049_PCH_275_Err/Total4049_PCH_275)**2),\
                        (Dead4049_PCH_3/Total4049_PCH_3)*100*np.sqrt(((Dead4049_PCH_3_Err/Dead4049_PCH_3)**2)\
                        +(Total4049_PCH_3_Err/Total4049_PCH_3)**2),\
                        (Dead4049_PCH_325/Total4049_PCH_325)*100*np.sqrt(((Dead4049_PCH_325_Err/Dead4049_PCH_325)**2)\
                        +(Total4049_PCH_325_Err/Total4049_PCH_325)**2),\
                        (Dead4049_PCH_35/Total4049_PCH_35)*100*np.sqrt(((Dead4049_PCH_35_Err/Dead4049_PCH_35)**2)\
                        +(Total4049_PCH_35_Err/Total4049_PCH_35)**2),\
                        (Dead4049_PCH_375/Total4049_PCH_375)*100*np.sqrt(((Dead4049_PCH_375_Err/Dead4049_PCH_375)**2)\
                        +(Total4049_PCH_375_Err/Total4049_PCH_375)**2),\
                        (Dead4049_PCH_4/Total4049_PCH_4)*100*np.sqrt(((Dead4049_PCH_4_Err/Dead4049_PCH_4)**2)\
                        +(Total4049_PCH_4_Err/Total4049_PCH_4)**2)]
DeathsPercent5059_Err = [(Dead5059_PCH_2/Total5059_PCH_2)*100*np.sqrt(((Dead5059_PCH_2_Err/Dead5059_PCH_2)**2)\
                        +(Total5059_PCH_2_Err/Total5059_PCH_2)**2),\
                        (Dead5059_PCH_225/Total5059_PCH_225)*100*np.sqrt(((Dead5059_PCH_225_Err/Dead5059_PCH_225)**2)\
                        +(Total5059_PCH_225_Err/Total5059_PCH_225)**2),\
                        (Dead5059_PCH_25/Total5059_PCH_25)*100*np.sqrt(((Dead5059_PCH_25_Err/Dead5059_PCH_25)**2)\
                        +(Total5059_PCH_25_Err/Total5059_PCH_25)**2),\
                        (Dead5059_PCH_275/Total5059_PCH_275)*100*np.sqrt(((Dead5059_PCH_275_Err/Dead5059_PCH_275)**2)\
                        +(Total5059_PCH_275_Err/Total5059_PCH_275)**2),\
                        (Dead5059_PCH_3/Total5059_PCH_3)*100*np.sqrt(((Dead5059_PCH_3_Err/Dead5059_PCH_3)**2)\
                        +(Total5059_PCH_3_Err/Total5059_PCH_3)**2),\
                        (Dead5059_PCH_325/Total5059_PCH_325)*100*np.sqrt(((Dead5059_PCH_325_Err/Dead5059_PCH_325)**2)\
                        +(Total5059_PCH_325_Err/Total5059_PCH_325)**2),\
                        (Dead5059_PCH_35/Total5059_PCH_35)*100*np.sqrt(((Dead5059_PCH_35_Err/Dead5059_PCH_35)**2)\
                        +(Total5059_PCH_35_Err/Total5059_PCH_35)**2),\
                        (Dead5059_PCH_375/Total5059_PCH_375)*100*np.sqrt(((Dead5059_PCH_375_Err/Dead5059_PCH_375)**2)\
                        +(Total5059_PCH_375_Err/Total5059_PCH_375)**2),\
                        (Dead5059_PCH_4/Total5059_PCH_4)*100*np.sqrt(((Dead5059_PCH_4_Err/Dead5059_PCH_4)**2)\
                        +(Total5059_PCH_4_Err/Total5059_PCH_4)**2)]
DeathsPercent6069_Err = [(Dead6069_PCH_2/Total6069_PCH_2)*100*np.sqrt(((Dead6069_PCH_2_Err/Dead6069_PCH_2)**2)\
                        +(Total6069_PCH_2_Err/Total6069_PCH_2)**2),\
                        (Dead6069_PCH_225/Total6069_PCH_225)*100*np.sqrt(((Dead6069_PCH_225_Err/Dead6069_PCH_225)**2)\
                        +(Total6069_PCH_225_Err/Total6069_PCH_225)**2),\
                        (Dead6069_PCH_25/Total6069_PCH_25)*100*np.sqrt(((Dead6069_PCH_25_Err/Dead6069_PCH_25)**2)\
                        +(Total6069_PCH_25_Err/Total6069_PCH_25)**2),\
                        (Dead6069_PCH_275/Total6069_PCH_275)*100*np.sqrt(((Dead6069_PCH_275_Err/Dead6069_PCH_275)**2)\
                        +(Total6069_PCH_275_Err/Total6069_PCH_275)**2),\
                        (Dead6069_PCH_3/Total6069_PCH_3)*100*np.sqrt(((Dead6069_PCH_3_Err/Dead6069_PCH_3)**2)\
                        +(Total6069_PCH_3_Err/Total6069_PCH_3)**2),\
                        (Dead6069_PCH_325/Total6069_PCH_325)*100*np.sqrt(((Dead6069_PCH_325_Err/Dead6069_PCH_325)**2)\
                        +(Total6069_PCH_325_Err/Total6069_PCH_325)**2),\
                        (Dead6069_PCH_35/Total6069_PCH_35)*100*np.sqrt(((Dead6069_PCH_35_Err/Dead6069_PCH_35)**2)\
                        +(Total6069_PCH_35_Err/Total6069_PCH_35)**2),\
                        (Dead6069_PCH_375/Total6069_PCH_375)*100*np.sqrt(((Dead6069_PCH_375_Err/Dead6069_PCH_375)**2)\
                        +(Total6069_PCH_375_Err/Total6069_PCH_375)**2),\
                        (Dead6069_PCH_4/Total6069_PCH_4)*100*np.sqrt(((Dead6069_PCH_4_Err/Dead6069_PCH_4)**2)\
                        +(Total6069_PCH_4_Err/Total6069_PCH_4)**2)]                      
DeathsPercent7079_Err = [(Dead7079_PCH_2/Total7079_PCH_2)*100*np.sqrt(((Dead7079_PCH_2_Err/Dead7079_PCH_2)**2)\
                        +(Total7079_PCH_2_Err/Total7079_PCH_2)**2),\
                        (Dead7079_PCH_225/Total7079_PCH_225)*100*np.sqrt(((Dead7079_PCH_225_Err/Dead7079_PCH_225)**2)\
                        +(Total7079_PCH_225_Err/Total7079_PCH_225)**2),\
                        (Dead7079_PCH_25/Total7079_PCH_25)*100*np.sqrt(((Dead7079_PCH_25_Err/Dead7079_PCH_25)**2)\
                        +(Total7079_PCH_25_Err/Total7079_PCH_25)**2),\
                        (Dead7079_PCH_275/Total7079_PCH_275)*100*np.sqrt(((Dead7079_PCH_275_Err/Dead7079_PCH_275)**2)\
                        +(Total7079_PCH_275_Err/Total7079_PCH_275)**2),\
                        (Dead7079_PCH_3/Total7079_PCH_3)*100*np.sqrt(((Dead7079_PCH_3_Err/Dead7079_PCH_3)**2)\
                        +(Total7079_PCH_3_Err/Total7079_PCH_3)**2),\
                        (Dead7079_PCH_325/Total7079_PCH_325)*100*np.sqrt(((Dead7079_PCH_325_Err/Dead7079_PCH_325)**2)\
                        +(Total7079_PCH_325_Err/Total7079_PCH_325)**2),\
                        (Dead7079_PCH_35/Total7079_PCH_35)*100*np.sqrt(((Dead7079_PCH_35_Err/Dead7079_PCH_35)**2)\
                        +(Total7079_PCH_35_Err/Total7079_PCH_35)**2),\
                        (Dead7079_PCH_375/Total7079_PCH_375)*100*np.sqrt(((Dead7079_PCH_375_Err/Dead7079_PCH_375)**2)\
                        +(Total7079_PCH_375_Err/Total7079_PCH_375)**2),\
                        (Dead7079_PCH_4/Total7079_PCH_4)*100*np.sqrt(((Dead7079_PCH_4_Err/Dead7079_PCH_4)**2)\
                        +(Total7079_PCH_4_Err/Total7079_PCH_4)**2)]
DeathsPercent8089_Err = [(Dead8089_PCH_2/Total8089_PCH_2)*100*np.sqrt(((Dead8089_PCH_2_Err/Dead8089_PCH_2)**2)\
                        +(Total8089_PCH_2_Err/Total8089_PCH_2)**2),\
                        (Dead8089_PCH_225/Total8089_PCH_225)*100*np.sqrt(((Dead8089_PCH_225_Err/Dead8089_PCH_225)**2)\
                        +(Total8089_PCH_225_Err/Total8089_PCH_225)**2),\
                        (Dead8089_PCH_25/Total8089_PCH_25)*100*np.sqrt(((Dead8089_PCH_25_Err/Dead8089_PCH_25)**2)\
                        +(Total8089_PCH_25_Err/Total8089_PCH_25)**2),\
                        (Dead8089_PCH_275/Total8089_PCH_275)*100*np.sqrt(((Dead8089_PCH_275_Err/Dead8089_PCH_275)**2)\
                        +(Total8089_PCH_275_Err/Total8089_PCH_275)**2),\
                        (Dead8089_PCH_3/Total8089_PCH_3)*100*np.sqrt(((Dead8089_PCH_3_Err/Dead8089_PCH_3)**2)\
                        +(Total8089_PCH_3_Err/Total8089_PCH_3)**2),\
                        (Dead8089_PCH_325/Total8089_PCH_325)*100*np.sqrt(((Dead8089_PCH_325_Err/Dead8089_PCH_325)**2)\
                        +(Total8089_PCH_325_Err/Total8089_PCH_325)**2),\
                        (Dead8089_PCH_35/Total8089_PCH_35)*100*np.sqrt(((Dead8089_PCH_35_Err/Dead8089_PCH_35)**2)\
                        +(Total8089_PCH_35_Err/Total8089_PCH_35)**2),\
                        (Dead8089_PCH_375/Total8089_PCH_375)*100*np.sqrt(((Dead8089_PCH_375_Err/Dead8089_PCH_375)**2)\
                        +(Total8089_PCH_375_Err/Total8089_PCH_375)**2),\
                        (Dead8089_PCH_4/Total8089_PCH_4)*100*np.sqrt(((Dead8089_PCH_4_Err/Dead8089_PCH_4)**2)\
                        +(Total8089_PCH_4_Err/Total8089_PCH_4)**2)]
DeathsPercent90_Err = [(Dead90_PCH_2/Total90_PCH_2)*100*np.sqrt(((Dead90_PCH_2_Err/Dead90_PCH_2)**2)\
                        +(Total90_PCH_2_Err/Total90_PCH_2)**2),\
                        (Dead90_PCH_225/Total90_PCH_225)*100*np.sqrt(((Dead90_PCH_225_Err/Dead90_PCH_225)**2)\
                        +(Total90_PCH_225_Err/Total90_PCH_225)**2),\
                        (Dead90_PCH_25/Total90_PCH_25)*100*np.sqrt(((Dead90_PCH_25_Err/Dead90_PCH_25)**2)\
                        +(Total90_PCH_25_Err/Total90_PCH_25)**2),\
                        (Dead90_PCH_275/Total90_PCH_275)*100*np.sqrt(((Dead90_PCH_275_Err/Dead90_PCH_275)**2)\
                        +(Total90_PCH_275_Err/Total90_PCH_275)**2),\
                        (Dead90_PCH_3/Total90_PCH_3)*100*np.sqrt(((Dead90_PCH_3_Err/Dead90_PCH_3)**2)\
                        +(Total90_PCH_3_Err/Total90_PCH_3)**2),\
                        (Dead90_PCH_325/Total90_PCH_325)*100*np.sqrt(((Dead90_PCH_325_Err/Dead90_PCH_325)**2)\
                        +(Total90_PCH_325_Err/Total90_PCH_325)**2),\
                        (Dead90_PCH_35/Total90_PCH_35)*100*np.sqrt(((Dead90_PCH_35_Err/Dead90_PCH_35)**2)\
                        +(Total90_PCH_35_Err/Total90_PCH_35)**2),\
                        (Dead90_PCH_375/Total90_PCH_375)*100*np.sqrt(((Dead90_PCH_375_Err/Dead90_PCH_375)**2)\
                        +(Total90_PCH_375_Err/Total90_PCH_375)**2),\
                        (Dead90_PCH_4/Total90_PCH_4)*100*np.sqrt(((Dead90_PCH_4_Err/Dead90_PCH_4)**2)\
                        +(Total90_PCH_4_Err/Total90_PCH_4)**2)] 
plt.bar(x-(4/L),DeathsPercent019,width=1/L,label = '0-19', yerr = DeathsPercent019_Err)
plt.bar(x-(3/L),DeathsPercent2029,width=1/L,label = '20-29',yerr = DeathsPercent2029_Err)
plt.bar(x-(2/L),DeathsPercent3039,width=1/L,label = '30-39',yerr = DeathsPercent3039_Err)
plt.bar(x-(1/L),DeathsPercent4049,width=1/L,label = '40-49',yerr = DeathsPercent4049_Err)
plt.bar(x,DeathsPercent5059,width=1/L,label = '50-59',yerr = DeathsPercent5059_Err)
plt.bar(x+(1/L),DeathsPercent6069,width=1/L,label = '60-69',yerr = DeathsPercent6069_Err)
plt.bar(x+(2/L),DeathsPercent7079,width=1/L,label = '70-79',yerr = DeathsPercent7079_Err)
plt.bar(x+(3/L),DeathsPercent8089,width=1/L,label = '80-89',yerr = DeathsPercent8089_Err)
plt.bar(x+(4/L),DeathsPercent90,width=1/L,label = '90+',yerr = DeathsPercent90_Err)
Labels = ['0','2','2.5','3','3.5','4']
plt.xticks(ticks = [0,1,2,3,4],labels = [2, 2.5, 3, 3.5, 4])
legend = plt.legend(title="Age Group",loc=5,bbox_to_anchor=(1.25,0.5))
frame = legend.get_frame()
plt.xlabel("$R_{0}$")
plt.ylabel("Deaths as Percent of total cases")
plt.rcParams["figure.figsize"] = (6,4)
# Out:
# [0 1 2 3 4 5 6 7 8]

# %%
#Total Cases
TotalCases_PCO = [TotalCases_PCO_2,TotalCases_PCO_225,TotalCases_PCO_25,TotalCases_PCO_275,TotalCases_PCO_3,TotalCases_PCO_325,TotalCases_PCO_35,TotalCases_PCO_375,TotalCases_PCO_4]
TotalCases_PCO_Err = [TotalCases_PCO_2_Err,TotalCases_PCO_225_Err,TotalCases_PCO_25_Err,TotalCases_PCO_275_Err,TotalCases_PCO_3_Err,TotalCases_PCO_325_Err,TotalCases_PCO_35_Err,TotalCases_PCO_375_Err,TotalCases_PCO_4_Err]
TotalCases_PCH = [TotalCases_PCH_2,TotalCases_PCH_225,TotalCases_PCH_25,TotalCases_PCH_275,TotalCases_PCH_3,TotalCases_PCH_325,TotalCases_PCH_35,TotalCases_PCH_375,TotalCases_PCH_4]
TotalCases_PCH_Err = [TotalCases_PCH_2_Err,TotalCases_PCH_225_Err,TotalCases_PCH_25_Err,TotalCases_PCH_275_Err,TotalCases_PCH_3_Err,TotalCases_PCH_325_Err,TotalCases_PCH_35_Err,TotalCases_PCH_375_Err,TotalCases_PCH_4_Err]
R = [2,2.25,2.5,2.75,3,3.25,3.5,3.75,4]
plt.errorbar(R,TotalCases_PCO, yerr = TotalCases_PCO_Err,fmt='o',label = 'PCOcination')
plt.errorbar(R,TotalCases_PCH,yerr = TotalCases_PCH_Err,marker = 'x',fmt='o',label = 'No PCOcination',color = 'red')
legend = plt.legend(title="Scenario",loc=5,bbox_to_anchor=(1.37,0.5))
frame = legend.get_frame()
plt.xlabel("$R_{0}$")
plt.ylabel("Total Cases")
plt.rcParams["figure.figsize"] = (6,4)

# %%
#Population Strucuture
Pop = pd.DataFrame({'Age': ['0-19','20-29','30-39','40-49','50-59','60-69','70-79','80-89','90+'],
                   'Current Demographic': [-3383995,-2199641,-2276830,-1787197,-1576051,-1087500,-744533,-391348,-88755],
                   'Adjusted Demographic': [5003195,2183630,1981414,1788846,1302245,810287,374775,82171,9289]})

AgeClass = ['90+','80-89','70-79','60-69','50-59','40-49','30-39','20-29','0-19']

bar_plot = sns.barplot(x='Current Demographic',y='Age',data = Pop, order=AgeClass,lw=0, color = 'red',label = 'Current demographic')
bar_plot = sns.barplot(x='Adjusted Demographic',y='Age',data = Pop, order=AgeClass,lw=0, color = 'blue',label = 'Adjusted demographic structure')
bar_plot.set(xlabel="Population", ylabel="Age Group", title = "Population Pyramid")
plt.xlim([-6e6, 6e6])
legend = plt.legend(title="Scenario",loc=5,bbox_to_anchor=(1.0,0.9), fontsize = 'x-small')
frame = legend.get_frame()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-42c1b8a57c13> in <module>
#       6 AgeClass = ['90+','80-89','70-79','60-69','50-59','40-49','30-39','20-29','0-19']
#       7
# ----> 8 bar_plot = sns.barplot(x='Current Demographic',y='Age',data = Pop, order=AgeClass,lw=0, color = 'red',label = 'Current demographic')
#       9 bar_plot = sns.barplot(x='Adjusted Demographic',y='Age',data = Pop, order=AgeClass,lw=0, color = 'blue',label = 'Adjusted demographic structure')
#      10 bar_plot.set(xlabel="Population", ylabel="Age Group", title = "Population Pyramid")
#
# NameError: name 'sns' is not defined
